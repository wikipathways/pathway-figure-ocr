# %% [markdown]
# # Chemical Intersections
#
# [GitHub issue](https://github.com/wikipathways/pathway-figure-ocr/issues/25)

# %%
import json
import os
import re
import sys
import tempfile
from pathlib import Path
from pprint import pprint

import numpy as np
import openpyxl
import pandas as pd
import requests
import requests_cache
import xlrd

requests_cache.install_cache("pfocr_cache")

# %% [markdown]
# ## Load PFOCR Chemicals

# %%
pfocr_chemicals_2020_url = "https://www.dropbox.com/s/08tnkgyty3u8cr4/pfocr_chemical_export_20201130.tsv?dl=1"

with tempfile.NamedTemporaryFile(suffix=".tsv") as f:
    pfocr_chemicals_2020_path = f.name
    with requests.get(pfocr_chemicals_2020_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)

    pfocr_chemicals_2020_df = (
        pd.read_csv(str(pfocr_chemicals_2020_path), sep="\t").rename(
            columns={
                "figure_id": "pfocr_id",
            }
        )
        # TODO: right now, lexicon_alias is either NaN or
        # it's identical to lexicon_term
        # .drop(columns=["lexicon_alias"])
    )

pfocr_chemicals_2020_df
# Out:
#                            pfocr_id matched_ocr_text  lexicon_alias  \
# 0       PMC100003__mb2410470011.jpg         bombesin       Bombesin
# 1       PMC100008__mb2411709009.jpg       Bradykinin     Bradykinin
# 2       PMC100008__mb2411709009.jpg    Isoproterenol  Isoproterenol
# 3       PMC100028__ii1110348001.jpg    Ethanolamines  Ethanolamines
# 4       PMC100028__ii1110348001.jpg      Fatty acids    Fatty Acids
# ...                             ...              ...            ...
# 120257   PMC99957__mb2310813001.jpg          Adenine        Adenine
# 120258   PMC99957__mb2310813001.jpg          Guanine        Guanine
# 120259   PMC99957__mb2310813001.jpg     Hypoxanthine   Hypoxanthine
# 120260   PMC99957__mb2310813011.jpg          Adenine        Adenine
# 120261   PMC99957__mb2310813011.jpg          adenine        Adenine
#
#          lexicon_term lexicon_term_source datasource identifier  \
# 0            Bombesin            pubtator       MESH    D001839
# 1          Bradykinin            pubtator       MESH    D001920
# 2       Isoproterenol            pubtator       MESH    D007545
# 3       Ethanolamines            pubtator       MESH    D004983
# 4         Fatty Acids            pubtator       MESH    D005227
# ...               ...                 ...        ...        ...
# 120257        Adenine            pubtator       MESH    D000225
# 120258        Guanine            pubtator       MESH    D006147
# 120259   Hypoxanthine            pubtator       MESH    D019271
# 120260        Adenine            pubtator       MESH    D000225
# 120261        Adenine            pubtator       MESH    D000225
#
#              annotations  figure_nobe_count  figure_entrez_count
# 0       neurotransmitter                  5                    5
# 1             medication                  8                   52
# 2             medication                  8                   52
# 3                    NaN                  0                    0
# 4                    NaN                  0                    0
# ...                  ...                ...                  ...
# 120257        medication                 10                   10
# 120258               NaN                 10                   10
# 120259               NaN                 10                   10
# 120260        medication                  2                    2
# 120261        medication                  2                    2
#
# [120262 rows x 10 columns]

# %%
pfocr_chemicals_2020_df[
    (
        pfocr_chemicals_2020_df["lexicon_alias"]
        != pfocr_chemicals_2020_df["lexicon_alias"]
    )
]
# Out:
#                            pfocr_id  matched_ocr_text lexicon_alias  \
# 13      PMC101494__ii1000773003.jpg             D-Ala           NaN
# 14      PMC101494__ii1000773003.jpg             L-Ala           NaN
# 25      PMC101920__jb1500344001.jpg               Thr           NaN
# 30         PMC102201__00-0335f8.jpg               Cys           NaN
# 47      PMC102289__pp0516637001.jpg               Phe           NaN
# ...                             ...               ...           ...
# 120159   PMC98962__mr0190007003.jpg             L-Ala           NaN
# 120160   PMC98962__mr0190007003.jpg  UDP MurNAc L-Ala           NaN
# 120161   PMC98962__mr0190007003.jpg             L-Lys           NaN
# 120162   PMC98962__mr0190007003.jpg               Lys           NaN
# 120215   PMC99537__jb1610128005.jpg               Asp           NaN
#
#          lexicon_term lexicon_term_source datasource identifier  \
# 13            Alanine               pfocr       MESH    D000409
# 14            Alanine               pfocr       MESH    D000409
# 25          Threonine               pfocr       MESH    D013912
# 30           Cysteine               pfocr       MESH    D003545
# 47      Phenylalanine               pfocr       MESH    D010649
# ...               ...                 ...        ...        ...
# 120159        Alanine               pfocr       MESH    D000409
# 120160        Alanine               pfocr       MESH    D000409
# 120161         Lysine               pfocr       MESH    D008239
# 120162         Lysine               pfocr       MESH    D008239
# 120215  Aspartic Acid               pfocr       MESH    D001224
#
#                   annotations  figure_nobe_count  figure_entrez_count
# 13      amino_acid|medication                  2                    2
# 14      amino_acid|medication                  2                    2
# 25      amino_acid|medication                  8                    9
# 30      amino_acid|medication                  1                    1
# 47      amino_acid|medication                  0                    0
# ...                       ...                ...                  ...
# 120159  amino_acid|medication                  1                    1
# 120160  amino_acid|medication                  1                    1
# 120161  amino_acid|medication                  1                    1
# 120162  amino_acid|medication                  1                    1
# 120215             amino_acid                 15                   16
#
# [6436 rows x 10 columns]

# %% [markdown]
# Get a normalized (actually just a rough-approximation) list of chemical names from PFOCR:

# %%
not_letters_numbers_re = re.compile("[^a-zA-Z0-9]")


def normalize(t):
    return not_letters_numbers_re.sub("", str(t).casefold())

# %%
pfocr_chemicals_2020 = set(
    pfocr_chemicals_2020_df["matched_ocr_text"].apply(normalize).to_list()
) | set(pfocr_chemicals_2020_df["lexicon_term"].apply(normalize).to_list())
len(pfocr_chemicals_2020)
# Out:
# 15804

# %% [markdown]
# ## CMap Chemicals

# %%
cmap_chemicals_url = (
    "https://www.dropbox.com/s/et5qkgl6gz9p8mn/CMap_Repurposing_Hub.xlsx?dl=1"
)

with tempfile.NamedTemporaryFile(suffix=".xlsx") as f:
    cmap_chemicals_path = f.name
    with requests.get(cmap_chemicals_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)

    cmap_chemicals_df = pd.read_excel(cmap_chemicals_path, sheet_name="Sheet1")

cmap_chemicals_df
# Out:
#                               Name                              MOA  \
# 0              (R)-(-)-apomorphine        dopamine receptor agonist
# 1                 (R)-(-)-rolipram      phosphodiesterase inhibitor
# 2                     (R)-baclofen  benzodiazepine receptor agonist
# 3                 (S)-(+)-rolipram      phosphodiesterase inhibitor
# 4     [sar9,met(o2)11]-substance-p            tachykinin antagonist
# ...                            ...                              ...
# 6793                      8-M-PDOT       melatonin receptor agonist
# 6794                    80841-78-7                              NaN
# 6795               9-aminoacridine                              NaN
# 6796           9-aminocamptothecin          topoisomerase inhibitor
# 6797   9-anthracenecarboxylic-acid                              NaN
#
#                                                  Target          Disease Area  \
# 0     ADRA2A, ADRA2B, ADRA2C, CALY, DRD1, DRD2, DRD3...  neurology/psychiatry
# 1                     PDE4A, PDE4B, PDE4C, PDE4D, PDE5A                   NaN
# 2                                        GABBR1, GABBR2                   NaN
# 3                                          PDE4B, PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                     MTNR1A, MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                        ANO1, CLCN1                   NaN
#
#                Indication                                                 Id  \
# 0     Parkinson's Disease  BRD-K76022557-003-28-9, BRD-K76022557-003-02-7...
# 1                     NaN  BRD-K75516118-001-04-1, BRD-K75516118-001-05-9...
# 2                     NaN     BRD-K62353271-001-04-7, BRD-K62353271-001-02-1
# 3                     NaN  BRD-K65856711-001-05-9, BRD-K65856711-001-03-6...
# 4                     NaN     BRD-K89787693-001-01-1, BRD-K89787693-001-02-9
# ...                   ...                                                ...
# 6793                  NaN     BRD-A07232941-001-03-5, BRD-A07232941-001-02-7
# 6794                  NaN                             BRD-K03044000-001-01-8
# 6795                  NaN  BRD-K00535541-001-04-8, BRD-K00535541-001-05-5...
# 6796                  NaN     BRD-K09291936-001-13-3, BRD-K09291936-001-14-9
# 6797                  NaN     BRD-K62607075-001-04-9, BRD-K62607075-001-03-6
#
#             Phase
# 0        Launched
# 1         Phase 1
# 2         Phase 3
# 3         Phase 1
# 4     Preclinical
# ...           ...
# 6793  Preclinical
# 6794  Preclinical
# 6795  Preclinical
# 6796      Phase 2
# 6797  Preclinical
#
# [6798 rows x 7 columns]

# %%
cmap_chemicals_df["PFOCR"] = (
    cmap_chemicals_df["Name"].apply(normalize).isin(pfocr_chemicals_2020)
)
cmap_chemicals_df
# Out:
#                               Name                              MOA  \
# 0              (R)-(-)-apomorphine        dopamine receptor agonist
# 1                 (R)-(-)-rolipram      phosphodiesterase inhibitor
# 2                     (R)-baclofen  benzodiazepine receptor agonist
# 3                 (S)-(+)-rolipram      phosphodiesterase inhibitor
# 4     [sar9,met(o2)11]-substance-p            tachykinin antagonist
# ...                            ...                              ...
# 6793                      8-M-PDOT       melatonin receptor agonist
# 6794                    80841-78-7                              NaN
# 6795               9-aminoacridine                              NaN
# 6796           9-aminocamptothecin          topoisomerase inhibitor
# 6797   9-anthracenecarboxylic-acid                              NaN
#
#                                                  Target          Disease Area  \
# 0     ADRA2A, ADRA2B, ADRA2C, CALY, DRD1, DRD2, DRD3...  neurology/psychiatry
# 1                     PDE4A, PDE4B, PDE4C, PDE4D, PDE5A                   NaN
# 2                                        GABBR1, GABBR2                   NaN
# 3                                          PDE4B, PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                     MTNR1A, MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                        ANO1, CLCN1                   NaN
#
#                Indication                                                 Id  \
# 0     Parkinson's Disease  BRD-K76022557-003-28-9, BRD-K76022557-003-02-7...
# 1                     NaN  BRD-K75516118-001-04-1, BRD-K75516118-001-05-9...
# 2                     NaN     BRD-K62353271-001-04-7, BRD-K62353271-001-02-1
# 3                     NaN  BRD-K65856711-001-05-9, BRD-K65856711-001-03-6...
# 4                     NaN     BRD-K89787693-001-01-1, BRD-K89787693-001-02-9
# ...                   ...                                                ...
# 6793                  NaN     BRD-A07232941-001-03-5, BRD-A07232941-001-02-7
# 6794                  NaN                             BRD-K03044000-001-01-8
# 6795                  NaN  BRD-K00535541-001-04-8, BRD-K00535541-001-05-5...
# 6796                  NaN     BRD-K09291936-001-13-3, BRD-K09291936-001-14-9
# 6797                  NaN     BRD-K62607075-001-04-9, BRD-K62607075-001-03-6
#
#             Phase  PFOCR
# 0        Launched  False
# 1         Phase 1  False
# 2         Phase 3  False
# 3         Phase 1  False
# 4     Preclinical  False
# ...           ...    ...
# 6793  Preclinical  False
# 6794  Preclinical  False
# 6795  Preclinical  False
# 6796      Phase 2  False
# 6797  Preclinical  False
#
# [6798 rows x 8 columns]

# %% [markdown]
# TODO: I don't know how to export without the index column, so I exported and then opened it in Excel in order to manually delete it. Is there a better way?

# %%
cmap_chemicals_df.to_excel("CMap_Repurposing_Hub.xlsx", sheet_name="Sheet1")

# %% [markdown]
# ## Anke Chemicals

# %%
full_library_chemicals_url = "https://www.dropbox.com/s/taia99vu2tah6cy/Full%20Library%20Gladstone%20%28with%20cpd%20names%29_20171106.xlsx?dl=1"

full_library_chemicals_sheet_name = "Dec2016 fullset copy4 platemaps"

with tempfile.NamedTemporaryFile(suffix=".xlsx") as f:
    full_library_chemicals_path = f.name
    with requests.get(full_library_chemicals_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)

    full_library_chemicals_df = pd.read_excel(
        full_library_chemicals_path,
        sheet_name=full_library_chemicals_sheet_name,
    )

full_library_chemicals_df
# Out:
#        Plate ID  Well  2D barcode Compound ID  conc (mM)  vol (uL)  \
# 0      AD000052  A/01       EMPTY         NaN         10         1
# 1      AD000052  A/02       EMPTY         NaN         10         1
# 2      AD000052  A/03   205064781     GL03080         10         1
# 3      AD000052  A/04   179703632     GL03168         10         1
# 4      AD000052  A/05   207363191     GL03088         10         1
# ...         ...   ...         ...         ...        ...       ...
# 6907  AD0000100  P/20       EMPTY         NaN         10        10
# 6908  AD0000100  P/21  1150964649     GL05462         10        10
# 6909  AD0000100  P/22       EMPTY         NaN         10        10
# 6910  AD0000100  P/23       EMPTY         NaN         10        10
# 6911  AD0000100  P/24       EMPTY         NaN         10        10
#
#              plateset                  compound name
# 0     Full GL library                            NaN
# 1     Full GL library                            NaN
# 2     Full GL library           Bortezomib (Velcade)
# 3     Full GL library                       PLX-4720
# 4     Full GL library  Lapatinib Ditosylate (Tykerb)
# ...               ...                            ...
# 6907  Full GL library                            NaN
# 6908  Full GL library                        KRIBB11
# 6909  Full GL library                            NaN
# 6910  Full GL library                            NaN
# 6911  Full GL library                            NaN
#
# [6912 rows x 8 columns]

# %%
full_library_chemicals_df["PFOCR"] = (
    full_library_chemicals_df["compound name"]
    .apply(normalize)
    .isin(pfocr_chemicals_2020)
)
full_library_chemicals_df
# Out:
#        Plate ID  Well  2D barcode Compound ID  conc (mM)  vol (uL)  \
# 0      AD000052  A/01       EMPTY         NaN         10         1
# 1      AD000052  A/02       EMPTY         NaN         10         1
# 2      AD000052  A/03   205064781     GL03080         10         1
# 3      AD000052  A/04   179703632     GL03168         10         1
# 4      AD000052  A/05   207363191     GL03088         10         1
# ...         ...   ...         ...         ...        ...       ...
# 6907  AD0000100  P/20       EMPTY         NaN         10        10
# 6908  AD0000100  P/21  1150964649     GL05462         10        10
# 6909  AD0000100  P/22       EMPTY         NaN         10        10
# 6910  AD0000100  P/23       EMPTY         NaN         10        10
# 6911  AD0000100  P/24       EMPTY         NaN         10        10
#
#              plateset                  compound name  PFOCR
# 0     Full GL library                            NaN  False
# 1     Full GL library                            NaN  False
# 2     Full GL library           Bortezomib (Velcade)  False
# 3     Full GL library                       PLX-4720   True
# 4     Full GL library  Lapatinib Ditosylate (Tykerb)  False
# ...               ...                            ...    ...
# 6907  Full GL library                            NaN  False
# 6908  Full GL library                        KRIBB11  False
# 6909  Full GL library                            NaN  False
# 6910  Full GL library                            NaN  False
# 6911  Full GL library                            NaN  False
#
# [6912 rows x 9 columns]

# %% [markdown]
# TODO: I don't know how to export without the index column, so I exported and then opened it in Excel in order to manually delete it. Is there a better way?

# %%
full_library_chemicals_df.to_excel(
    "Full Library Gladstone (with cpd names)_20171106_PFOCR.xlsx",
    sheet_name=full_library_chemicals_sheet_name,
)

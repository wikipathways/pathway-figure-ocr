# %%
import json
from io import BytesIO
from pathlib import Path
from zipfile import ZipFile

import numpy as np
import pandas as pd
import requests
import requests_cache

# %%
requests_cache.install_cache("pfocr_cache")

# %%
from functools import partial

import rpy2.robjects as ro
from rpy2.ipython import html
from rpy2.robjects import default_converter, pandas2ri
from rpy2.robjects.conversion import localconverter
from rpy2.robjects.lib.dplyr import DataFrame
from rpy2.robjects.packages import importr

html.html_rdataframe = partial(html.html_rdataframe, table_class="docutils")

# %%
pandas2ri.activate()
base = importr("base")
readRDS = ro.r["readRDS"]
saveRDS = ro.r["saveRDS"]

# %%
def rds2pandas(rds_path):
    r_df = readRDS(str(rds_path))
    with localconverter(ro.default_converter + pandas2ri.converter):
        pandas_df = ro.conversion.rpy2py(r_df)
    return pandas_df

# %%
def pandas2rds(pandas_df, rds_path):
    with localconverter(default_converter + pandas2ri.converter) as cv:
        r_df = DataFrame(pandas_df)

    saveRDS(r_df, str(rds_path))

# %%
current_dir = Path("./")

# %%
latest_pfocr_data_url = (
    "https://www.dropbox.com/sh/nmm0pddamgmu32m/AACCNdFXJrpQRD-EZOPe73RCa?dl=1"
)

zipfile = ZipFile(BytesIO(requests.get(latest_pfocr_data_url).content))
figures_rds_path = current_dir.joinpath("pfocr_figures_draft.rds")
zipfile.extract(str(figures_rds_path))
genes_rds_path = current_dir.joinpath("pfocr_genes_draft.rds")
zipfile.extract(str(genes_rds_path))
chemicals_rds_path = current_dir.joinpath("pfocr_chemicals_draft.rds")
zipfile.extract(str(chemicals_rds_path))
diseases_rds_path = current_dir.joinpath("pfocr_diseases_draft.rds")
zipfile.extract(str(diseases_rds_path))
# Out:
# '/content/pfocr_genes_draft.rds'

# %%
figures_df = rds2pandas(figures_rds_path).rename(
    columns={
        "figid": "pfocr_id",
        "pmcid": "pmc_id",
        "filename": "figure_filename",
        "number": "figure_number",
        "pmc_ranked_result_index": "pmc_search_index",
        "figtitle": "figure_title",
        "papertitle": "paper_title",
        "caption": "figure_caption",
        "figlink": "relative_figure_page_url",
        "reftext": "reference",
        "year": "publication_year",
    }
)
figures_df["paper_url"] = (
    "https://www.ncbi.nlm.nih.gov/pmc/articles/" + figures_df["pmc_id"]
)

figures_df["figure_page_url"] = (
    "https://www.ncbi.nlm.nih.gov" + figures_df["relative_figure_page_url"]
)

figures_df["figure_thumbnail_url"] = (
    "https://www.ncbi.nlm.nih.gov/pmc/articles/"
    + figures_df["pmc_id"]
    + "/bin/"
    + figures_df["figure_filename"]
)

figures_df.drop(
    columns=[
        "figure_filename",
        "relative_figure_page_url",
    ],
    inplace=True,
)

figures_df
# Out:
#                                         pfocr_id figure_number  \
# 1      PMC5732092__cshperspect-CYT-028522_F2.jpg      Figure 2
# 2      PMC5793760__cshperspect-TGF-022210_F4.jpg      Figure 4
# 3      PMC5793761__cshperspect-TGF-031989_F1.jpg      Figure 1
# 4      PMC5830892__cshperspect-CEL-027961_F2.jpg      Figure 2
# 5      PMC5830900__cshperspect-TGF-031997_F1.jpg      Figure 1
# ...                                          ...           ...
# 79945           PMC4216988__zh20221474360006.jpg        Fig. 6
# 79946              PMC2873070__nihms128887f5.jpg      Scheme 1
# 79947       PMC3651446__pnas.1220523110fig06.jpg        Fig. 6
# 79948      PMC6770832__cancers-11-01236-g005.jpg      Figure 5
# 79949  PMC4609065__12885_2015_1721_Fig5_HTML.jpg        Fig. 5
#
#                                           figure_caption      pmc_id  \
# 1      Interleukin (IL)-17RA/RC signaling pathways. I...  PMC5732092
# 2      TGF-β signaling pathways. TGF-βs signal by bin...  PMC5793760
# 3      Bone morphogenetic protein (BMP) signaling pat...  PMC5793761
# 4      FERM-binding partners of Crumbs3. Through its ...  PMC5830892
# 5      Role of the TGF-β family in mammary gland deve...  PMC5830900
# ...                                                  ...         ...
# 79945  Hypothetical mechanism of activation of ENaC b...  PMC4216988
# 79946  A schematic diagram of a proposed working mode...  PMC2873070
# 79947  Models for nucleation of centrosomal and kinet...  PMC3651446
# 79948  A simplified TGFβ pathway leading to p21 expre...  PMC6770832
# 79949  Hypothetical model of EGFR and ANXA3 to fluoro...  PMC4609065
#
#                                              paper_title  \
# 1      Interleukin 17 Family Cytokines: Signaling Mec...
# 2      TGF-β Signaling in Control of Cardiovascular F...
# 3      Bone Morphogenetic Proteins in Vascular Homeos...
# 4                          The Crumbs3 Polarity Protein.
# 5      TGF-β Family Signaling in Ductal Differentiati...
# ...                                                  ...
# 79945  Prostasin interacts with the epithelial Na+ ch...
# 79946  Apolipoprotein E mediates sulfatide depletion ...
# 79947  Aurora kinase inhibitors reveal mechanisms of ...
# 79948  Relevance of Non-Targeted Effects for Radiothe...
# 79949  Construction of possible integrated predictive...
#
#                                                reference pmc_search_index  \
# 1      Leticia Monin, et al. Cold Spring Harb Perspec...            33056
# 2      Marie-José Goumans, et al. Cold Spring Harb Pe...            54906
# 3      Marie-José Goumans, et al. Cold Spring Harb Pe...            13758
# 4      Ben Margolis. Cold Spring Harb Perspect Biol. ...            38670
# 5      Kaoru Kahata, et al. Cold Spring Harb Perspect...            19123
# ...                                                  ...              ...
# 79945  Marcelo D. Carattino, et al. Am J Physiol Rena...           108774
# 79946  Hua Cheng, et al. Neurobiol Aging. ;31(7):1188...           143547
# 79947  Jiun-Ming Wu, et al. Proc Natl Acad Sci U S A....           159643
# 79948  Carmel Mothersill, et al. Cancers (Basel). 201...              618
# 79949    Hiro Takahashi, et al. BMC Cancer. 2015;15:718.            20865
#
#        pathway_score                                       figure_title  \
# 1           0.900423        Interleukin (IL)-17RA/RC signaling pathways
# 2           0.932830                            TGFB signaling pathways
# 3           0.966398  Bone morphogenetic protein (BMP) signaling pat...
# 4           0.693111                   FERM-binding partners of Crumbs3
# 5           0.600142  Role of the TGFB family in mammary gland devel...
# ...              ...                                                ...
# 79945       0.143076  Hypothetical mechanism of activation of ENaC b...
# 79946       0.127176  A schematic diagram of a proposed working mode...
# 79947       0.055546  Models for nucleation of centrosomal and kinet...
# 79948       0.140041  Simplified TGFB pathway leading to p21 expression
# 79949       0.090798  EGFR and ANXA3 to fluoropyrimidine resistance ...
#
#            organism publication_year  \
# 1      Homo sapiens             2018
# 2      Homo sapiens             2018
# 3      Homo sapiens             2018
# 4      Homo sapiens             2018
# 5      Homo sapiens             2018
# ...             ...              ...
# 79945  Homo sapiens             2014
# 79946  Homo sapiens             None
# 79947  Homo sapiens             2013
# 79948  Homo sapiens             2019
# 79949  Homo sapiens             2015
#
#                                                paper_url  \
# 1      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 3      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 4      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 5      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# ...                                                  ...
# 79945  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 79946  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 79947  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 79948  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 79949  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
#
#                                          figure_page_url  \
# 1      https://www.ncbi.nlm.nih.govpmc/articles/PMC57...
# 2      https://www.ncbi.nlm.nih.govpmc/articles/PMC57...
# 3      https://www.ncbi.nlm.nih.govpmc/articles/PMC57...
# 4      https://www.ncbi.nlm.nih.govpmc/articles/PMC58...
# 5      https://www.ncbi.nlm.nih.govpmc/articles/PMC58...
# ...                                                  ...
# 79945  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 79946  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 79947  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 79948  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 79949  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
#
#                                     figure_thumbnail_url
# 1      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 3      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 4      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 5      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# ...                                                  ...
# 79945  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 79946  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 79947  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 79948  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 79949  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
#
# [79949 rows x 14 columns]

# %%
chemicals_df = rds2pandas(chemicals_rds_path)
chemicals_by_pfocr_id = dict()
for pfocr_id, df in chemicals_df[["pfocr_id", "identifier"]].groupby(
    "pfocr_id"
):
    # TODO: could any of these be something other than MESH IDs?
    chemicals_by_pfocr_id[pfocr_id] = set(df["identifier"].dropna())

# %%
diseases_df = rds2pandas(diseases_rds_path)
diseases_by_pfocr_id = dict()
for pfocr_id, df in diseases_df[["pfocr_id", "identifier"]].groupby("pfocr_id"):
    # TODO: could any of these be something other than MESH IDs?
    diseases_by_pfocr_id[pfocr_id] = set(df["identifier"].dropna())

# %%
genes_df = rds2pandas(genes_rds_path).rename(
    columns={
        "figid": "pfocr_id",
        "pmcid": "pmc_id",
        "entrez": "ncbigene_id",
        "word": "matched_ocr_text",
        "symbol": "lexicon_term",
        "source": "lexicon_term_source",
    }
)
genes_by_pfocr_id = dict()
for pfocr_id, df in genes_df[["pfocr_id", "ncbigene_id"]].groupby("pfocr_id"):
    genes_by_pfocr_id[pfocr_id] = set(df["ncbigene_id"].dropna())

# %% [markdown]
# ## Export
#
# https://github.com/wikipathways/pathway-figure-ocr/issues/16#issuecomment-1075574192
# ```json
# {
#   "_id": "PMC0000000__nihm00000000",
#   "associatedWith": {
#     "title": "signaling in immune response",
#     "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC0000000/bin/nihm00000000.jpg",
#     "pmc": "PMC0000000",
#     "pubmed": "00000000",
#     "mentions": {
#         "diseases": {
#               "mesh": ["D000860", "D000333"]
#         },
#         "chemicals": {
#                "mesh": ["D0001", "D00002"]
#         },
#         "genes": {
#                "ncbigene": ["1234", "2345"]
#         }
#      }
# }
# ```

# %%
# https://stackoverflow.com/a/8230505/5354298
class SetEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, set):
            return list(obj)
        return json.JSONEncoder.default(self, obj)


export_dir = current_dir.joinpath("export")
if not export_dir.exists():
    export_dir.mkdir()

with open(export_dir.joinpath("bte_chemicals_diseases_genes.ndjson"), "w") as f:
    for i, row in figures_df.iterrows():
        pfocr_id = row["pfocr_id"]

        chemicals = chemicals_by_pfocr_id.get(pfocr_id, set())
        diseases = diseases_by_pfocr_id.get(pfocr_id, set())
        genes = genes_by_pfocr_id.get(pfocr_id, set())

        if chemicals or diseases or genes:
            f.write(
                json.dumps(
                    {
                        "_id": pfocr_id,
                        "associatedWith": {
                            "title": row["figure_title"],
                            "figureUrl": row["figure_thumbnail_url"],
                            "pmc": row["pmc_id"],
                            # "pubmed": "",
                            "mentions": {
                                "chemicals": {"mesh": chemicals},
                                "diseases": {"mesh": diseases},
                                "genes": {"ncbigene": genes},
                            },
                        },
                    },
                    cls=SetEncoder,
                )
            )

            f.write("\n")

# %%
# !head export/bte_chemicals_diseases_genes.ndjson
# Out:
# {"_id": "PMC5732092__cshperspect-CYT-028522_F2.jpg", "associatedWith": {"title": "Interleukin (IL)-17RA/RC signaling pathways", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5732092/bin/cshperspect-CYT-028522_F2.jpg", "pmc": "PMC5732092", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["84818", "5196", "10131", "7188", "6387", "4791", "1994", "4283", "2920", "6426", "5966", "5473", "4117", "1432", "7189", "6374", "7186", "6300", "5594", "3627", "2919", "3326", "1051", "5601", "4790", "10758", "5603", "6373", "10563", "5600", "3576", "23765", "2921", "5602", "3605", "5971", "6372", "5599", "9547", "5595", "112744", "7184", "5970"]}}}}
# {"_id": "PMC5793760__cshperspect-TGF-022210_F4.jpg", "associatedWith": {"title": "TGFB signaling pathways", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5793760/bin/cshperspect-TGF-022210_F4.jpg", "pmc": "PMC5793760", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["658", "7040", "650", "4088", "657", "7042", "4090", "652", "392255", "27302", "659", "656", "2658", "8200", "4089", "649", "7043", "654", "651", "653", "9210", "4087", "4086", "353500", "7048", "90", "9573", "6498", "7046", "655", "2657", "151449"]}}}}
# {"_id": "PMC5793761__cshperspect-TGF-031989_F1.jpg", "associatedWith": {"title": "Bone morphogenetic protein (BMP) signaling pathway", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5793761/bin/cshperspect-TGF-031989_F1.jpg", "pmc": "PMC5793761", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["658", "650", "657", "4090", "652", "392255", "25805", "4117", "2077", "27302", "1432", "659", "656", "5594", "4093", "64750", "2658", "8200", "168667", "4091", "4089", "649", "57154", "654", "5601", "651", "653", "56963", "9210", "5603", "4086", "5600", "4035", "353500", "5602", "6445", "90", "9573", "4256", "5599", "5595", "4092", "655", "6300", "2657", "151449"]}}}}
# {"_id": "PMC5830892__cshperspect-CEL-027961_F2.jpg", "associatedWith": {"title": "FERM-binding partners of Crumbs3", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5830892/bin/cshperspect-CEL-027961_F2.jpg", "pmc": "PMC5830892", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["71", "59", "58", "2119", "72", "70", "55249", "60"]}}}}
# {"_id": "PMC5830900__cshperspect-TGF-031997_F1.jpg", "associatedWith": {"title": "Role of the TGFB family in mammary gland development and maturation", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5830900/bin/cshperspect-TGF-031997_F1.jpg", "pmc": "PMC5830900", "mentions": {"chemicals": {"mesh": ["D011374"]}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["6776", "7040", "650", "6777", "4088", "7042", "4090", "3082", "652", "392255", "3479", "27302", "4488", "656", "3625", "4093", "2658", "8200", "4091", "4089", "649", "7043", "3624", "654", "651", "653", "9210", "4086", "4087", "353500", "9573", "6498", "4092", "655", "2657", "151449"]}}}}
# {"_id": "PMC5843509__nihms906417f3.jpg", "associatedWith": {"title": "Design Principles of Electrical Synaptic Plasticity", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5843509/bin/nihms906417f3.jpg", "pmc": "PMC5843509", "mentions": {"chemicals": {"mesh": ["D018350", "D004298", "D002118", "C094686"]}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["109", "111", "114", "889", "113", "112", "5493", "613", "115", "196883", "108", "9735", "55811", "107", "816", "8740", "57369"]}}}}
# {"_id": "PMC5880173__cshperspect-TGF-022327_F1.jpg", "associatedWith": {"title": "Bone morphogenetic protein (BMP) pathway and potential strategies for therapeutic modulation", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5880173/bin/cshperspect-TGF-022327_F1.jpg", "pmc": "PMC5880173", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["650", "657", "5293", "10000", "652", "4090", "392255", "5291", "1432", "27302", "659", "656", "6300", "5594", "8503", "4093", "2658", "8200", "4089", "649", "654", "30849", "651", "5294", "653", "5603", "9210", "23533", "5600", "4086", "353500", "207", "208", "146850", "5602", "90", "9573", "5599", "5290", "5595", "92", "655", "5601", "2657", "151449"]}}}}
# {"_id": "PMC5920792__nihms917800f1.jpg", "associatedWith": {"title": "Feedback Regulation of RTK Signaling in Development", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5920792/bin/nihms917800f1.jpg", "pmc": "PMC5920792", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["2261", "54756", "2260", "53834", "2264", "23767", "2263"]}}}}
# {"_id": "PMC5920792__nihms917800f2.jpg", "associatedWith": {"title": "Feedback Regulation of RTK Signaling in Development", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5920792/bin/nihms917800f2.jpg", "pmc": "PMC5920792", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": []}, "genes": {"ncbigene": ["2885", "1846", "3845", "3265", "4893", "5293", "10000", "6903", "5291", "5605", "5604", "5728", "10252", "1431", "161742", "8503", "5594", "5781", "10251", "81848", "5037", "1844", "30849", "5294", "10253", "369", "1843", "23533", "6654", "6655", "5894", "207", "146850", "208", "1845", "1848", "399473", "5290", "5595", "2475", "673", "200734", "1847"]}}}}
# {"_id": "PMC5920792__nihms917800f3.jpg", "associatedWith": {"title": "Feedback Regulation of RTK Signaling in Development", "figureUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5920792/bin/nihms917800f3.jpg", "pmc": "PMC5920792", "mentions": {"chemicals": {"mesh": []}, "diseases": {"mesh": ["C000656865"]}, "genes": {"ncbigene": ["867", "60495", "23327", "1154", "4734"]}}}}

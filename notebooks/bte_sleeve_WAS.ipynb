# %% [raw]
# !pip install numpy pandas requests requests_cache SetSimilaritySearch

# %%
from copy import copy
import json
import pandas as pd
import textwrap

# %% [markdown]
# # BTE Sleeve
#
# Some queries result in an explosion of the number of results. This is bad for performance of the server and also not very useful to the user. This notebook explores using PFOCR as a "compression sleeve" to dampen these types of explosions. I don't have a CC-licensed image of a compression sleeve, so instead here's an image of a heat-shrink tube.
#
# <a title="oomlout, CC BY-SA 2.0 &lt;https://creativecommons.org/licenses/by-sa/2.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:HESH-06-L-STAN-01_(9601242883).jpg"><img width="512" alt="HESH-06-L-STAN-01 (9601242883)" src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/HESH-06-L-STAN-01_%289601242883%29.jpg/512px-HESH-06-L-STAN-01_%289601242883%29.jpg"></a>
#
# Let's try BTE Sleeve on the test query [A.2_RHOBTB2_twohop](https://github.com/NCATSTranslator/minihackathons/blob/main/2021-12_demo/workflowA/A.2_RHOBTB2_twohop.json):
#
# `RHOBTB2 Gene`--entity_regulates_entity|genetically_interacts_with--`Any Gene`--related_to--`Any SmallMolecule`
#
# `n0`--e01--`n1`--e02--`n2`
#
#
# Note BTE Sleeve currently only works on queries with nodes of categories supported by PFOCR, e.g., `biolink:Gene`, `biolink:SmallMolecule`, `biolink:Disease`. TODO: update the Fisher's Exact test to work with node categories not in PFOCR.
#
# Also, BTE Sleeve currently assumes `n0` has an `ids` parameter. TODO: update to handle `ids` params on any q_node.

# %%
import requests
import requests_cache


requests_cache.install_cache("pfocr_cache", allowable_methods=['GET', 'POST'])

# %% [markdown]
# ## Get BTE TRAPI Results

# %%
query = {
    "message": {
        "query_graph": {
            "edges": {
                "e01": {
                    "object": "n0",
                    "subject": "n1",
                    "predicates": [
                        "biolink:entity_regulates_entity",
                        "biolink:genetically_interacts_with"
                    ]
                },
                "e02": {
                    "object": "n1",
                    "subject": "n2",
                    "predicates": [
                        "biolink:related_to"
                    ]
                }
            },
            "nodes": {
                "n0": {
                    "ids": [
                        "NCBIGene:7454"
                    ],
                    "categories": [
                        "biolink:Gene"
                    ]
                },
                "n1": {
                    "categories": [
                        "biolink:Gene"
                    ],
                },
                "n2": {
                    "categories": [
                        "biolink:SmallMolecule"
                    ]
                }
            }
        }
    }
}

trapi_response = requests.post("http://localhost:3000/v1/query", json=query)
#trapi_response = requests.post("https://api.bte.ncats.io/v1/query", json=query)
#trapi_response = requests.post("https://arax.ncats.io/api/rtxkg2/v1.2/query", json=query)
#trapi_response = requests.post("https://arax.ncats.io/api/arax/v1.2/query", json=query)
print(trapi_response.status_code)
if trapi_response.status_code != 200:
    print(trapi_response.text)
if trapi_response.from_cache:
    print(f"got response from cache")

trapi_message = trapi_response.json()["message"]

#print(json.dumps(query))
# Out:
# 200
# got response from cache

# %%
# note we're also including any categories from the results
curie_categories = set()
for v in  query["message"]["query_graph"]["nodes"].values():
    if "categories" in v:
        for category in v["categories"]:
            curie_categories.add(category)

# %%
# for genes/gene products, chemicals and diseases
preferred_prefixes = set(["NCBIGene", "MESH"])
unified_names = set()
unified_curies = set()
unification_failed_curies = set()
unified_prefixes = set()
all_prefixes = set()
curie_to_name = dict()
curie_to_unified_curie = dict()
for k, v in trapi_message["knowledge_graph"]["nodes"].items():
    name = v["name"]
    for category in v["categories"]:
        curie_categories.add(category)
        
    for a in v["attributes"]:
        if a["attribute_type_id"] == "biolink:xref":
            curies = a["value"]
            
            # k should always be one of the curies
            if not k in curies:
                raise Exception(f"key {k} not in {curies}")
            
            unified_curie = None
            intersecting_unified_curies = unified_curies.intersection(set(curies))
            if len(intersecting_unified_curies) > 1:
                raise Exception(f"matching multiple: {k} to {list(intersecting_unified_curies)}")
            elif len(intersecting_unified_curies) == 1:
                unified_curie = list(intersecting_unified_curies)[0]
            else:
                # get curie for preferred prefix. usually this is k, but not always.
                for curie in curies:
                    [prefix, identifier] = curie.split(":")
                    if prefix in preferred_prefixes:
                        unified_curie = curie
                        unified_curies.add(unified_curie)
                        break
                        
            if not unified_curie:
                if k in curie_to_unified_curie:
                    unified_curie = curie_to_unified_curie[k]
                else:
                    unification_failed_curies.add(k)
                    break
                    
                #raise Exception(f"failed to find a unified curie for {k} in {curies}")
                
            [unified_prefix, unified_identifier] = unified_curie.split(":")
            unified_prefixes.add(unified_prefix)
            
            for curie in curies:
                [prefix, identifier] = curie.split(":")
                all_prefixes.add(prefix)
                if not curie in curie_to_unified_curie:
                    curie_to_unified_curie[curie] = unified_curie
                if not curie in curie_to_name:
                    curie_to_name[curie] = name
                    unified_names.add(name)
                elif curie_to_name[curie] != name:
                    print(f"curie {curie} has multiple primary names: {curie_to_name[curie]} and {name}")
                    #raise Exception(f"curie{curie} has multiple names: {curie_to_name[curie]} and {name}")


print(f'curie_categories: {curie_categories}')
print("")
print(f"curie_to_name key count: {len(curie_to_name.keys())}")
print(f"curie_to_unified_curie key count: {len(curie_to_unified_curie.keys())}")
print("")
print("all curie prefixes found:")
print(all_prefixes)
print("")
print("unified curie prefixes found:")
print(unified_prefixes)
print("")
print(f"failed to unify {len(unification_failed_curies)} curies")
# Out:
# curie UMLS:C0010592 has multiple primary names: Cyclosporin A and Cyclosporine
# curie UMLS:C0086135 has multiple primary names: Desmopressin and Desmopressin Acetate
# curie UMLS:C0021641 has multiple primary names: Iletin and Insulin
# curie UMLS:C0003779 has multiple primary names: Desmopressin and Argipressin
# curie UMLS:C0245109 has multiple primary names: Anakinra and anakinra
# curie_categories: {'biolink:Gene', 'biolink:MolecularMixture', 'biolink:Polypeptide', 'biolink:PhenotypicFeature', 'biolink:SmallMolecule', 'biolink:ComplexMolecularMixture', 'biolink:Protein', 'biolink:ChemicalEntity'}
#
# curie_to_name key count: 36205
# curie_to_unified_curie key count: 36205
#
# all curie prefixes found:
# {'CAS', 'KEGG.COMPOUND', 'DRUGBANK', 'PR', 'GTOPDB', 'NCBIGene', 'ENSEMBL', 'OMIM', 'HMDB', 'CHEBI', 'INCHIKEY', 'UNII', 'HGNC', 'MESH', 'UniProtKB', 'CHEMBL.COMPOUND', 'DrugCentral', 'PUBCHEM.COMPOUND', 'UMLS'}
#
# unified curie prefixes found:
# {'NCBIGene', 'MESH'}
#
# failed to unify 5616 curies

# %%
columns = []
q_node_id_keys = set(["object", "subject"])
q_node_ids = []
q_edge_ids = []
for q_edge_id,edge_v in query["message"]["query_graph"]["edges"].items():
    q_edge_ids.append(q_edge_id)
    q_node_id_found = False
    for k,v in edge_v.items():
        if (k in q_node_id_keys) and (type(v) is str):
            if v not in columns:
                q_node_ids.append(v)
                columns.append(v)
            if not q_node_id_found:
                q_node_id_found = True
                columns.append(q_edge_id)
                
for q_node_id in q_node_ids:
    columns.append(f"{q_node_id}_curie")
    columns.append(f"{q_node_id}_unified_curie")
    
columns.append("trapi_result_curie_combo")
    
print(columns)
print(q_node_ids)
print(q_edge_ids)
# Out:
# ['n0', 'e01', 'n1', 'e02', 'n2', 'n0_curie', 'n0_unified_curie', 'n1_curie', 'n1_unified_curie', 'n2_curie', 'n2_unified_curie', 'trapi_result_curie_combo']
# ['n0', 'n1', 'n2']
# ['e01', 'e02']

# %%
trapi_result_columns = []
for i in range(len(q_node_ids)):
    trapi_result_columns.append(q_node_ids[i])
    if i < len(q_edge_ids):
        trapi_result_columns.append(q_edge_ids[i])
print(trapi_result_columns)
# Out:
# ['n0', 'e01', 'n1', 'e02', 'n2']

# %%
from copy import deepcopy


trapi_results = trapi_message["results"]

result_row_data = []
for trapi_result in trapi_results:
    curie_to_qnode_ids = dict()
    for qnode_id, entries in trapi_result["node_bindings"].items():
        for entry in entries:
            curie = entry["id"]
            if curie not in curie_to_qnode_ids:
                curie_to_qnode_ids[curie] = []
            curie_to_qnode_ids[curie].append(qnode_id)
        
    row_data_template = dict()
    q_edge_id_to_predicates = dict()
    trapi_result_curies = set()
    for qedge_id, entries in trapi_result["edge_bindings"].items():
        for entry in entries:
            curie = entry["id"]
            kg_entry = trapi_message["knowledge_graph"]["edges"][curie]
            subject_curie = kg_entry["subject"]
            object_curie = kg_entry["object"]
            predicate_curie = kg_entry["predicate"]
            [predicate_prefix, predicate_identifier] = predicate_curie.split(":")
            
            if qedge_id not in q_edge_id_to_predicates:
                q_edge_id_to_predicates[qedge_id] = set()
            q_edge_id_to_predicates[qedge_id].add(predicate_identifier)

            for curie in [subject_curie, object_curie]:
                for qnode_id in curie_to_qnode_ids[curie]:
                    if curie in curie_to_unified_curie:
                        unified_curie = curie_to_unified_curie[curie]
                    else:
                        break

                    name = curie_to_name[curie]
                    row_data_template[qnode_id] = name

                    trapi_result_curies.add(unified_curie)
                    row_data_template[qnode_id + "_curie"] = curie
                    row_data_template[qnode_id + "_unified_curie"] = unified_curie
                    
    if len(trapi_result_curies) != len(q_node_ids):
        #print(f'skipping {list(curie_to_qnode_ids.keys())}')
        continue
        
    row_data_template["trapi_result_curie_combo"] = tuple(sorted(trapi_result_curies))
    q_edge_ids_processed = set()
    row_datas = [row_data_template]
    for q_edge_id,predicates in q_edge_id_to_predicates.items():
        next_row_datas = []
        for row_data in row_datas:
            for predicate in predicates:
                next_row_data = deepcopy(row_data)
                next_row_data[q_edge_id] = predicate
                next_row_datas.append(
                    next_row_data 
                )
        row_datas = next_row_datas
    result_row_data += row_datas
        
print("warning: predicate direction(s) may be switched")
results_df = pd.DataFrame.from_records(result_row_data, columns=columns).drop_duplicates()
results_df
# Out:
# warning: predicate direction(s) may be switched
#         n0                                 e01     n1  \
# 0      WAS  entity_positively_regulates_entity   MANF
# 1      WAS  entity_positively_regulates_entity   MANF
# 2      WAS  entity_positively_regulates_entity   MANF
# 3      WAS  entity_positively_regulates_entity   MANF
# 4      WAS  entity_positively_regulates_entity   MANF
# ...    ...                                 ...    ...
# 35263  WAS          genetically_interacts_with  ASB15
# 35264  WAS          genetically_interacts_with  ASB15
# 35265  WAS          genetically_interacts_with  ASB15
# 35266  WAS          genetically_interacts_with  ASB15
# 35267  WAS          genetically_interacts_with  ASB15
#
#                                       e02  \
# 0                 increases_expression_of
# 1      entity_positively_regulates_entity
# 2              resistance_associated_with
# 3      entity_negatively_regulates_entity
# 4      entity_negatively_regulates_entity
# ...                                   ...
# 35263          resistance_associated_with
# 35264          resistance_associated_with
# 35265          resistance_associated_with
# 35266                             part_of
# 35267                             part_of
#
#                                                       n2       n0_curie  \
# 0      (E)-N-[(2R,3R,4R,5R,6R)-2-[(2R,3R,4R,5S,6R)-3-...  NCBIGene:7454
# 1      (E)-N-[(2R,3R,4R,5R,6R)-2-[(2R,3R,4R,5S,6R)-3-...  NCBIGene:7454
# 2                                              Tretinoin  NCBIGene:7454
# 3                                              Tretinoin  NCBIGene:7454
# 4                                             Diclofenac  NCBIGene:7454
# ...                                                  ...            ...
# 35263                                          Pelitinib  NCBIGene:7454
# 35264  2-(4-(Benzo[d][1,3]dioxol-5-yl)-2-tert-butyl-1...  NCBIGene:7454
# 35265                                          Linifanib  NCBIGene:7454
# 35266                           Early Promoters, Genetic  NCBIGene:7454
# 35267                                 5' Flanking Region  NCBIGene:7454
#
#       n0_unified_curie         n1_curie n1_unified_curie  \
# 0        NCBIGene:7454    NCBIGene:7873    NCBIGene:7873
# 1        NCBIGene:7454    NCBIGene:7873    NCBIGene:7873
# 2        NCBIGene:7454    NCBIGene:7873    NCBIGene:7873
# 3        NCBIGene:7454    NCBIGene:7873    NCBIGene:7873
# 4        NCBIGene:7454    NCBIGene:7873    NCBIGene:7873
# ...                ...              ...              ...
# 35263    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 35264    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 35265    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 35266    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 35267    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
#
#                         n2_curie n2_unified_curie  \
# 0       PUBCHEM.COMPOUND:5282055     MESH:D014415
# 1       PUBCHEM.COMPOUND:5282055     MESH:D014415
# 2        PUBCHEM.COMPOUND:444795     MESH:D014212
# 3        PUBCHEM.COMPOUND:444795     MESH:D014212
# 4          PUBCHEM.COMPOUND:3033     MESH:D004008
# ...                          ...              ...
# 35263   PUBCHEM.COMPOUND:6445562     MESH:C413879
# 35264   PUBCHEM.COMPOUND:9858940     MESH:C519132
# 35265  PUBCHEM.COMPOUND:11485656     MESH:C513486
# 35266              UMLS:C0013462     MESH:D011401
# 35267              UMLS:C0949645     MESH:D024506
#
#                              trapi_result_curie_combo
# 0        (MESH:D014415, NCBIGene:7454, NCBIGene:7873)
# 1        (MESH:D014415, NCBIGene:7454, NCBIGene:7873)
# 2        (MESH:D014212, NCBIGene:7454, NCBIGene:7873)
# 3        (MESH:D014212, NCBIGene:7454, NCBIGene:7873)
# 4        (MESH:D004008, NCBIGene:7454, NCBIGene:7873)
# ...                                               ...
# 35263  (MESH:C413879, NCBIGene:142685, NCBIGene:7454)
# 35264  (MESH:C519132, NCBIGene:142685, NCBIGene:7454)
# 35265  (MESH:C513486, NCBIGene:142685, NCBIGene:7454)
# 35266  (MESH:D011401, NCBIGene:142685, NCBIGene:7454)
# 35267  (MESH:D024506, NCBIGene:142685, NCBIGene:7454)
#
# [35268 rows x 12 columns]

# %%
for q_node_id in q_node_ids:
    print(len(set(results_df[q_node_id])))
# Out:
# 1
# 101
# 3248

# %%
len(set(results_df["trapi_result_curie_combo"]))
# Out:
# 22366

# %% [markdown]
# Total results count (excluding any that couldn't be unified): 3,738. That's too many for a researcher to efficiently go through manually, so let's try filtering to make that more manageable.

# %% [markdown]
# ## Match up BTE TRAPI Results & PFOCR
#
# We're going to try using PFOCR to filter and prioritize the results.
#
# First we need to get the PFOCR Data. We could get it from the API, but for now, we'll just go ahead and download the entire JSON file we gave to BTE.

# %%
pfocr_url = "https://www.dropbox.com/s/1f14t5zaseocyg6/bte_chemicals_diseases_genes.ndjson?dl=1"
pfocr_request = requests.get(pfocr_url)
print(f"status_code: {pfocr_request.status_code}")
if pfocr_request.status_code != 200:
    print(pfocr_request.text)
# Out:
# status_code: 200

# %%
curies_to_figure_ids = {}
figure_id_to_curies = {}
figure_id_to_pfocr_result = {}
for line in pfocr_request.text.splitlines():
    pfocr_result = json.loads(line)
    figure_id = pfocr_result["_id"]

    curies = set()
    for identifier in pfocr_result["associatedWith"]["mentions"]["chemicals"]["mesh"]:
        curie = "MESH:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)
    for identifier in pfocr_result["associatedWith"]["mentions"]["diseases"]["mesh"]:
        curie = "MESH:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)
    for identifier in pfocr_result["associatedWith"]["mentions"]["genes"]["ncbigene"]:
        curie = "NCBIGene:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)

    figure_id_to_pfocr_result[figure_id] = pfocr_result
    figure_id_to_curies[figure_id] = curies

    curies_key = tuple(sorted(curies))
    if curies_key not in curies_to_figure_ids:
        curies_to_figure_ids[curies_key] = []
    curies_to_figure_ids[curies_key].append(figure_id)

# %%
from SetSimilaritySearch import SearchIndex

# the reference sets are supposed to be from PFOCR only
reference_sets = list()
for curies in set(curies_to_figure_ids.keys()):
    reference_sets.append(set(curies))
# but in order to calculate the scores correctly,
# the SetSimilaritySearch library requires that
# every curie from the bte results need to be
# mentioned at least once in the reference set.
# That's the only reason we add them below, as
# one large set.

unified_curie_columns = [
    q_node_id + "_unified_curie" for q_node_id in q_node_ids
]

trapi_result_curie_combos = set()
for i, df in results_df[unified_curie_columns].drop_duplicates().iterrows():
    trapi_result_curies = []
    for unified_curie_column in unified_curie_columns:
        trapi_result_curies.append(
            df[unified_curie_column]
        )
    trapi_result_curie_combos.add(tuple(sorted(
        trapi_result_curies
    )))
    
reference_set = set()
for trapi_result_curie_combo in trapi_result_curie_combos:
    reference_set |= set(trapi_result_curie_combo)
reference_sets.append(reference_set)

matchable_node_min = 2
matchable_node_count = len(q_node_ids)
index = SearchIndex(reference_sets, similarity_func_name="containment", 
    similarity_threshold=matchable_node_min/matchable_node_count)

trapi_figure_overlap_rows = []
for trapi_result_curie_combo in trapi_result_curie_combos:
    trapi_curies = set(trapi_result_curie_combo)
    results = index.query(trapi_curies)
    for result in results:
        figure_curie_combos = reference_sets[result[0]]
        figure_curie_key = tuple(sorted(figure_curie_combos))
        
        # needed to not match bte results to themselves
        if figure_curie_key in curies_to_figure_ids:
            figure_ids = curies_to_figure_ids[figure_curie_key]
        else:
            continue
            
        score = result[1]
        
        common_curies = trapi_curies.intersection(figure_curie_combos)
        for figure_id in figure_ids:
            pfocr_result = figure_id_to_pfocr_result[figure_id]
            trapi_figure_overlap_rows.append({
                "figure_id": figure_id,
                "figure_url": pfocr_result["associatedWith"]["figureUrl"],
                "figure_title": pfocr_result["associatedWith"]["title"],
                "trapi_result_curie_combo": trapi_result_curie_combo,
                "figure_curie_combo": figure_curie_key,
                "overlap_curie_combo": tuple(sorted(common_curies)),
                "score": score,
            })


trapi_figure_overlap_df = pd.DataFrame.from_records(trapi_figure_overlap_rows)
trapi_figure_overlap_df
# Out:
#                                      figure_id  \
# 0             PMC4662426__bbi-9-2015-153f5.jpg
# 1           PMC3328896__CDI2012-692639.002.jpg
# 2                PMC2944409__nihms233031f6.jpg
# 3                          PMC3988951__gr6.jpg
# 4              PMC7525051__acmi-2-082-g005.jpg
# ...                                        ...
# 351365   PMC6620384__bsr-39-bsr20190513-g1.jpg
# 351366  PMC4762141__41048_2015_5_Fig5_HTML.jpg
# 351367        PMC4597143__zjw0101551330004.jpg
# 351368           PMC3603002__nihms207342f6.jpg
# 351369      PMC6862015__ijms-20-05517-g005.jpg
#
#                                                figure_url  \
# 0       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 1       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 2       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 3       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 4       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# ...                                                   ...
# 351365  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 351366  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 351367  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 351368  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 351369  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                              figure_title  \
# 0       Difference in expression of the calcium signal...
# 1       Cbl-b functions as central gate keeper of T-ce...
# 2       Calcium Signaling Pathway (KEGG, Kanehisa Labo...
# 3       Insights into TREM2-related signaling using da...
# 4       Chemokine signalling (KEGG) pathway regulation...
# ...                                                   ...
# 351365  Regulatory mechanisms of Robo4 and their effec...
# 351366  Different gene expressions in regulation of ac...
# 351367      Quantification of the full chemotaxis pathway
# 351368  T cell signaling pathways and protein phosphor...
# 351369               Complement lectin pathway activation
#
#                                trapi_result_curie_combo  \
# 0          (MESH:D002166, NCBIGene:5335, NCBIGene:7454)
# 1          (MESH:D002166, NCBIGene:5335, NCBIGene:7454)
# 2          (MESH:D002166, NCBIGene:5335, NCBIGene:7454)
# 3          (MESH:D002166, NCBIGene:5335, NCBIGene:7454)
# 4          (MESH:D002166, NCBIGene:5335, NCBIGene:7454)
# ...                                                 ...
# 351365    (MESH:C516969, NCBIGene:28964, NCBIGene:7454)
# 351366    (MESH:C516969, NCBIGene:28964, NCBIGene:7454)
# 351367    (MESH:C516969, NCBIGene:28964, NCBIGene:7454)
# 351368    (MESH:C520365, NCBIGene:50618, NCBIGene:7454)
# 351369  (MESH:C000625785, NCBIGene:1311, NCBIGene:7454)
#
#                                        figure_curie_combo  \
# 0       (MESH:C024376, MESH:D000275, MESH:D002118, MES...
# 1       (MESH:D017260, NCBIGene:10000, NCBIGene:10725,...
# 2       (MESH:C024376, MESH:D000255, MESH:D002118, MES...
# 3       (NCBIGene:1072, NCBIGene:1073, NCBIGene:10766,...
# 4       (MESH:D000249, NCBIGene:107, NCBIGene:108, NCB...
# ...                                                   ...
# 351365  (MESH:C516025, NCBIGene:146850, NCBIGene:2321,...
# 351366  (MESH:C035086, MESH:C043055, MESH:C113338, MES...
# 351367  (MESH:D014001, NCBIGene:10000, NCBIGene:10152,...
# 351368  (NCBIGene:10451, NCBIGene:10725, NCBIGene:1432...
# 351369  (MESH:C050928, MESH:C051905, MESH:C489165, NCB...
#
#                     overlap_curie_combo     score
# 0        (NCBIGene:5335, NCBIGene:7454)  0.666667
# 1        (NCBIGene:5335, NCBIGene:7454)  0.666667
# 2        (NCBIGene:5335, NCBIGene:7454)  0.666667
# 3        (NCBIGene:5335, NCBIGene:7454)  0.666667
# 4        (NCBIGene:5335, NCBIGene:7454)  0.666667
# ...                                 ...       ...
# 351365  (NCBIGene:28964, NCBIGene:7454)  0.666667
# 351366  (NCBIGene:28964, NCBIGene:7454)  0.666667
# 351367  (NCBIGene:28964, NCBIGene:7454)  0.666667
# 351368  (NCBIGene:50618, NCBIGene:7454)  0.666667
# 351369   (NCBIGene:1311, NCBIGene:7454)  0.666667
#
# [351370 rows x 7 columns]

# %%
print(len(set(
    trapi_figure_overlap_df[trapi_figure_overlap_df["overlap_curie_combo"].map(len) >= 2]["trapi_result_curie_combo"]
)))
print(len(set(
    trapi_figure_overlap_df[trapi_figure_overlap_df["overlap_curie_combo"].map(len) >= 3]["trapi_result_curie_combo"]
)))
print(len(set(
    trapi_figure_overlap_df[trapi_figure_overlap_df["overlap_curie_combo"].map(len) >= 4]["trapi_result_curie_combo"]
)))
print(len(set(trapi_figure_overlap_df["figure_id"])))
# Out:
# 16179
# 139
# 0
# 11723

# %% [markdown]
# ### trapi_curie_combo_count_by_figure_df

# %%
trapi_curie_combo_count_by_figure_df = trapi_figure_overlap_df[["figure_id", "trapi_result_curie_combo"]].rename(columns={
    "trapi_result_curie_combo": "trapi_curie_combo_count"
}).groupby("figure_id").count().sort_values(
    by="trapi_curie_combo_count", ascending=False)
trapi_curie_combo_count_by_figure_df
# Out:
#                                            trapi_curie_combo_count
# figure_id
# PMC2642659__zpq9990969120002.jpg                              6944
# PMC4538774__BMRI2015-949514.004.jpg                           6384
# PMC7263378__nihms-1585779-f0004.jpg                           6182
# PMC5501852__41598_2017_5280_Fig6_HTML.jpg                     6056
# PMC5118094__nihms825299f7.jpg                                 5163
# ...                                                            ...
# PMC4909440__kmco-03-03-1160174-g001.jpg                          1
# PMC4908701__12014_2016_9114_Fig5_HTML.jpg                        1
# PMC4907806__nihms770844f3.jpg                                    1
# PMC4905575__nihms791846f5.jpg                                    1
# PMC99013__mr0400030005.jpg                                       1
#
# [11723 rows x 1 columns]

# %% [markdown]
# ### figure count/score by trapi curie combo

# %%
trapi_figure_overlap_df[["trapi_result_curie_combo", "figure_id"]].rename(columns={
    "figure_id": "figure_count"
}).groupby("trapi_result_curie_combo").count().sort_values(
    by="figure_count", ascending=False).head(10)
# Out:
#                                                figure_count
# trapi_result_curie_combo
# (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)          2774
# (MESH:D002118, NCBIGene:5595, NCBIGene:7454)           1161
# (MESH:D002118, NCBIGene:5335, NCBIGene:7454)            928
# (NCBIGene:1950, NCBIGene:1956, NCBIGene:7454)           777
# (MESH:D002118, NCBIGene:207, NCBIGene:7454)             762
# (MESH:D000255, NCBIGene:207, NCBIGene:7454)             622
# (NCBIGene:7040, NCBIGene:7124, NCBIGene:7454)           620
# (NCBIGene:1956, NCBIGene:2064, NCBIGene:7454)           556
# (MESH:D020123, NCBIGene:207, NCBIGene:7454)             478
# (MESH:D012694, NCBIGene:207, NCBIGene:7454)             365

# %%
trapi_result_figure_score_df = trapi_figure_overlap_df[["trapi_result_curie_combo", "score"]].rename(
    columns={"score": "cumulative_trapi_result_curie_combo_figure_score"}
).groupby("trapi_result_curie_combo").sum().sort_values(
    by="cumulative_trapi_result_curie_combo_figure_score", ascending=False)
trapi_result_figure_score_df.head(10)
# Out:
#                                                cumulative_trapi_result_curie_combo_figure_score
# trapi_result_curie_combo
# (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)                                       1853.333333
# (MESH:D002118, NCBIGene:5595, NCBIGene:7454)                                         781.333333
# (MESH:D002118, NCBIGene:5335, NCBIGene:7454)                                         625.333333
# (NCBIGene:1950, NCBIGene:1956, NCBIGene:7454)                                        518.666667
# (MESH:D002118, NCBIGene:207, NCBIGene:7454)                                          509.666667
# (MESH:D000255, NCBIGene:207, NCBIGene:7454)                                          415.333333
# (NCBIGene:7040, NCBIGene:7124, NCBIGene:7454)                                        414.333333
# (NCBIGene:1956, NCBIGene:2064, NCBIGene:7454)                                        372.000000
# (MESH:D020123, NCBIGene:207, NCBIGene:7454)                                          318.666667
# (MESH:D012694, NCBIGene:207, NCBIGene:7454)                                          243.333333

# %% [markdown]
# ### TODO: why is NCBIGene:5111 returned as a SmallMolecule?

# %%
results_df[results_df["trapi_result_curie_combo"] == ("NCBIGene:23221", "NCBIGene:5111", "NCBIGene:595")]
# Out:
# Empty DataFrame
# Columns: [n0, e01, n1, e02, n2, n0_curie, n0_unified_curie, n1_curie, n1_unified_curie, n2_curie, n2_unified_curie, trapi_result_curie_combo]
# Index: []

# %%
results_with_figures_df = trapi_figure_overlap_df.merge(
    results_df,
    on="trapi_result_curie_combo",
    how="left").merge(
    trapi_result_figure_score_df.reset_index(),
    on="trapi_result_curie_combo",
    how="left",
    validate="many_to_one"
).merge(
    trapi_curie_combo_count_by_figure_df.reset_index().rename(columns={
        "trapi_curie_combo_count": "trapi_curie_combo_count_by_figure"
    }),
    on="figure_id",
    how="left",
    validate="many_to_one"
).sort_values(
    by="cumulative_trapi_result_curie_combo_figure_score", ascending=False
)

results_with_figures_df
# Out:
#                                         figure_id  \
# 427559          PMC3696710__cjcr-25-03-346-f2.jpg
# 427497   PMC7709261__40364_2020_252_Fig2_HTML.jpg
# 427489  PMC5241340__10549_2016_4079_Fig8_HTML.jpg
# 427490              PMC2857646__nihms191420f1.jpg
# 427491           PMC4682714__ata0021300280002.jpg
# ...                                           ...
# 293815    PMC4487197__40303_2015_13_Fig2_HTML.jpg
# 293729  PMC5319840__elife-22914-fig3-figsupp2.jpg
# 293728  PMC5319840__elife-22914-fig3-figsupp2.jpg
# 630465              PMC5118094__nihms825299f7.jpg
# 673601         PMC6862015__ijms-20-05517-g005.jpg
#
#                                                figure_url  \
# 427559  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 427497  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 427489  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 427490  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 427491  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# ...                                                   ...
# 293815  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 293729  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 293728  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 630465  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 673601  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                              figure_title  \
# 427559  Different models of Hh signaling pathway activ...
# 427497  Function of lncRNAs in regulating TGFB signali...
# 427489  Hypothesis of miR-567 modulation in healthy an...
# 427490            Schematic of the TGFB signaling pathway
# 427491  Provides a schematic and abbreviated overview ...
# ...                                                   ...
# 293815  Ephrin receptor signaling pathway (genes hypom...
# 293729  Tgfbr2 cKO CD34+ SCC cells upregulate genes im...
# 293728  Tgfbr2 cKO CD34+ SCC cells upregulate genes im...
# 630465  Cocaine regulation of specific Canonical Pathw...
# 673601               Complement lectin pathway activation
#
#                                 trapi_result_curie_combo  \
# 427559     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427497     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427489     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427490     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427491     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# ...                                                  ...
# 293815  (MESH:C000706872, NCBIGene:10006, NCBIGene:7454)
# 293729      (MESH:C474722, NCBIGene:6503, NCBIGene:7454)
# 293728      (MESH:C474722, NCBIGene:6503, NCBIGene:7454)
# 630465     (MESH:C526575, NCBIGene:10095, NCBIGene:7454)
# 673601   (MESH:C000625785, NCBIGene:1311, NCBIGene:7454)
#
#                                        figure_curie_combo  \
# 427559  (MESH:D009369, NCBIGene:1950, NCBIGene:1956, N...
# 427497  (NCBIGene:11025, NCBIGene:3880, NCBIGene:4086,...
# 427489  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# 427490  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# 427491  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# ...                                                   ...
# 293815  (MESH:C043055, MESH:C105630, MESH:D006153, NCB...
# 293729  (MESH:C004322, MESH:C045346, MESH:C054171, MES...
# 293728  (MESH:C004322, MESH:C045346, MESH:C054171, MES...
# 630465  (MESH:C035086, NCBIGene:10092, NCBIGene:10093,...
# 673601  (MESH:C050928, MESH:C051905, MESH:C489165, NCB...
#
#                     overlap_curie_combo     score   n0  \
# 427559   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427497   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427489   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427490   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427491   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# ...                                 ...       ...  ...
# 293815  (NCBIGene:10006, NCBIGene:7454)  0.666667  WAS
# 293729   (NCBIGene:6503, NCBIGene:7454)  0.666667  WAS
# 293728   (NCBIGene:6503, NCBIGene:7454)  0.666667  WAS
# 630465  (NCBIGene:10095, NCBIGene:7454)  0.666667  WAS
# 673601   (NCBIGene:1311, NCBIGene:7454)  0.666667  WAS
#
#                                        e01      n1  \
# 427559  entity_negatively_regulates_entity   TGFB1
# 427497  entity_negatively_regulates_entity   TGFB1
# 427489  entity_negatively_regulates_entity   TGFB1
# 427490  entity_negatively_regulates_entity   TGFB1
# 427491  entity_negatively_regulates_entity   TGFB1
# ...                                    ...     ...
# 293815  entity_positively_regulates_entity    ABI1
# 293729  entity_negatively_regulates_entity     SLA
# 293728  entity_negatively_regulates_entity     SLA
# 630465          genetically_interacts_with  ARPC1B
# 673601  entity_negatively_regulates_entity    COMP
#
#                                 e02  \
# 427559                      part_of
# 427497                      part_of
# 427489                      part_of
# 427490                      part_of
# 427491                      part_of
# ...                             ...
# 293815  sensitivity_associated_with
# 293729   resistance_associated_with
# 293728  sensitivity_associated_with
# 630465   resistance_associated_with
# 673601   resistance_associated_with
#
#                                                        n2       n0_curie  \
# 427559                                              TGFB2  NCBIGene:7454
# 427497                                              TGFB2  NCBIGene:7454
# 427489                                              TGFB2  NCBIGene:7454
# 427490                                              TGFB2  NCBIGene:7454
# 427491                                              TGFB2  NCBIGene:7454
# ...                                                   ...            ...
# 293815  N-[4-[(4-Ethylpiperazin-1-yl)methyl]-3-(triflu...  NCBIGene:7454
# 293729  N-[4-[[6-Methoxy-7-[3-(4-morpholinyl)propoxy]-...  NCBIGene:7454
# 293728  N-[4-[[6-Methoxy-7-[3-(4-morpholinyl)propoxy]-...  NCBIGene:7454
# 630465                                          Masitinib  NCBIGene:7454
# 673601                                          Motesanib  NCBIGene:7454
#
#        n0_unified_curie        n1_curie n1_unified_curie  \
# 427559    NCBIGene:7454   NCBIGene:7040    NCBIGene:7040
# 427497    NCBIGene:7454   NCBIGene:7040    NCBIGene:7040
# 427489    NCBIGene:7454   NCBIGene:7040    NCBIGene:7040
# 427490    NCBIGene:7454   NCBIGene:7040    NCBIGene:7040
# 427491    NCBIGene:7454   NCBIGene:7040    NCBIGene:7040
# ...                 ...             ...              ...
# 293815    NCBIGene:7454  NCBIGene:10006   NCBIGene:10006
# 293729    NCBIGene:7454   NCBIGene:6503    NCBIGene:6503
# 293728    NCBIGene:7454   NCBIGene:6503    NCBIGene:6503
# 630465    NCBIGene:7454  NCBIGene:10095   NCBIGene:10095
# 673601    NCBIGene:7454   NCBIGene:1311    NCBIGene:1311
#
#                          n2_curie n2_unified_curie  \
# 427559              NCBIGene:7042    NCBIGene:7042
# 427497              NCBIGene:7042    NCBIGene:7042
# 427489              NCBIGene:7042    NCBIGene:7042
# 427490              NCBIGene:7042    NCBIGene:7042
# 427491              NCBIGene:7042    NCBIGene:7042
# ...                           ...              ...
# 293815  PUBCHEM.COMPOUND:53340664  MESH:C000706872
# 293729   PUBCHEM.COMPOUND:9914412     MESH:C474722
# 293728   PUBCHEM.COMPOUND:9914412     MESH:C474722
# 630465  PUBCHEM.COMPOUND:10074640     MESH:C526575
# 673601  PUBCHEM.COMPOUND:11667893  MESH:C000625785
#
#         cumulative_trapi_result_curie_combo_figure_score  \
# 427559                                       1853.333333
# 427497                                       1853.333333
# 427489                                       1853.333333
# 427490                                       1853.333333
# 427491                                       1853.333333
# ...                                                  ...
# 293815                                          0.666667
# 293729                                          0.666667
# 293728                                          0.666667
# 630465                                          0.666667
# 673601                                          0.666667
#
#         trapi_curie_combo_count_by_figure
# 427559                                  3
# 427497                                  1
# 427489                                  1
# 427490                                  1
# 427491                                  1
# ...                                   ...
# 293815                               4195
# 293729                                302
# 293728                                302
# 630465                               5163
# 673601                                281
#
# [673602 rows x 20 columns]

# %% [markdown]
# ## Fisher's Exact Test
#
# ### TODO: vectorize
# For better performance, try vectorizing the calculation of Fisher's Exact test, e.g.:
# https://stackoverflow.com/questions/34947578/how-to-vectorize-fishers-exact-test

# %%
all_genes = set()
gene_instance_count = 0
all_chemicals = set()
chemical_instance_count = 0
all_diseases = set()
disease_instance_count = 0
for figure_id, pfocr_result in figure_id_to_pfocr_result.items():
    genes = pfocr_result["associatedWith"]["mentions"]["genes"]["ncbigene"]
    for gene in genes:
        gene_instance_count += 1
        all_genes.add(gene)
        
    chemicals = pfocr_result["associatedWith"]["mentions"]["chemicals"]["mesh"]
    for chemical in chemicals:
        chemical_instance_count += 1
        all_chemicals.add(chemical)
        
    diseases = pfocr_result["associatedWith"]["mentions"]["diseases"]["mesh"]
    for disease in diseases:
        disease_instance_count += 1
        all_diseases.add(disease)
    
print("total instance counts:")
print(gene_instance_count)
print(chemical_instance_count)
print(disease_instance_count)

print("")

print("unique counts:")
print(len(all_genes))
print(len(all_chemicals))
print(len(all_diseases))

print("")

curie_category_to_curies = {
    "biolink:ChemicalEntity": all_chemicals,
    "biolink:SmallMolecule": all_chemicals,
    "biolink:Disease": all_diseases,
    "biolink:Gene": all_genes,
}


all_figure_curies = set()
for curie_category in set(curie_category_to_curies.keys()).intersection(curie_categories):
    all_figure_curies |= curie_category_to_curies[curie_category]
all_figure_curie_count = len(all_figure_curies)

print(all_figure_curie_count)
# Out:
# total instance counts:
# 1369680
# 275456
# 20465
#
# unique counts:
# 14253
# 14482
# 1430
#
# 28735

# %%
# trapi_curies_in_pwy
results_with_figures_df["yes_pwy_yes_trapi"] = (
    results_with_figures_df["overlap_curie_combo"].map(len)
)

# q_node_id_count - trapi_curies_in_pwy
results_with_figures_df["no_pwy_yes_trapi"] = (
    len(q_node_ids) - results_with_figures_df["yes_pwy_yes_trapi"]
)

# curies_in_pwy - trapi_curies_in_pwy
results_with_figures_df["yes_pwy_no_trapi"] = (
    results_with_figures_df["figure_curie_combo"].map(len) - 
    results_with_figures_df["yes_pwy_yes_trapi"]
)

# 28735 - curies_in_pwy - q_node_id_count - trapi_curies_in_pwy
results_with_figures_df["no_pwy_no_trapi"] = (
    all_figure_curie_count -
    results_with_figures_df["figure_curie_combo"].map(len) -
    len(q_node_ids) -
    results_with_figures_df["yes_pwy_yes_trapi"]
)

# %%
import scipy.stats as stats


results_with_figures_df["fishers_exact"] = results_with_figures_df[
    ["yes_pwy_yes_trapi",
     "no_pwy_yes_trapi",
     "yes_pwy_no_trapi",
     "no_pwy_no_trapi"]
].apply(
    lambda r: stats.fisher_exact([[
        r.yes_pwy_yes_trapi,
        r.no_pwy_yes_trapi
    ], [
        r.yes_pwy_no_trapi,
        r.no_pwy_no_trapi,
    ]]),
    axis=1)

results_with_figures_df["p_value"] = results_with_figures_df["fishers_exact"].apply(
    lambda x: x[1]
)

# %%
results_with_figures_df["p_value"].sort_values()
# Out:
# 243319    2.530667e-13
# 243314    2.530667e-13
# 243316    2.530667e-13
# 243317    2.530667e-13
# 243318    2.530667e-13
#               ...
# 28919     4.788013e-04
# 666040    4.788013e-04
# 666039    4.788013e-04
# 531907    4.788013e-04
# 28920     4.788013e-04
# Name: p_value, Length: 673602, dtype: float64

# %%
results_with_figures_df
# Out:
#                                         figure_id  \
# 427559          PMC3696710__cjcr-25-03-346-f2.jpg
# 427497   PMC7709261__40364_2020_252_Fig2_HTML.jpg
# 427489  PMC5241340__10549_2016_4079_Fig8_HTML.jpg
# 427490              PMC2857646__nihms191420f1.jpg
# 427491           PMC4682714__ata0021300280002.jpg
# ...                                           ...
# 293815    PMC4487197__40303_2015_13_Fig2_HTML.jpg
# 293729  PMC5319840__elife-22914-fig3-figsupp2.jpg
# 293728  PMC5319840__elife-22914-fig3-figsupp2.jpg
# 630465              PMC5118094__nihms825299f7.jpg
# 673601         PMC6862015__ijms-20-05517-g005.jpg
#
#                                                figure_url  \
# 427559  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 427497  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 427489  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 427490  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 427491  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# ...                                                   ...
# 293815  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 293729  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 293728  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 630465  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 673601  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                              figure_title  \
# 427559  Different models of Hh signaling pathway activ...
# 427497  Function of lncRNAs in regulating TGFB signali...
# 427489  Hypothesis of miR-567 modulation in healthy an...
# 427490            Schematic of the TGFB signaling pathway
# 427491  Provides a schematic and abbreviated overview ...
# ...                                                   ...
# 293815  Ephrin receptor signaling pathway (genes hypom...
# 293729  Tgfbr2 cKO CD34+ SCC cells upregulate genes im...
# 293728  Tgfbr2 cKO CD34+ SCC cells upregulate genes im...
# 630465  Cocaine regulation of specific Canonical Pathw...
# 673601               Complement lectin pathway activation
#
#                                 trapi_result_curie_combo  \
# 427559     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427497     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427489     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427490     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# 427491     (NCBIGene:7040, NCBIGene:7042, NCBIGene:7454)
# ...                                                  ...
# 293815  (MESH:C000706872, NCBIGene:10006, NCBIGene:7454)
# 293729      (MESH:C474722, NCBIGene:6503, NCBIGene:7454)
# 293728      (MESH:C474722, NCBIGene:6503, NCBIGene:7454)
# 630465     (MESH:C526575, NCBIGene:10095, NCBIGene:7454)
# 673601   (MESH:C000625785, NCBIGene:1311, NCBIGene:7454)
#
#                                        figure_curie_combo  \
# 427559  (MESH:D009369, NCBIGene:1950, NCBIGene:1956, N...
# 427497  (NCBIGene:11025, NCBIGene:3880, NCBIGene:4086,...
# 427489  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# 427490  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# 427491  (NCBIGene:4087, NCBIGene:4088, NCBIGene:4089, ...
# ...                                                   ...
# 293815  (MESH:C043055, MESH:C105630, MESH:D006153, NCB...
# 293729  (MESH:C004322, MESH:C045346, MESH:C054171, MES...
# 293728  (MESH:C004322, MESH:C045346, MESH:C054171, MES...
# 630465  (MESH:C035086, NCBIGene:10092, NCBIGene:10093,...
# 673601  (MESH:C050928, MESH:C051905, MESH:C489165, NCB...
#
#                     overlap_curie_combo     score   n0  \
# 427559   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427497   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427489   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427490   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# 427491   (NCBIGene:7040, NCBIGene:7042)  0.666667  WAS
# ...                                 ...       ...  ...
# 293815  (NCBIGene:10006, NCBIGene:7454)  0.666667  WAS
# 293729   (NCBIGene:6503, NCBIGene:7454)  0.666667  WAS
# 293728   (NCBIGene:6503, NCBIGene:7454)  0.666667  WAS
# 630465  (NCBIGene:10095, NCBIGene:7454)  0.666667  WAS
# 673601   (NCBIGene:1311, NCBIGene:7454)  0.666667  WAS
#
#                                        e01      n1  ...  \
# 427559  entity_negatively_regulates_entity   TGFB1  ...
# 427497  entity_negatively_regulates_entity   TGFB1  ...
# 427489  entity_negatively_regulates_entity   TGFB1  ...
# 427490  entity_negatively_regulates_entity   TGFB1  ...
# 427491  entity_negatively_regulates_entity   TGFB1  ...
# ...                                    ...     ...  ...
# 293815  entity_positively_regulates_entity    ABI1  ...
# 293729  entity_negatively_regulates_entity     SLA  ...
# 293728  entity_negatively_regulates_entity     SLA  ...
# 630465          genetically_interacts_with  ARPC1B  ...
# 673601  entity_negatively_regulates_entity    COMP  ...
#
#                          n2_curie n2_unified_curie  \
# 427559              NCBIGene:7042    NCBIGene:7042
# 427497              NCBIGene:7042    NCBIGene:7042
# 427489              NCBIGene:7042    NCBIGene:7042
# 427490              NCBIGene:7042    NCBIGene:7042
# 427491              NCBIGene:7042    NCBIGene:7042
# ...                           ...              ...
# 293815  PUBCHEM.COMPOUND:53340664  MESH:C000706872
# 293729   PUBCHEM.COMPOUND:9914412     MESH:C474722
# 293728   PUBCHEM.COMPOUND:9914412     MESH:C474722
# 630465  PUBCHEM.COMPOUND:10074640     MESH:C526575
# 673601  PUBCHEM.COMPOUND:11667893  MESH:C000625785
#
#        cumulative_trapi_result_curie_combo_figure_score  \
# 427559                                      1853.333333
# 427497                                      1853.333333
# 427489                                      1853.333333
# 427490                                      1853.333333
# 427491                                      1853.333333
# ...                                                 ...
# 293815                                         0.666667
# 293729                                         0.666667
# 293728                                         0.666667
# 630465                                         0.666667
# 673601                                         0.666667
#
#        trapi_curie_combo_count_by_figure yes_pwy_yes_trapi no_pwy_yes_trapi  \
# 427559                                 3                 2                1
# 427497                                 1                 2                1
# 427489                                 1                 2                1
# 427490                                 1                 2                1
# 427491                                 1                 2                1
# ...                                  ...               ...              ...
# 293815                              4195                 2                1
# 293729                               302                 2                1
# 293728                               302                 2                1
# 630465                              5163                 2                1
# 673601                               281                 2                1
#
#        yes_pwy_no_trapi no_pwy_no_trapi  \
# 427559               13           28715
# 427497               14           28714
# 427489                4           28724
# 427490                4           28724
# 427491                4           28724
# ...                 ...             ...
# 293815               65           28663
# 293729               65           28663
# 293728               65           28663
# 630465              129           28599
# 673601               53           28675
#
#                                        fishers_exact       p_value
# 427559    (4417.692307692308, 7.629975582113902e-07)  7.629976e-07
# 427497               (4102.0, 8.719769682728204e-07)  8.719770e-07
# 427489             (14362.0, 1.0902242242363447e-07)  1.090224e-07
# 427490             (14362.0, 1.0902242242363447e-07)  1.090224e-07
# 427491             (14362.0, 1.0902242242363447e-07)  1.090224e-07
# ...                                              ...           ...
# 293815   (881.9384615384615, 1.6047155573859988e-05)  1.604716e-05
# 293729   (881.9384615384615, 1.6047155573859988e-05)  1.604716e-05
# 293728   (881.9384615384615, 1.6047155573859988e-05)  1.604716e-05
# 630465     (443.3953488372093, 6.17088606859295e-05)  6.170886e-05
# 673601  (1082.0754716981132, 1.0780946115877873e-05)  1.078095e-05
#
# [673602 rows x 26 columns]

# %% [markdown]
# ## Analysis of results with vs. without BTE Sleeve

# %% [markdown]
# With the current query graph, requiring co-occurrence of at least 2 nodes in at least one PFOCR figure cuts the number of TRAPI result curie combos down to 887 from 3,738.
#
# When requiring 3 nodes, it went down all the way to 0, but I've seen other queries where that yield 9 to 30 results.

# %% [markdown]
# Total number of curie combos returned:

# %%
len(results_df["trapi_result_curie_combo"].drop_duplicates())
# Out:
# 22366

# %% [markdown]
# TRAPI result curie combos where at least `x` curies are also found in at least one figure:

# %%
for i in range(2, len(q_node_ids) + 1):
    curie_combo_count = len(set(
        trapi_figure_overlap_df[
            trapi_figure_overlap_df["overlap_curie_combo"].map(len) >= i
        ]["trapi_result_curie_combo"]
    ))
    print(f'when {i}+ overlapping curies: {curie_combo_count}')
# Out:
# when 2+ overlapping curies: 16179
# when 3+ overlapping curies: 139

# %% [markdown]
# curie combos where curies for each pair of nodes are found in at least one figure:

# %%
from itertools import combinations


overlap_columns = results_with_figures_df["overlap_curie_combo"].apply(pd.Series)

for q_node_id in q_node_ids:
    overlap_df = results_with_figures_df[(
        results_with_figures_df[f"{q_node_id}_unified_curie"] == overlap_columns[0]
    ) | (
        results_with_figures_df[f"{q_node_id}_unified_curie"] == overlap_columns[1]
    )]
    print(f'{q_node_id}')
    print(f'  {len(overlap_df["trapi_result_curie_combo"].drop_duplicates())} TRAPI result(s)')
    print(f'  {len(overlap_df["figure_id"].drop_duplicates())} figure(s)')

for (a, b) in combinations(q_node_ids, 2):
    overlap_df = results_with_figures_df[((
        results_with_figures_df[f"{a}_unified_curie"] == overlap_columns[0]
    ) | (
        results_with_figures_df[f"{a}_unified_curie"] == overlap_columns[1]
    )) & ((
        results_with_figures_df[f"{b}_unified_curie"] == overlap_columns[0]
    ) | (
        results_with_figures_df[f"{b}_unified_curie"] == overlap_columns[1]
    ))]
    print(f'{a} & {b}')
    print(f'  {len(overlap_df["trapi_result_curie_combo"].drop_duplicates())} TRAPI result(s)')
    print(f'  {len(overlap_df["figure_id"].drop_duplicates())} figure(s)')
# Out:
# n0
#   16075 TRAPI result(s)
#   210 figure(s)
# n1
#   15842 TRAPI result(s)
#   11681 figure(s)
# n2
#   3438 TRAPI result(s)
#   11677 figure(s)
# n0 & n1
#   15681 TRAPI result(s)
#   168 figure(s)
# n0 & n2
#   1446 TRAPI result(s)
#   157 figure(s)
# n1 & n2
#   2624 TRAPI result(s)
#   11606 figure(s)

# %% [markdown]
# ## View TRAPI results with figures
#
# Note you can click the figures to go to the paper.
#
# Compare these results with the `results_df` table earlier in this notebook and also with the [ARAX UI](https://arax.ncats.io/?r=44922) (click "Load" and then "Results".).
#
# Does requiring co-occurrence for specific nodes like `n0` and `n2` help? Does ranking by p-value help?

# %% [markdown]
# ### By lowest p-value

# %%
lowest_p_value_df = results_with_figures_df.sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 5
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in lowest_p_value_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(lowest_p_value_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302074/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302074/bin/cdd464f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Yeast Cdc42 GTPase and Ste20 PAK-like...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6758901/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6758901/bin/ns0526160001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Models of Cdc42 activation<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5532371/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5532371/bin/41598_2017_6754_Fig8_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 A possible pathway for pre-...<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6328557/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6328557/bin/41467_2018_7998_Fig7_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 The mechanism of Mir20a/106a-WTX axis...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2773630/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2773630/bin/cshperspect-SYM-003384_F6.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Molecular interactions during pheromone...<br>
#                 p-value: 1.1e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6894087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6894087/bin/fj.201900991Rf7.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic drawing that illustrates the...<br>
#                 p-value: 1.5e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 101 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2861543/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2861543/bin/fig-6.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Differential role for endocytosis in...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6895846/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6895846/bin/cancers-11-01736-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 ADAM17 is a membrane-bound...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7881399/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7881399/bin/GHFBB-13-S68-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Action relationships including activation...<br>
#                 p-value: 2.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6590709/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6590709/bin/nihms-1035910-f0006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Glycosylation in health and disease<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6165231/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6165231/bin/ijms-19-02835-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Hedgehog (Hh) pathway activation<br>
#                 p-value: 4.0e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6042961/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6042961/bin/elife-35012-fig10.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 FRMD8 stabilises the iRhom2/ADAM17...<br>
#                 p-value: 4.0e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3939471/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3939471/bin/viruses-06-00535-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Involvement of CD81 in Hepatitis C Virus...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 206 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, NCBIGene:7042</span>
#   <span>(cumulative containment score: 1853.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 5.1e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 1.8e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 2.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 2.9e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 3.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 4.4e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 6.3e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 2764 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98914/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98914/bin/mr0280010012.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Signalling pathway for pseudohyphal growth<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC25236/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC25236/bin/mk0180513007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Models for FLO11 action in the filamentous...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3785965/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3785965/bin/rstb20130015-g4.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 p120catenin regulation of Rho-GTPase...<br>
#                 p-value: 2.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2544441/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2544441/bin/zh00090857030003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Signaling pathway for the regulation of...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 67 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, MESH:C115711</span>
#   <span>(cumulative containment score: 10.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - sensitivity_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - resistance_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 1.1e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 4.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 6.3e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6690932/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6690932/bin/41598_2019_48131_Fig3_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Drug screening of the lysosomal pathway by...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 8.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 5 more figures
#
# ...
#
# plus 16174 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in lowest_p_value_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-weight: bold; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(lowest_p_value_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - 1,3-Benzothiazol-2-yl(2-((2-(3-pyridinyl)ethyl)amino)-4-pyrimidinyl)acetonitrile</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - 1,3-Benzothiazol-2-yl(2-((2-(3-pyridinyl)ethyl)amino)-4-pyrimidinyl)acetonitrile</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - PDK1 inhibitor AR-12</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - PDK1 inhibitor AR-12</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - PDK1 inhibitor AR-12</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - PDK1 inhibitor AR-12</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - Masitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - Masitinib</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Cryptotanshinone</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Cryptotanshinone</span>
# </div>
# ...
#
# plus 392 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - physically_interacts_with - Axitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - sensitivity_associated_with - Axitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Axitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - resistance_associated_with - Axitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Axitinib</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - (S)-4-(2-(4-Amino-1,2,5-oxadiazol-3-yl)-1-ethyl-7-(piperidin-3-ylmethoxy)-1H-imidazo[4,5-c]pyridin-4-yl)-2-methylbut-3-yn-2-ol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - resistance_associated_with - (S)-4-(2-(4-Amino-1,2,5-oxadiazol-3-yl)-1-ethyl-7-(piperidin-3-ylmethoxy)-1H-imidazo[4,5-c]pyridin-4-yl)-2-methylbut-3-yn-2-ol</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - 4-(4-(Benzo[d][1,3]dioxol-5-yl)-5-(pyridin-2-yl)-1H-imidazol-2-yl)benzamide</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Sulfuric Acid Esters</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - coexists_with - Sulfuric Acid Esters</span>
# </div>
# ...
#
# plus 1056 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic diagram showing the mechanisms of sesquiterpenoids in regulation of insect eusociality
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 5.1e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - 1H-Purine-2,6-dione, 7-(2-(4-(2-chlorophenyl)-1-piperazinyl)ethyl)-3,7-dihydro-1,3-dimethyl-</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Phosphorus</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Roflumilast</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Lipoic acid</span>
# </div>
# ...
#
# plus 1270 more TRAPI results
#
# ...
#
# plus 11720 more figures

# %% [markdown]
# ### co-occurrence: `n0` and (`n1` or `n2`)

# %%
n0_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: r.n0_unified_curie in set(r.overlap_curie_combo),
    axis=1
)].sort_values(
    "p_value"
)

# %%
print(len(set(results_with_figures_df["figure_id"])))
print(len(set(n0_cooccurrence_df["figure_id"])))
# Out:
# 11723
# 210

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 5
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 51 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/bin/oncotarget-07-12206-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Epidermal growth factor receptor regulates...<br>
#                 p-value: 2.5e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/bin/gr1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myosin 1c in cellular signaling pathways<br>
#                 p-value: 2.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/bin/nihms246275f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune and central nervous systems...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig4_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 3.8e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/bin/nihms951359f3.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Herpesvirus-encoded microRNAs detected in...<br>
#                 p-value: 5.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 16 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, NCBIGene:7042</span>
#   <span>(cumulative containment score: 1853.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 5.1e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 1.8e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 2.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 2.9e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 3.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 4.4e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 6.3e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 5 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/bin/nihms114350f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Spatial Segregation of...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/bin/IJCB2012-501962.003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic of signaling pathways activated...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 1.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/bin/zbc0190834370009.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Several signaling pathways work together...<br>
#                 p-value: 2.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 47 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, MESH:C115711</span>
#   <span>(cumulative containment score: 10.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - resistance_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - sensitivity_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 1.1e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 4.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 6.3e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 8.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 1.0e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
#
# ...
#
# plus 16070 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-weight: bold; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Ethanol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Ethanol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Ethanol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Ethanol</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Nitrogen</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Creatinolfosfate</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Creatinolfosfate</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Adenosine-5'-triphosphate</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - Adenosine-5'-triphosphate</span>
# </div>
# ...
#
# plus 392 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - L-Theanine</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Grape Seed Proanthocyanidins</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - 2-(N-Morpholino)-ethanesulfonic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - 2-(N-Morpholino)-ethanesulfonic acid</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Dactinomycin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Dactinomycin</span>
# </div>
# ...
#
# plus 1056 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic diagram showing the mechanisms of sesquiterpenoids in regulation of insect eusociality
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 5.1e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - coexists_with - Lewis Y antigen</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - tesamorelin</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_positively_regulates_entity - Calcipotriol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Calcipotriol</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Bisindolylmaleimide i</span>
# </div>
# ...
#
# plus 1270 more TRAPI results
#
# ...
#
# plus 207 more figures

# %% [markdown]
# ### co-occurrence: `n0` and `n1`

# %%
n0_n1_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: (
        r.n0_unified_curie in set(r.overlap_curie_combo)
    ) and (
        r.n1_unified_curie in set(r.overlap_curie_combo)
    ),
    axis=1
)].sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 5
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_n1_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_n1_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 45 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/bin/oncotarget-07-12206-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Epidermal growth factor receptor regulates...<br>
#                 p-value: 2.5e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig4_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 3.8e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/bin/nihms951359f3.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Herpesvirus-encoded microRNAs detected in...<br>
#                 p-value: 5.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 1.2e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4257089/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4257089/bin/fimmu-05-00599-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 In silico modeling of a CD4+ T-cell<br>
#                 p-value: 1.6e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7650600/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7650600/bin/cancers-12-02991-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 KIR2DL2/L3/S2+ CD8+ T cell cluster...<br>
#                 p-value: 1.7e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4439562/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4439562/bin/db141843f4.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 GPCR (or GPR) signaling in the regulation...<br>
#                 p-value: 2.1e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, NCBIGene:7042</span>
#   <span>(cumulative containment score: 1853.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 5.1e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 1.8e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 2.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 2.9e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 3.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 4.4e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 6.3e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/bin/IJCB2012-501962.003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic of signaling pathways activated...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/bin/nihms114350f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Spatial Segregation of...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 1.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/bin/zbc0190834370009.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Several signaling pathways work together...<br>
#                 p-value: 2.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 45 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, MESH:C115711</span>
#   <span>(cumulative containment score: 10.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - sensitivity_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - resistance_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 1.1e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 4.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 6.3e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 8.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 1.0e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
#
# ...
#
# plus 15677 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_n1_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-weight: bold; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_n1_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with - MicroRNAs</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - MicroRNAs</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - MicroRNAs</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - MicroRNAs</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity - MicroRNAs</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with - MicroRNAs</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - Benzamide, 4-(1-aminoethyl)-N-1H-pyrrolo(2,3-b)pyridin-4-yl-, (R)-</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - sensitivity_associated_with - Benzamide, 4-(1-aminoethyl)-N-1H-pyrrolo(2,3-b)pyridin-4-yl-, (R)-</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - Ispinesib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - Ispinesib</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - Erlotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - resistance_associated_with - Erlotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Erlotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_en
# ...
#
# plus 387 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Amylotriose</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Amylotriose</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Amylotriose</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Cannabidiol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Cannabidiol</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Bile acid</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - physically_interacts_with - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - molecularly_interacts_with - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - decreases_activity_of - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - directly_interacts_with - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_decreased_by - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - affects_activity_of - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - coexists_with - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Lapatinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - correlated_with - Lapatinib</span>
# </div>
# ...
#
# plus 1054 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic diagram showing the mechanisms of sesquiterpenoids in regulation of insect eusociality
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 5.1e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Eplerenone</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - interacts_with - Eplerenone</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Sodium fluoride</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_positively_regulates_entity - Iodine</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - entity_negatively_regulates_entity - Iodine</span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.1e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - sensitivity_associated_with - Saracatinib</span>
# </div>
# ...
#
# plus 1270 more TRAPI results
#
# ...
#
# plus 165 more figures

# %% [markdown]
# ### co-occurrence: `n0` and `n2`

# %%
n0_n2_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: (
        r.n0_unified_curie in set(r.overlap_curie_combo)
    ) and (
        r.n2_unified_curie in set(r.overlap_curie_combo)
    ),
    axis=1
)].sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 5
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_n2_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                    <img src="{figure_url}" style="height: {row_height}">
                </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_n2_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3018310/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3018310/bin/GEN1871105f1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 F igure 1.—<br>
#                 p-value: 9.9e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1274246/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1274246/bin/1471-2121-6-24-1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 The purine nucleotide synthesis pathway in...<br>
#                 p-value: 1.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4508005/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4508005/bin/nihms-691992-f0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myoblast fusion during muscle development<br>
#                 p-value: 1.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3408425/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3408425/bin/2993fig9.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Systems-level regulation of metabolic...<br>
#                 p-value: 1.2e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5749725/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5749725/bin/pone.0189887.g002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Identification of metastasis driver genes...<br>
#                 p-value: 3.0e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 1 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/bin/gr1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myosin 1c in cellular signaling pathways<br>
#                 p-value: 2.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/bin/nihms246275f2.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune and central nervous systems...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7210543/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7210543/bin/JIR2020-5649790.003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Scribble complex in immune cells<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3733802/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3733802/bin/pone.0071191.g002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Prioritizing Disease Candidate Proteins in...<br>
#                 p-value: 8.9e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7280878/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7280878/bin/nihpp-2003.14333v2-f0004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Target genes and pathways of COL-3 and...<br>
#                 p-value: 1.6e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7468567/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7468567/bin/f1000research-9-28930-g0003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Target genes and pathways of COL-3 and...<br>
#                 p-value: 1.7e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, NCBIGene:7042</span>
#   <span>(cumulative containment score: 1853.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic diagram showing the mechanisms...<br>
#                 p-value: 5.1e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8039963/bin/thnov11p5197g007.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genetic and molecular signal dynamics that...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3073350/bin/nihms283106f1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Linking actin dynamics and gene...<br>
#                 p-value: 1.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8037087/bin/ijms-22-03680-g002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Main mechanisms mediated by cannabinoids...<br>
#                 p-value: 1.8e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 2.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6780401/bin/jcm-08-01369-g003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Impacts of mutations in the TGFB signaling...<br>
#                 p-value: 2.9e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 3.1e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3047474/bin/nihms274014f2.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Innate IgA-inducing signaling pathways<br>
#                 p-value: 4.4e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4610744/bin/nihms-724234-f0001.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes and pathways identified from GWAS...<br>
#                 p-value: 6.3e-09,
#                 containment: 1.0
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 3 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3433902/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3433902/bin/zjw0051241270005.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune response to phagosome in antigen...<br>
#                 p-value: 2.5e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:7040, MESH:C115711</span>
#   <span>(cumulative containment score: 10.33)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - resistance_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - sensitivity_associated_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">1-(Tert-Butyl)-3-(2-((4-(diethylamino)butyl)amino)-6-(3,5-dimethoxyphenyl)pyrido[2,3-d]pyrimidin-7-yl)urea</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880350/bin/aging-13-202448-g008.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic illustration the contribution of...<br>
#                 p-value: 4.2e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 1472 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_n2_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-weight: bold; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_n2_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produced_by -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity - SRC - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - SRC - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - RGS14 - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - RAC1 - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity - RAC1 - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity - TGFB1 - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# ...
#
# plus 1 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - WNK1 - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity - TGFB1 - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity - TGFB1 - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic diagram showing the mechanisms of sesquiterpenoids in regulation of insect eusociality
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7511761/bin/fgene-11-01027-g006.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-weight: bold; font-size: small;">
#       TRAPI result p-value: 5.1e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_negatively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB1</span>
#  - part_of -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TGFB2</span>
# </span>
# </div>
# ...
#
# plus 161 more figures

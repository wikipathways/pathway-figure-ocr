# %% [raw]
# !pip install numpy pandas requests requests_cache SetSimilaritySearch

# %%
from copy import copy
import json
import pandas as pd
import textwrap

# %% [markdown]
# # BTE Sleeve
#
# Some queries result in an explosion of the number of results. This is bad for performance of the server and also not very useful to the user. This notebook explores using PFOCR as a "compression sleeve" to dampen these types of explosions. I don't have a CC-licensed image of a compression sleeve, so instead here's an image of a heat-shrink tube.
#
# <a title="oomlout, CC BY-SA 2.0 &lt;https://creativecommons.org/licenses/by-sa/2.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:HESH-06-L-STAN-01_(9601242883).jpg"><img width="512" alt="HESH-06-L-STAN-01 (9601242883)" src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/HESH-06-L-STAN-01_%289601242883%29.jpg/512px-HESH-06-L-STAN-01_%289601242883%29.jpg"></a>
#
# `WAS Gene`--entity_regulates_entity|genetically_interacts_with--`Any Gene`--related_to--`Any SmallMolecule`
#
# `n0`--e01--`n1`--e02--`n2`
#
# Note BTE Sleeve currently only works on queries with nodes of categories supported by PFOCR, e.g., `biolink:Gene`, `biolink:SmallMolecule`, `biolink:Disease`. TODO: update the Fisher's Exact test to work with node categories not in PFOCR.
#
# Also, BTE Sleeve currently assumes `n0` has an `ids` parameter. TODO: update to handle `ids` params on any q_node.

# %%
import requests
import requests_cache


requests_cache.install_cache("pfocr_cache", allowable_methods=['GET', 'POST'])

# %% [markdown]
# ## Get BTE TRAPI Results

# %%
query = {
    "message": {
        "query_graph": {
            "edges": {
                "e0": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": [
                        "biolink:entity_regulates_entity",
                        "biolink:genetically_interacts_with"
                    ]
                },
                "e1": {
                    "subject": "n1",
                    "object": "n2",
                    "predicates": [
                        "biolink:related_to"
                    ]
                }
            },
            "nodes": {
                "n0": {
                    "ids": [
                        "NCBIGene:7454"
                    ],
                    "categories": [
                        "biolink:Gene"
                    ]
                },
                "n1": {
                    "categories": [
                        "biolink:Gene"
                    ],
                },
                "n2": {
                    "categories": [
                        "biolink:SmallMolecule"
                    ]
                }
            }
        }
    }
}

trapi_response = requests.post("http://localhost:3000/v1/query", json=query)
#trapi_response = requests.post("https://api.bte.ncats.io/v1/query", json=query)
#trapi_response = requests.post("https://arax.ncats.io/api/rtxkg2/v1.2/query", json=query)
#trapi_response = requests.post("https://arax.ncats.io/api/arax/v1.2/query", json=query)
print(trapi_response.status_code)
if trapi_response.status_code != 200:
    print(trapi_response.text)
if trapi_response.from_cache:
    print(f"got response from cache")

trapi_message = trapi_response.json()["message"]

#print(json.dumps(query))
# Out:
# 200
# got response from cache

# %%
# NOTE: we're also including any categories from the TRAPI results.
# Some categories are supersets of others.
# TODO: maybe handle this systematically?
curie_categories = set()
for v in  query["message"]["query_graph"]["nodes"].values():
    if "categories" in v:
        for category in v["categories"]:
            curie_categories.add(category)

# %%
# for genes/gene products, chemicals and diseases
preferred_prefixes = set(["NCBIGene", "MESH"])
unified_names = set()
unified_curies = set()
unification_failed_curies = set()
unified_prefixes = set()
all_prefixes = set()
curie_to_name = dict()
curie_to_unified_curie = dict()
for k, v in trapi_message["knowledge_graph"]["nodes"].items():
    name = v["name"]
    for category in v["categories"]:
        curie_categories.add(category)
        
    for a in v["attributes"]:
        if a["attribute_type_id"] == "biolink:xref":
            curies = a["value"]
            
            # k should always be one of the curies
            if not k in curies:
                raise Exception(f"key {k} not in {curies}")
            
            unified_curie = None
            intersecting_unified_curies = unified_curies.intersection(set(curies))
            if len(intersecting_unified_curies) > 1:
                raise Exception(f"matching multiple: {k} to {list(intersecting_unified_curies)}")
            elif len(intersecting_unified_curies) == 1:
                unified_curie = list(intersecting_unified_curies)[0]
            else:
                # get curie for preferred prefix. usually this is k, but not always.
                for curie in curies:
                    [prefix, identifier] = curie.split(":")
                    if prefix in preferred_prefixes:
                        unified_curie = curie
                        unified_curies.add(unified_curie)
                        break
                        
            if not unified_curie:
                if k in curie_to_unified_curie:
                    unified_curie = curie_to_unified_curie[k]
                else:
                    unification_failed_curies.add(k)
                    break
                    
                #raise Exception(f"failed to find a unified curie for {k} in {curies}")
                
            [unified_prefix, unified_identifier] = unified_curie.split(":")
            unified_prefixes.add(unified_prefix)
            
            for curie in curies:
                [prefix, identifier] = curie.split(":")
                all_prefixes.add(prefix)
                if not curie in curie_to_unified_curie:
                    curie_to_unified_curie[curie] = unified_curie
                if not curie in curie_to_name:
                    curie_to_name[curie] = name
                    unified_names.add(name)
                elif curie_to_name[curie] != name:
                    print(f"curie {curie} has multiple primary names: {curie_to_name[curie]} and {name}")
                    #raise Exception(f"curie{curie} has multiple names: {curie_to_name[curie]} and {name}")


#print(f'curie_categories: {curie_categories}')
#print("")
#print(f"curie_to_name key count: {len(curie_to_name.keys())}")
#print(f"curie_to_unified_curie key count: {len(curie_to_unified_curie.keys())}")
#print("")
print("all CURIE prefixes found:")
print(all_prefixes)
print("")
print("unified CURIE prefixes found:")
print(unified_prefixes)
print("")
print(f"failed to unify {len(unification_failed_curies)} CURIEs")
# Out:
# curie UMLS:C0003779 has multiple primary names: Desmopressin and Argipressin
# all CURIE prefixes found:
# {'PR', 'DRUGBANK', 'CAS', 'CHEMBL.COMPOUND', 'HGNC', 'MESH', 'OMIM', 'UMLS', 'NCBIGene', 'INCHIKEY', 'CHEBI', 'ENSEMBL', 'UniProtKB', 'GTOPDB', 'PUBCHEM.COMPOUND', 'HMDB', 'UNII', 'KEGG.COMPOUND', 'DrugCentral'}
#
# unified CURIE prefixes found:
# {'MESH', 'NCBIGene'}
#
# failed to unify 5100 CURIEs

# %%
columns = []
q_node_id_keys = set(["object", "subject"])
q_node_ids = []
q_edge_ids = []
for q_edge_id,edge_v in query["message"]["query_graph"]["edges"].items():
    q_edge_ids.append(q_edge_id)
    q_node_id_found = False
    for k,v in edge_v.items():
        if (k in q_node_id_keys) and (type(v) is str):
            if v not in columns:
                q_node_ids.append(v)
                columns.append(v)
            if not q_node_id_found:
                q_node_id_found = True
                columns.append(q_edge_id)
                
for q_node_id in q_node_ids:
    columns.append(f"{q_node_id}_curie")
    columns.append(f"{q_node_id}_unified_curie")
    
columns.append("trapi_result_curie_combo")

trapi_result_columns = []
for i in range(len(q_node_ids)):
    trapi_result_columns.append(q_node_ids[i])
    if i < len(q_edge_ids):
        trapi_result_columns.append(q_edge_ids[i])

# %%
from copy import deepcopy


trapi_results = trapi_message["results"]

result_row_data = []
for trapi_result in trapi_results:
    curie_to_qnode_ids = dict()
    for qnode_id, entries in trapi_result["node_bindings"].items():
        for entry in entries:
            curie = entry["id"]
            if curie not in curie_to_qnode_ids:
                curie_to_qnode_ids[curie] = []
            curie_to_qnode_ids[curie].append(qnode_id)
        
    row_data_template = dict()
    q_edge_id_to_predicates = dict()
    trapi_result_curies = set()
    for qedge_id, entries in trapi_result["edge_bindings"].items():
        for entry in entries:
            curie = entry["id"]
            kg_entry = trapi_message["knowledge_graph"]["edges"][curie]
            subject_curie = kg_entry["subject"]
            object_curie = kg_entry["object"]
            predicate_curie = kg_entry["predicate"]
            [predicate_prefix, predicate_identifier] = predicate_curie.split(":")
            
            if qedge_id not in q_edge_id_to_predicates:
                q_edge_id_to_predicates[qedge_id] = set()
            q_edge_id_to_predicates[qedge_id].add(predicate_identifier)

            for curie in [subject_curie, object_curie]:
                for qnode_id in curie_to_qnode_ids[curie]:
                    if curie in curie_to_unified_curie:
                        unified_curie = curie_to_unified_curie[curie]
                    else:
                        break

                    name = curie_to_name[curie]
                    row_data_template[qnode_id] = name

                    trapi_result_curies.add(unified_curie)
                    row_data_template[qnode_id + "_curie"] = curie
                    row_data_template[qnode_id + "_unified_curie"] = unified_curie
                    
    if len(trapi_result_curies) != len(q_node_ids):
        #print(f'skipping {list(curie_to_qnode_ids.keys())}')
        continue
        
    row_data_template["trapi_result_curie_combo"] = tuple(sorted(trapi_result_curies))
    q_edge_ids_processed = set()
    row_datas = [row_data_template]
    for q_edge_id,predicates in q_edge_id_to_predicates.items():
        next_row_datas = []
        for row_data in row_datas:
            for predicate in predicates:
                next_row_data = deepcopy(row_data)
                next_row_data[q_edge_id] = predicate
                next_row_datas.append(
                    next_row_data 
                )
        row_datas = next_row_datas
    result_row_data += row_datas
        
print("warning: predicate direction(s) may be switched")
results_df = pd.DataFrame.from_records(result_row_data, columns=columns).drop_duplicates()
results_df
# Out:
# warning: predicate direction(s) may be switched
#         n0                                  e0     n1  \
# 0      WAS  entity_positively_regulates_entity   LIAS
# 1      WAS  entity_positively_regulates_entity   LIAS
# 2      WAS  entity_positively_regulates_entity   LIAS
# 3      WAS  entity_positively_regulates_entity   LIAS
# 4      WAS  entity_positively_regulates_entity   LIAS
# ...    ...                                 ...    ...
# 25911  WAS          genetically_interacts_with  ASB15
# 25912  WAS          genetically_interacts_with  ASB15
# 25913  WAS          genetically_interacts_with  ASB15
# 25914  WAS          genetically_interacts_with  ASB15
# 25915  WAS          genetically_interacts_with  ASB15
#
#                                           e1  \
# 0      entity_negatively_regulated_by_entity
# 1             associated_with_sensitivity_to
# 2             associated_with_sensitivity_to
# 3             associated_with_sensitivity_to
# 4              associated_with_resistance_to
# ...                                      ...
# 25911          associated_with_resistance_to
# 25912          associated_with_resistance_to
# 25913                          coexists_with
# 25914                               has_part
# 25915                               has_part
#
#                                                       n2       n0_curie  \
# 0                               Epigallocatechin gallate  NCBIGene:7454
# 1                                    S-Trityl-L-cysteine  NCBIGene:7454
# 2                                                Embelin  NCBIGene:7454
# 3                                              Daporinad  NCBIGene:7454
# 4                                              Daporinad  NCBIGene:7454
# ...                                                  ...            ...
# 25911  2-(4-(Benzo[d][1,3]dioxol-5-yl)-2-tert-butyl-1...  NCBIGene:7454
# 25912                                          Linifanib  NCBIGene:7454
# 25913                                Intergenic Sequence  NCBIGene:7454
# 25914                           Early Promoters, Genetic  NCBIGene:7454
# 25915                                 5' Flanking Region  NCBIGene:7454
#
#       n0_unified_curie         n1_curie n1_unified_curie  \
# 0        NCBIGene:7454   NCBIGene:11019   NCBIGene:11019
# 1        NCBIGene:7454   NCBIGene:11019   NCBIGene:11019
# 2        NCBIGene:7454   NCBIGene:11019   NCBIGene:11019
# 3        NCBIGene:7454   NCBIGene:11019   NCBIGene:11019
# 4        NCBIGene:7454   NCBIGene:11019   NCBIGene:11019
# ...                ...              ...              ...
# 25911    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 25912    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 25913    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 25914    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
# 25915    NCBIGene:7454  NCBIGene:142685  NCBIGene:142685
#
#                         n2_curie n2_unified_curie  \
# 0         PUBCHEM.COMPOUND:65064     MESH:C045651
# 1         PUBCHEM.COMPOUND:76044     MESH:C003724
# 2          PUBCHEM.COMPOUND:3218     MESH:C010945
# 3       PUBCHEM.COMPOUND:6914657     MESH:C480543
# 4       PUBCHEM.COMPOUND:6914657     MESH:C480543
# ...                          ...              ...
# 25911   PUBCHEM.COMPOUND:9858940     MESH:C519132
# 25912  PUBCHEM.COMPOUND:11485656     MESH:C513486
# 25913              UMLS:C0887857     MESH:D021901
# 25914              UMLS:C0013462     MESH:D011401
# 25915              UMLS:C0949645     MESH:D024506
#
#                              trapi_result_curie_combo
# 0       (MESH:C045651, NCBIGene:11019, NCBIGene:7454)
# 1       (MESH:C003724, NCBIGene:11019, NCBIGene:7454)
# 2       (MESH:C010945, NCBIGene:11019, NCBIGene:7454)
# 3       (MESH:C480543, NCBIGene:11019, NCBIGene:7454)
# 4       (MESH:C480543, NCBIGene:11019, NCBIGene:7454)
# ...                                               ...
# 25911  (MESH:C519132, NCBIGene:142685, NCBIGene:7454)
# 25912  (MESH:C513486, NCBIGene:142685, NCBIGene:7454)
# 25913  (MESH:D021901, NCBIGene:142685, NCBIGene:7454)
# 25914  (MESH:D011401, NCBIGene:142685, NCBIGene:7454)
# 25915  (MESH:D024506, NCBIGene:142685, NCBIGene:7454)
#
# [25916 rows x 12 columns]

# %% [markdown]
# Unique CURIE count per query node:

# %%
for q_node_id in q_node_ids:
    print(f'{q_node_id}: {len(set(results_df[q_node_id]))}')
# Out:
# n0: 1
# n1: 86
# n2: 2787

# %% [markdown]
# Total results count (excluding any that couldn't be unified):

# %%
len(set(results_df["trapi_result_curie_combo"]))
# Out:
# 17467

# %% [markdown]
# That's too too high for a researcher to efficiently go through manually. Let's try filtering to make that more manageable.

# %% [markdown]
# ### TODO: NCBIGene for SmallMolecules?
# Why are some of the returned TRAPI results using NCBIGene CURIEs for small molecules?

# %%
results_df[(
    results_df["n2_curie"].str.startswith("NCBIGene:")
) | (
    results_df["n2_unified_curie"].str.startswith("NCBIGene:")
)][["n2", "n2_curie", "n2_unified_curie"]]
# Out:
#            n2        n2_curie n2_unified_curie
# 1763   LGALS1   NCBIGene:3956    NCBIGene:3956
# 4061      JTB  NCBIGene:10899   NCBIGene:10899
# 4062      JTB  NCBIGene:10899   NCBIGene:10899
# 9419   LGALS1   NCBIGene:3956    NCBIGene:3956
# 9420      VIM   NCBIGene:7431    NCBIGene:7431
# 9422    RBBP8   NCBIGene:5932    NCBIGene:5932
# 10076     VIM   NCBIGene:7431    NCBIGene:7431
# 12841     EGF   NCBIGene:1950    NCBIGene:1950
# 12842     EGF   NCBIGene:1950    NCBIGene:1950
# 12843     EGF   NCBIGene:1950    NCBIGene:1950
# 12958     TNF   NCBIGene:7124    NCBIGene:7124
# 12959   ERBB2   NCBIGene:2064    NCBIGene:2064
# 13166    SHC1   NCBIGene:6464    NCBIGene:6464
# 14786     CRK   NCBIGene:1398    NCBIGene:1398
# 18854   THBS1   NCBIGene:7057    NCBIGene:7057
# 20618    XPO1   NCBIGene:7514    NCBIGene:7514
# 20895    IRS1   NCBIGene:3667    NCBIGene:3667
# 21745     TNF   NCBIGene:7124    NCBIGene:7124
# 22080  SH2D3A  NCBIGene:10045   NCBIGene:10045

# %% [markdown]
# ## Match up BTE TRAPI Results & PFOCR
#
# We're going to try using PFOCR to filter and prioritize the results.
#
# First we need to get the PFOCR Data. We could get it from the API, but for now, we'll just go ahead and download the entire JSON file we gave to BTE.

# %%
pfocr_url = "https://www.dropbox.com/s/1f14t5zaseocyg6/bte_chemicals_diseases_genes.ndjson?dl=1"
pfocr_request = requests.get(pfocr_url)
print(f"status_code: {pfocr_request.status_code}")
if pfocr_request.status_code != 200:
    print(pfocr_request.text)
# Out:
# status_code: 200

# %%
curies_to_figure_ids = {}
figure_id_to_curies = {}
figure_id_to_pfocr_result = {}
for line in pfocr_request.text.splitlines():
    pfocr_result = json.loads(line)
    figure_id = pfocr_result["_id"]

    curies = set()
    for identifier in pfocr_result["associatedWith"]["mentions"]["chemicals"]["mesh"]:
        curie = "MESH:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)
    for identifier in pfocr_result["associatedWith"]["mentions"]["diseases"]["mesh"]:
        curie = "MESH:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)
    for identifier in pfocr_result["associatedWith"]["mentions"]["genes"]["ncbigene"]:
        curie = "NCBIGene:" + identifier
        if curie in curie_to_unified_curie:
            unified_curie = curie_to_unified_curie[curie]
            curies.add(unified_curie)
        else:
            #print(f"{curie} not in list")
            # this curie isn't in the BTE results, but we'll add an item for
            # the purpose of the denominator in jaccard/containment cals
            curies.add(curie)

    figure_id_to_pfocr_result[figure_id] = pfocr_result
    figure_id_to_curies[figure_id] = curies

    curies_key = tuple(sorted(curies))
    if curies_key not in curies_to_figure_ids:
        curies_to_figure_ids[curies_key] = []
    curies_to_figure_ids[curies_key].append(figure_id)

# %%
from SetSimilaritySearch import SearchIndex

# the reference sets are supposed to be from PFOCR only
reference_sets = list()
for curies in set(curies_to_figure_ids.keys()):
    reference_sets.append(set(curies))
# but in order to calculate the scores correctly,
# the SetSimilaritySearch library requires that
# every curie from the bte results need to be
# mentioned at least once in the reference set.
# That's the only reason we add them below, as
# one large set.

unified_curie_columns = [
    q_node_id + "_unified_curie" for q_node_id in q_node_ids
]

trapi_result_curie_combos = set()
for i, df in results_df[unified_curie_columns].drop_duplicates().iterrows():
    trapi_result_curies = []
    for unified_curie_column in unified_curie_columns:
        trapi_result_curies.append(
            df[unified_curie_column]
        )
    trapi_result_curie_combos.add(tuple(sorted(
        trapi_result_curies
    )))
    
reference_set = set()
for trapi_result_curie_combo in trapi_result_curie_combos:
    reference_set |= set(trapi_result_curie_combo)
reference_sets.append(reference_set)

matchable_node_min = 2
matchable_node_count = len(q_node_ids)
index = SearchIndex(reference_sets, similarity_func_name="containment", 
    similarity_threshold=matchable_node_min/matchable_node_count)

trapi_figure_overlap_rows = []
for trapi_result_curie_combo in trapi_result_curie_combos:
    trapi_curies = set(trapi_result_curie_combo)
    results = index.query(trapi_curies)
    for result in results:
        figure_curie_combos = reference_sets[result[0]]
        figure_curie_key = tuple(sorted(figure_curie_combos))
        
        # needed to not match bte results to themselves
        if figure_curie_key in curies_to_figure_ids:
            figure_ids = curies_to_figure_ids[figure_curie_key]
        else:
            continue
            
        score = result[1]
        
        common_curies = trapi_curies.intersection(figure_curie_combos)
        for figure_id in figure_ids:
            pfocr_result = figure_id_to_pfocr_result[figure_id]
            trapi_figure_overlap_rows.append({
                "figure_id": figure_id,
                "figure_url": pfocr_result["associatedWith"]["figureUrl"],
                "figure_title": pfocr_result["associatedWith"]["title"],
                "trapi_result_curie_combo": trapi_result_curie_combo,
                "figure_curie_combo": figure_curie_key,
                "overlap_curie_combo": tuple(sorted(common_curies)),
                "score": score,
            })


trapi_figure_overlap_df = pd.DataFrame.from_records(trapi_figure_overlap_rows)
trapi_figure_overlap_df
# Out:
#                                          figure_id  \
# 0            PMC7650600__cancers-12-02991-g008.jpg
# 1         PMC4914279__oncotarget-07-12206-g008.jpg
# 2       PMC7801429__41598_2020_79603_Fig2_HTML.jpg
# 3              PMC4538774__BMRI2015-949514.004.jpg
# 4                            PMC4753639__fig-9.jpg
# ...                                            ...
# 309332               PMC6016836__nihms951359f3.jpg
# 309333               PMC5407862__conc-24-111f2.jpg
# 309334                    PMC3117391__btr202f3.jpg
# 309335            PMC5681226__elife-25496-fig8.jpg
# 309336  PMC7801429__41598_2020_79603_Fig4_HTML.jpg
#
#                                                figure_url  \
# 0       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 1       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 2       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 3       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 4       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# ...                                                   ...
# 309332  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 309333  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 309334  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 309335  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 309336  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                              figure_title  \
# 0       KIR2DL2/L3/S2+ CD8+ T cell cluster analysis of...
# 1       Epidermal growth factor receptor regulates cof...
# 2       An ER signaling pathway network identified by ...
# 3       Representation of the adherens junction pathwa...
# 4       Targeting Tyrosine Kinase Inhibitor-Resistant ...
# ...                                                   ...
# 309332  Herpesvirus-encoded microRNAs detected in huma...
# 309333  Algorithm for the management of EGFR-mutated n...
# 309334  Pathway for getifinib and docetaxel to generat...
# 309335  Proposed gene regulatory network that controls...
# 309336  An ER signaling pathway network identified by ...
#
#                                trapi_result_curie_combo  \
# 0       (MESH:D000077204, NCBIGene:1956, NCBIGene:7454)
# 1       (MESH:D000077204, NCBIGene:1956, NCBIGene:7454)
# 2       (MESH:D000077204, NCBIGene:1956, NCBIGene:7454)
# 3       (MESH:D000077204, NCBIGene:1956, NCBIGene:7454)
# 4       (MESH:D000077204, NCBIGene:1956, NCBIGene:7454)
# ...                                                 ...
# 309332     (MESH:C067311, NCBIGene:1956, NCBIGene:7454)
# 309333     (MESH:C067311, NCBIGene:1956, NCBIGene:7454)
# 309334     (MESH:C067311, NCBIGene:1956, NCBIGene:7454)
# 309335     (MESH:C067311, NCBIGene:1956, NCBIGene:7454)
# 309336     (MESH:C067311, NCBIGene:1956, NCBIGene:7454)
#
#                                        figure_curie_combo  \
# 0       (MESH:C041654, MESH:C078661, MESH:D009369, MES...
# 1       (NCBIGene:1072, NCBIGene:1073, NCBIGene:11034,...
# 2       (NCBIGene:10174, NCBIGene:10657, NCBIGene:1097...
# 3       (MESH:D006153, NCBIGene:1000, NCBIGene:1001, N...
# 4       (MESH:C005705, MESH:C034758, MESH:C046557, MES...
# ...                                                   ...
# 309332  (MESH:D000255, NCBIGene:10096, NCBIGene:10316,...
# 309333  (MESH:C067311, MESH:C400278, MESH:C419708, MES...
# 309334  (MESH:C067311, MESH:C419708, NCBIGene:1432, NC...
# 309335  (NCBIGene:1956, NCBIGene:4790, NCBIGene:7124, ...
# 309336  (NCBIGene:1051, NCBIGene:10657, NCBIGene:1147,...
#
#                    overlap_curie_combo     score
# 0       (NCBIGene:1956, NCBIGene:7454)  0.666667
# 1       (NCBIGene:1956, NCBIGene:7454)  0.666667
# 2       (NCBIGene:1956, NCBIGene:7454)  0.666667
# 3       (NCBIGene:1956, NCBIGene:7454)  0.666667
# 4       (NCBIGene:1956, NCBIGene:7454)  0.666667
# ...                                ...       ...
# 309332  (NCBIGene:1956, NCBIGene:7454)  0.666667
# 309333   (MESH:C067311, NCBIGene:1956)  0.666667
# 309334   (MESH:C067311, NCBIGene:1956)  0.666667
# 309335  (NCBIGene:1956, NCBIGene:7454)  0.666667
# 309336  (NCBIGene:1956, NCBIGene:7454)  0.666667
#
# [309337 rows x 7 columns]

# %% [markdown]
# ### trapi_curie_combo_count_by_figure_df

# %%
trapi_curie_combo_count_by_figure_df = trapi_figure_overlap_df[["figure_id", "trapi_result_curie_combo"]].rename(columns={
    "trapi_result_curie_combo": "trapi_curie_combo_count"
}).groupby("figure_id").count().sort_values(
    by="trapi_curie_combo_count", ascending=False)
trapi_curie_combo_count_by_figure_df
# Out:
#                                            trapi_curie_combo_count
# figure_id
# PMC7263378__nihms-1585779-f0004.jpg                           5847
# PMC2642659__zpq9990969120002.jpg                              5505
# PMC4538774__BMRI2015-949514.004.jpg                           4954
# PMC5118094__nihms825299f7.jpg                                 4703
# PMC5501852__41598_2017_5280_Fig6_HTML.jpg                     4456
# ...                                                            ...
# PMC4878148__nihms710492f1.jpg                                    1
# PMC4877629__jn227496fig3.jpg                                     1
# PMC4877093__pone.0156002.g002.jpg                                1
# PMC4877005__pone.0155951.g002.jpg                                1
# PMC99013__mr0400030005.jpg                                       1
#
# [8960 rows x 1 columns]

# %% [markdown]
# ### Figure count by TRAPI CURIE combo

# %%
trapi_figure_overlap_df[["trapi_result_curie_combo", "figure_id"]].rename(columns={
    "figure_id": "figure_count"
}).groupby("trapi_result_curie_combo").count().sort_values(
    by="figure_count", ascending=False)
# Out:
#                                                 figure_count
# trapi_result_curie_combo
# (MESH:D002118, NCBIGene:5595, NCBIGene:7454)            1161
# (MESH:D002118, NCBIGene:5335, NCBIGene:7454)             928
# (NCBIGene:1950, NCBIGene:1956, NCBIGene:7454)            777
# (MESH:D002118, NCBIGene:207, NCBIGene:7454)              762
# (MESH:D000255, NCBIGene:207, NCBIGene:7454)              622
# ...                                                      ...
# (MESH:C499326, NCBIGene:51517, NCBIGene:7454)              1
# (MESH:C580998, NCBIGene:10097, NCBIGene:7454)              1
# (MESH:C580998, NCBIGene:10109, NCBIGene:7454)              1
# (MESH:C580998, NCBIGene:147179, NCBIGene:7454)             1
# (MESH:C532254, NCBIGene:11252, NCBIGene:7454)              1
#
# [13165 rows x 1 columns]

# %% [markdown]
# ### Figure containment score by TRAPI CURIE combo
#
# This can yield the same order of results, but if one TRAPI result has higher overlap of CURIEs with the figure(s), that TRAPI result could leapfrog over another TRAPI result that overlaps with more figures but at lower containment scores.
#
# Note the weakness of containment is it doesn't take into account the number of CURIEs in the figure.

# %%
trapi_result_figure_score_df = trapi_figure_overlap_df[["trapi_result_curie_combo", "score"]].rename(
    columns={"score": "cumulative_trapi_result_curie_combo_figure_score"}
).groupby("trapi_result_curie_combo").sum().sort_values(
    by="cumulative_trapi_result_curie_combo_figure_score", ascending=False)
trapi_result_figure_score_df
# Out:
#                                                 cumulative_trapi_result_curie_combo_figure_score
# trapi_result_curie_combo
# (MESH:D002118, NCBIGene:5595, NCBIGene:7454)                                          781.333333
# (MESH:D002118, NCBIGene:5335, NCBIGene:7454)                                          625.333333
# (NCBIGene:1950, NCBIGene:1956, NCBIGene:7454)                                         518.666667
# (MESH:D002118, NCBIGene:207, NCBIGene:7454)                                           509.666667
# (MESH:D000255, NCBIGene:207, NCBIGene:7454)                                           415.333333
# ...                                                                                          ...
# (MESH:C499326, NCBIGene:51517, NCBIGene:7454)                                           0.666667
# (MESH:C580998, NCBIGene:10097, NCBIGene:7454)                                           0.666667
# (MESH:C580998, NCBIGene:10109, NCBIGene:7454)                                           0.666667
# (MESH:C580998, NCBIGene:147179, NCBIGene:7454)                                          0.666667
# (MESH:C532254, NCBIGene:11252, NCBIGene:7454)                                           0.666667
#
# [13165 rows x 1 columns]

# %%
results_with_figures_df = trapi_figure_overlap_df.merge(
    results_df,
    on="trapi_result_curie_combo",
    how="left").merge(
    trapi_result_figure_score_df.reset_index(),
    on="trapi_result_curie_combo",
    how="left",
    validate="many_to_one"
).merge(
    trapi_curie_combo_count_by_figure_df.reset_index().rename(columns={
        "trapi_curie_combo_count": "trapi_curie_combo_count_by_figure"
    }),
    on="figure_id",
    how="left",
    validate="many_to_one"
).sort_values(
    by="cumulative_trapi_result_curie_combo_figure_score", ascending=False
)

# %% [markdown]
# ## Fisher's Exact Test
#
# ### TODO: vectorize
# For better performance, try vectorizing the calculation of Fisher's Exact test, e.g.:
#
# https://stackoverflow.com/questions/34947578/how-to-vectorize-fishers-exact-test

# %%
all_genes = set()
gene_instance_count = 0
all_chemicals = set()
chemical_instance_count = 0
all_diseases = set()
disease_instance_count = 0
for figure_id, pfocr_result in figure_id_to_pfocr_result.items():
    genes = pfocr_result["associatedWith"]["mentions"]["genes"]["ncbigene"]
    for gene in genes:
        gene_instance_count += 1
        all_genes.add(gene)
        
    chemicals = pfocr_result["associatedWith"]["mentions"]["chemicals"]["mesh"]
    for chemical in chemicals:
        chemical_instance_count += 1
        all_chemicals.add(chemical)
        
    diseases = pfocr_result["associatedWith"]["mentions"]["diseases"]["mesh"]
    for disease in diseases:
        disease_instance_count += 1
        all_diseases.add(disease)
    
print("total instance counts:")
print(f'  chemicals: {chemical_instance_count}')
print(f'  diseases: {disease_instance_count}')
print(f'  genes: {gene_instance_count}')

print("")

print("unique counts:")
print(f'  chemicals: {len(all_chemicals)}')
print(f'  diseases: {len(all_diseases)}')
print(f'  genes: {len(all_genes)}')

print("")

curie_category_to_curies = {
    "biolink:ChemicalEntity": all_chemicals,
    "biolink:SmallMolecule": all_chemicals,
    "biolink:Disease": all_diseases,
    "biolink:Gene": all_genes,
}


all_figure_curies = set()
for curie_category in set(curie_category_to_curies.keys()).intersection(curie_categories):
    all_figure_curies |= curie_category_to_curies[curie_category]
all_figure_curie_count = len(all_figure_curies)

print(f'M for Fisher Exact test: {all_figure_curie_count}')
print('TODO: should this number be based on what is in BTE/TRAPI?')
# Out:
# total instance counts:
#   chemicals: 275456
#   diseases: 20465
#   genes: 1369680
#
# unique counts:
#   chemicals: 14482
#   diseases: 1430
#   genes: 14253
#
# M for Fisher Exact test: 28735
# TODO: should this number be based on what is in BTE/TRAPI?

# %% [markdown]
# See [this contingency table](https://docs.google.com/spreadsheets/d/1d-48R5N0auuKXSLJ7oZ2E_ldO26Z5KiEH3AQx5kDrC4/edit#gid=0):
#
# |      |  |
# | ----------- | ----------- |
# | trapi_curies_in_pwy      | q_node_id_count - trapi_curies_in_pwy       |
# | curies_in_pwy - trapi_curies_in_pwy   | 28735 - curies_in_pwy - q_node_id_count + trapi_curies_in_pwy        |
#
# and [the scipy documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.fisher_exact.html):
#
# |      |  |
# | ----------- | ----------- |
# | x      | n - x       |
# | N - x   | M - (n + N) + x        |

# %%
# trapi_curies_in_pwy
# x
results_with_figures_df["yes_pwy_yes_trapi"] = (
    results_with_figures_df["overlap_curie_combo"].map(len)
)

# q_node_id_count - trapi_curies_in_pwy
# n - x
results_with_figures_df["no_pwy_yes_trapi"] = (
    len(q_node_ids) - results_with_figures_df["yes_pwy_yes_trapi"]
)

# curies_in_pwy - trapi_curies_in_pwy
# N - x
results_with_figures_df["yes_pwy_no_trapi"] = (
    results_with_figures_df["figure_curie_combo"].map(len) - 
    results_with_figures_df["yes_pwy_yes_trapi"]
)

# 28735 - curies_in_pwy - q_node_id_count + trapi_curies_in_pwy
# M - (n + N) + x
results_with_figures_df["no_pwy_no_trapi"] = (
    all_figure_curie_count -
    results_with_figures_df["figure_curie_combo"].map(len) -
    len(q_node_ids) +
    results_with_figures_df["yes_pwy_yes_trapi"]
)

# %%
import scipy.stats as stats


results_with_figures_df["fishers_exact"] = results_with_figures_df[
    ["yes_pwy_yes_trapi",
     "no_pwy_yes_trapi",
     "yes_pwy_no_trapi",
     "no_pwy_no_trapi"]
].apply(
    lambda r: stats.fisher_exact([[
        r.yes_pwy_yes_trapi,
        r.no_pwy_yes_trapi
    ], [
        r.yes_pwy_no_trapi,
        r.no_pwy_no_trapi,
    ]]),
    axis=1)

results_with_figures_df["p_value"] = results_with_figures_df["fishers_exact"].apply(
    lambda x: x[1]
)

# %%
results_with_figures_df["p_value"].sort_values()
# Out:
# 94417     2.529082e-13
# 94415     2.529082e-13
# 94416     2.529082e-13
# 94419     2.529082e-13
# 94420     2.529082e-13
#               ...
# 46090     4.786686e-04
# 46089     4.786686e-04
# 387757    4.786686e-04
# 32893     4.786686e-04
# 149783    4.786686e-04
# Name: p_value, Length: 542662, dtype: float64

# %% [markdown]
# ## Analysis of results with vs. without BTE Sleeve

# %% [markdown]
# With the current query graph, requiring co-occurrence of TRAPI result CURIE(s) for particular node(s) in at least one PFOCR figure cuts down the number of TRAPI result CURIE combos.

# %% [markdown]
# ### Without BTE Sleeve
#
# For the total number of TRAPI result CURIE combos returned, we're only
# including a combo when every CURIE in it can be unified. If any of the
# CURIEs in a combo cannot be unified, we drop that combo.

# %%
print(f'{len(set(results_df["trapi_result_curie_combo"]))} TRAPI results')
print(f'{len(figure_id_to_curies.keys())} figures')
# Out:
# 17467 TRAPI results
# 77719 figures

# %% [markdown]
# ### With BTE Sleeve
# The totals when the TRAPI result CURIE(s) for specified nodes must be found in at least one figure:

# %%
from itertools import combinations


for i in range(2, len(q_node_ids) + 1):
    for q_node_id_combination in combinations(q_node_ids, i):
        print(f'{" & ".join(q_node_id_combination)}')
        s = pd.Series([True] * len(results_with_figures_df), index=results_with_figures_df.index)
        for q_node_id in q_node_id_combination:
            s = s & results_with_figures_df.apply(
                lambda r: r[f'{q_node_id}_unified_curie'] in r["overlap_curie_combo"], axis=1
            )
        print(f'  {len(set(results_with_figures_df[s == True]["trapi_result_curie_combo"]))} TRAPI result(s)')
        print(f'  {len(set(results_with_figures_df[s == True]["figure_id"]))} figure(s)')
# Out:
# n0 & n1
#   12960 TRAPI result(s)
#   160 figure(s)
# n0 & n2
#   1026 TRAPI result(s)
#   156 figure(s)
# n1 & n2
#   2091 TRAPI result(s)
#   8842 figure(s)
# n0 & n1 & n2
#   111 TRAPI result(s)
#   88 figure(s)

# %% [markdown]
# ## View TRAPI results with figures
#
# Click a figure to get its paper.
#
# Compare these results with the `results_df` table from earlier in this notebook and also with the [ARAX UI](https://arax.ncats.io/) (copy the query into the JSON input field and reformat to make valid JSON).
#
# Does requiring co-occurrence for specific nodes like `n0` and `n2` help? Does ranking by p-value help?

# %% [markdown]
# ### co-occurrence: any two nodes

# %%
any_two_cooccurrence_df = results_with_figures_df.sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in any_two_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(any_two_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302074/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302074/bin/cdd464f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Yeast Cdc42 GTPase and Ste20 PAK-like...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5532371/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5532371/bin/41598_2017_6754_Fig8_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 A possible pathway for pre-...<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6758901/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6758901/bin/ns0526160001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Models of Cdc42 activation<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6328557/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6328557/bin/41467_2018_7998_Fig7_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 The mechanism of Mir20a/106a-WTX axis...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2773630/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2773630/bin/cshperspect-SYM-003384_F6.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Molecular interactions during pheromone...<br>
#                 p-value: 1.1e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6894087/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6894087/bin/fj.201900991Rf7.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic drawing that illustrates the...<br>
#                 p-value: 1.5e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 101 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2861543/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2861543/bin/fig-6.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Differential role for endocytosis in...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6895846/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6895846/bin/cancers-11-01736-g002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 ADAM17 is a membrane-bound...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7881399/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7881399/bin/GHFBB-13-S68-g006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Action relationships including activation...<br>
#                 p-value: 2.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6590709/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6590709/bin/nihms-1035910-f0006.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Glycosylation in health and disease<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6165231/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6165231/bin/ijms-19-02835-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Hedgehog (Hh) pathway activation<br>
#                 p-value: 4.0e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6042961/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6042961/bin/elife-35012-fig10.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 FRMD8 stabilises the iRhom2/ADAM17...<br>
#                 p-value: 4.0e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3939471/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3939471/bin/viruses-06-00535-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Involvement of CD81 in Hepatitis C Virus...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 206 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98914/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98914/bin/mr0280010012.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Signalling pathway for pseudohyphal growth<br>
#                 p-value: 4.4e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC25236/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC25236/bin/mk0180513007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Models for FLO11 action in the filamentous...<br>
#                 p-value: 7.3e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3785965/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3785965/bin/rstb20130015-g4.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 p120catenin regulation of Rho-GTPase...<br>
#                 p-value: 2.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2544441/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2544441/bin/zh00090857030003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Signaling pathway for the regulation of...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 67 more figures
#
# ...
#
# plus 13162 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in any_two_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-style: italic; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(any_two_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - Epothilone B</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - Epothilone B</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - Epothilone B</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - Epothilone B</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Dimethyl sulfoxide</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - N-(2,2,2-Trifluoroethyl)-N-{4-[2,2,2-trifluoro-1-hydroxy-1-(trifluoromethyl)ethyl]phenyl}benzenesulfonamide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - N-(2,2,2-Trifluoroethyl)-N-{4-[2,2,2-trifluoro-1-hydroxy-1-(trifluoromethyl)ethyl]phenyl}benzenesulfonamide</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Virulence Factors</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Virulence Factors</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Virulence Factors</span><br>
# <span
# ...
#
# plus 391 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - affects_response_to - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - decreases_activity_of - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_affected_by - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_decreased_by - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulated_by_entity - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - increases_response_to - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Icotinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - physically_interacts_with - Icotinib</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulated_by_entity - Androstanolone</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Androstanolone</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Androstanolone</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Rosiglitazone</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - correlated_with - PI-103</span>
# </div>
# ...
#
# plus 1055 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic representations of the components and signaling pathways induced by pathogens for activating the Arp2/3 complex-mediated actin rearrangements
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.0e-11, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - PI-103</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - PI-103</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - Tretinoin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Tretinoin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - Tretinoin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Tretinoin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Tretinoin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Tretinoin</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Silibinin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Silibinin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Silibinin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - Silibinin</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_resistance_to - Avagacestat</span>
# </div>
# ...
#
# plus 573 more TRAPI results
#
# ...
#
# plus 8957 more figures

# %% [markdown]
# ### co-occurrence: `n0` and (`n1` or `n2`)

# %%
n0_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: r.n0_unified_curie in set(r.overlap_curie_combo),
    axis=1
)].sort_values(
    "p_value"
)

# %%
print(len(set(results_with_figures_df["figure_id"])))
print(len(set(n0_cooccurrence_df["figure_id"])))
# Out:
# 8960
# 206

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 51 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/bin/oncotarget-07-12206-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Epidermal growth factor receptor regulates...<br>
#                 p-value: 2.5e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/bin/gr1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myosin 1c in cellular signaling pathways<br>
#                 p-value: 2.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/bin/nihms246275f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune and central nervous systems...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig4_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 3.8e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/bin/nihms951359f3.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Herpesvirus-encoded microRNAs detected in...<br>
#                 p-value: 5.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 16 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/bin/nihms114350f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Spatial Segregation of...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/bin/IJCB2012-501962.003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic of signaling pathways activated...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 1.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/bin/zbc0190834370009.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Several signaling pathways work together...<br>
#                 p-value: 2.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 47 more figures
#
# ...
#
# plus 13140 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-style: italic; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Dimethyl sulfoxide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Dimethyl sulfoxide</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Cocaine</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Cocaine</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - 2-[[(1R)-1-[7-Methyl-2-(4-morpholinyl)-4-oxo-4H-pyrido[1,2-a]pyrimidin-9-yl]ethyl]amino]benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - 2-[[(1R)-1-[7-Methyl-2-(4-morpholinyl)-4-oxo-4H-pyrido[1,2-a]pyrimidin-9-yl]ethyl]amino]benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - 2-[[(1R)-1-[7-Methyl-2-(4-morpholinyl)-4-oxo-4H-pyrido[1,2-a]pyrimidin-9-yl]ethyl]amino]benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - 2-[[(1R)-1-[7-Methyl-2-(4-morpholinyl)-4-oxo-4H-pyrido[1,2-a]pyrimidin-9-yl]ethyl]amino]benzoic acid</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Losartan</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Losartan</span>
# </div>
# ...
#
# plus 391 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - molecularly_interacts_with - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - molecular_modification_decreased_by - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_resistance_to - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - correlated_with - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_affected_by - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - molecular_interaction_increased_by - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_decreased_by - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - affects_response_to - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - coexists_with - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - decreases_activity_of - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - expression_decreased_by - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - decreases_response_to - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - increases_response_to - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_sensitivity_to - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - physically_interacts_with - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulated_by_entity - Gefitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - directly_interacts_with - Gefitinib</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_increased_by - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulates_entity - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulated_by_entity - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - coexists_with - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_positively_regulates_entity - Sirolimus</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Sirolimus</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-r
# ...
#
# plus 1055 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic representations of the components and signaling pathways induced by pathogens for activating the Arp2/3 complex-mediated actin rearrangements
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.0e-11, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - EGFR - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_sensitivity_to - AICA ribonucleotide</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_resistance_to - AICA ribonucleotide</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_sensitivity_to - Pyrimethamine</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - 2-Cyclopentyl-4-(5-phenyl-1H-pyrrolo[2,3-b]pyridin-3-yl)benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - 2-Cyclopentyl-4-(5-phenyl-1H-pyrrolo[2,3-b]pyridin-3-yl)benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_sensitivity_to - 2-Cyclopentyl-4-(5-phenyl-1H-pyrrolo[2,3-b]pyridin-3-yl)benzoic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - associated_with_resistance_to - 2-Cyclopentyl-4-(5-phenyl-1H-pyrrolo[2,3-b]pyridin-3-yl)benzoic acid</span>
# </div>
# ...
#
# plus 573 more TRAPI results
#
# ...
#
# plus 203 more figures

# %% [markdown]
# ### co-occurrence: `n0` and `n1`

# %%
n0_n1_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: (
        r.n0_unified_curie in set(r.overlap_curie_combo)
    ) and (
        r.n1_unified_curie in set(r.overlap_curie_combo)
    ),
    axis=1
)].sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_n1_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                  <img src="{figure_url}" style="height: {row_height}">
              </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_n1_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.3e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 45 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4753639/bin/fig-9.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Targeting Tyrosine Kinase Inhibitor-...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4914279/bin/oncotarget-07-12206-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Epidermal growth factor receptor regulates...<br>
#                 p-value: 2.5e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig4_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 3.8e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6016836/bin/nihms951359f3.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Herpesvirus-encoded microRNAs detected in...<br>
#                 p-value: 5.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7801429/bin/41598_2020_79603_Fig2_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 An ER signaling pathway network identified...<br>
#                 p-value: 1.2e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4257089/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4257089/bin/fimmu-05-00599-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 In silico modeling of a CD4+ T-cell<br>
#                 p-value: 1.6e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7650600/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7650600/bin/cancers-12-02991-g008.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 KIR2DL2/L3/S2+ CD8+ T cell cluster...<br>
#                 p-value: 1.7e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4439562/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4439562/bin/db141843f4.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 GPCR (or GPR) signaling in the regulation...<br>
#                 p-value: 2.1e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.2e-08,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5824968/bin/kcib-11-01-1381806-g001.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Model depicting NMJ structural...<br>
#                 p-value: 4.8e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8012622/bin/41598_2021_86799_Fig5_HTML.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Formation pathway of cytoskeleton...<br>
#                 p-value: 5.7e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6760864/bin/nihms-1037319-f0003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 New insights into cytoskeletal remodeling...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5858164/bin/thnov08p1511g007.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Working model of endothelial specific...<br>
#                 p-value: 7.6e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3296313/bin/IJCB2012-501962.003.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic of signaling pathways activated...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2771939/bin/nihms114350f1.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Spatial Segregation of...<br>
#                 p-value: 1.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 1.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/">
#                   <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2435243/bin/zbc0190834370009.jpg" style="height: 100px">
#               </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Several signaling pathways work together...<br>
#                 p-value: 2.2e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 45 more figures
#
# ...
#
# plus 12957 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_n1_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-style: italic; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_n1_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Nitrogen</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Nitrogen</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Cholesterol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - Cholesterol</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - derives_into - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulates_entity - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - RNA, Messenger</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px;
# ...
#
# plus 387 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_decreased_by - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_sensitivity_to - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - decreases_activity_of - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - activity_affected_by - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - interacts_with - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - directly_interacts_with - Pelitinib</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_resistance_to - Pelitinib</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_sensitivity_to - Salubrinal</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - associated_with_sensitivity_to - Rucaparib</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - entity_negatively_regulated_by_entity - Icaritin</span>
# </div>
# ...
#
# plus 1054 more TRAPI results
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic representations of the components and signaling pathways induced by pathogens for activating the Arp2/3 complex-mediated actin rearrangements
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.0e-11, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - ramucirumab</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - ramucirumab</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Quercetin</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity - Quercetin</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_sensitivity_to - (S)-4-(2-(4-Amino-1,2,5-oxadiazol-3-yl)-1-ethyl-7-(piperidin-3-ylmethoxy)-1H-imidazo[4,5-c]pyridin-4-yl)-2-methylbut-3-yn-2-ol</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">ACTC1</span>
#  - associated_with_resistance_to - (S)-4-(2-(4-Amino-1,2,5-oxadiazol-3-yl)-1-ethyl-7-(piperidin-3-ylmethoxy)-1H-imidazo[4,5-c]pyridin-4-yl)-2-methylbut-3-yn-2-ol</span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - 3-Cyclohexyl-1-propylsulfonic acid</span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity - 3-Cyclohexyl-1-propylsulfonic acid</span>
# </div>
# ...
#
# plus 563 more TRAPI results
#
# ...
#
# plus 157 more figures

# %% [markdown]
# ### co-occurrence: `n0` and `n2`

# %%
n0_n2_cooccurrence_df = results_with_figures_df[results_with_figures_df.apply(
    lambda r: (
        r.n0_unified_curie in set(r.overlap_curie_combo)
    ) and (
        r.n2_unified_curie in set(r.overlap_curie_combo)
    ),
    axis=1
)].sort_values(
    "p_value"
)

# %% [markdown]
# #### By TRAPI result

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 10

for trapi_result_curie_combo, df1 in n0_n2_cooccurrence_df.groupby("trapi_result_curie_combo", sort=False):
    trapi_curie_names = []
    for curie in df1["trapi_result_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        trapi_curie_names.append(name)

    cumulative_trapi_result_curie_combo_figure_score = list(set(
        df1["cumulative_trapi_result_curie_combo_figure_score"]
    ))[0]
    
    ordered_trapi_result_curie_combo = []
    for q_node_id in q_node_ids:
        ordered_trapi_result_curie_combo.append(list(set(
            df1[f"{q_node_id}_unified_curie"]
        ))[0])

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px;">
  <span>{", ".join(ordered_trapi_result_curie_combo)}</span> 
  <span>(cumulative containment score: {cumulative_trapi_result_curie_combo_figure_score:.2f})</span>
</div>
'''))

    overlap_names = []
    for curie in df1["overlap_curie_combo"].tolist()[0]:
        name = curie_to_name[curie]
        overlap_names.append(name)

    trapi_result_rows = []
    for i,row in df1[trapi_result_columns].drop_duplicates().iterrows():
        trapi_result_chunks = []
        for trapi_result_column in trapi_result_columns:
            row_value = row[trapi_result_column]
            if row_value in overlap_names:
                trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
            else:
                trapi_result_chunk = f'{row_value}'
            trapi_result_chunks.append(trapi_result_chunk)
        trapi_result_rows.append(
            f'{" - ".join(trapi_result_chunks)}'
        )
    trapi_result_row_count = len(trapi_result_rows)
    display(HTML(data=f'''
<div style="font-size: small;">
{"<br>".join(trapi_result_rows)}
</div>
'''))

    figures = []
    row_height='100px'
    for figure_id, df0 in df1.groupby("figure_id", sort=False):
        [pmc,filename] = figure_id.split("__")
        paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
        figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
        figure_title = list(set(df0["figure_title"]))[0]
        figure_title_limited = textwrap.shorten(figure_title, width=45, placeholder="...")

        p_value = list(set(
            df0["p_value"]
        ))[0]
        score = list(set(df0["score"]))[0]

        # TODO: why does the commented out block below not display correctly
        # on GitHub? The figcaption appears to the right of the image.
        # The div solution below is a kludge.
        figures.append(f'''
        <div style="margin: 5px !important; padding: 5px !important;>
            <figure style="margin: 5px !important;">
                <a target="_blank" href="{paper_url}">
                    <img src="{figure_url}" style="height: {row_height}">
                </a>
            </figure>
            <div style="font-size: x-small;">
                {figure_title_limited}<br>
                p-value: {p_value:.1e}, 
                containment: {score:.2}
            </div>
        </div>
        ''')
        
#        figures.append(f'''
#            <figure style="margin: 5px !important;">
#                <a target="_blank" href="{paper_url}">
#                  <img src="{figure_url}" style="height: {row_height}">
#                </a>
#                <figcaption style="font-size: small;">
#                      {figure_title_limited}<br>
#                      p-value: {p_value:.1e}, 
#                      containment: {score:.2}
#                </figcaption>
#            </figure>
#        ''')

    figure_count = len(figures)
    display(HTML(data=f'''
    <div style="display: flex; flex-flow: row wrap; text-align: center;">
    {''.join(figures[:display_count_limit])}
    </div>
'''))

    if figure_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {figure_count - display_count_limit} more figures")
        print("")


    count += 1
    if count >= limit:
        print("...")
        print("")
        remaining = len(set(n0_n2_cooccurrence_df["trapi_result_curie_combo"])) - limit
        print(f'plus {remaining} more TRAPI results')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D006153</span>
#   <span>(cumulative containment score: 75.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Engineering a genetically encoded,...<br>
#                 p-value: 2.5e-13,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3877165/bin/nihms490093f2.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic view of integration of TCR...<br>
#                 p-value: 2.5e-10,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4487197/bin/40303_2015_13_Fig2_HTML.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Ephrin receptor signaling pathway (genes...<br>
#                 p-value: 1.2e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4538774/bin/BMRI2015-949514.004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Representation of the adherens junction...<br>
#                 p-value: 4.3e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2642659/bin/zpq9990969120002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Visualization of molecular interaction and...<br>
#                 p-value: 2.6e-07,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3018310/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3018310/bin/GEN1871105f1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 F igure 1.—<br>
#                 p-value: 9.9e-07,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4508005/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4508005/bin/nihms-691992-f0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myoblast fusion during muscle development<br>
#                 p-value: 1.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1274246/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1274246/bin/1471-2121-6-24-1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 The purine nucleotide synthesis pathway in...<br>
#                 p-value: 1.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3408425/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3408425/bin/2993fig9.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Systems-level regulation of metabolic...<br>
#                 p-value: 1.2e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5749725/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5749725/bin/pone.0189887.g002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Identification of metastasis driver genes...<br>
#                 p-value: 3.0e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 1 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:1956, NCBIGene:7124</span>
#   <span>(cumulative containment score: 144.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Proposed gene regulatory network that...<br>
#                 p-value: 1.0e-12,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5501852/bin/41598_2017_5280_Fig6_HTML.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Interaction network of cancer cells and...<br>
#                 p-value: 4.0e-08,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3715701/bin/gr1.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Myosin 1c in cellular signaling pathways<br>
#                 p-value: 2.7e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2995293/bin/nihms246275f2.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune and central nervous systems...<br>
#                 p-value: 3.4e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6230871/bin/zh70091843040003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Genes altered in NHE1 transgenic hearts...<br>
#                 p-value: 5.1e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7210543/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7210543/bin/JIR2020-5649790.003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Scribble complex in immune cells<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3733802/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3733802/bin/pone.0071191.g002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Prioritizing Disease Candidate Proteins in...<br>
#                 p-value: 8.9e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7280878/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7280878/bin/nihpp-2003.14333v2-f0004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Target genes and pathways of COL-3 and...<br>
#                 p-value: 1.6e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7468567/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7468567/bin/f1000research-9-28930-g0003.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Target genes and pathways of COL-3 and...<br>
#                 p-value: 1.7e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 4 more figures
# <div style="border: 1px solid slategray; padding: 6px;">
#   <span>NCBIGene:7454, NCBIGene:998, MESH:D009584</span>
#   <span>(cumulative containment score: 51.67)</span>
# </div>
# <div style="font-size: small;">
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# <br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
#
# </div>
#     <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Schematic representations of the...<br>
#                 p-value: 3.0e-11,
#                 containment: 1.0
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7047328/bin/fimmu-11-00249-g0002.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Tryptophan breakdown via the kynurenine...<br>
#                 p-value: 6.6e-06,
#                 containment: 0.67
#             </div>
#         </div>
#
#         <div style="margin: 5px !important; padding: 5px !important;>
#             <figure style="margin: 5px !important;">
#                 <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3433902/">
#                     <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3433902/bin/zjw0051241270005.jpg" style="height: 100px">
#                 </a>
#             </figure>
#             <div style="font-size: x-small;">
#                 Immune response to phagosome in antigen...<br>
#                 p-value: 2.5e-05,
#                 containment: 0.67
#             </div>
#         </div>
#
#     </div>
# ...
#
# plus 1023 more TRAPI results

# %% [markdown]
# #### By figure

# %%
from IPython.display import Image
from IPython.core.display import HTML 


limit = 3
count = 0
display_count_limit = 5

for figure_id, raw_df in n0_n2_cooccurrence_df.groupby("figure_id", sort=False):
    df0 = raw_df.sort_values(
        "p_value"
    )
    [pmc,filename] = figure_id.split("__")
    paper_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/"
    figure_url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc}/bin/{filename}"
    figure_title = list(set(df0["figure_title"]))[0]

    display(HTML(data=f'''
<div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
  {figure_title}
</div>
<figure style="margin: 5px !important;">
    <a target="_blank" href="{paper_url}">
      <img src="{figure_url}" style="max-height: 500px; max-width: 100%;">
    </a>
</figure>
'''))

    trapi_results_row_sets = []
    for trapi_result_curie_combo, df1 in df0[
        trapi_result_columns + ["trapi_result_curie_combo", "overlap_curie_combo", "p_value", "score"]
    ].drop_duplicates().groupby("trapi_result_curie_combo", sort=False):
        overlap_names = []
        for curie in df1["overlap_curie_combo"].tolist()[0]:
            name = curie_to_name[curie]
            overlap_names.append(name)

        trapi_results_rows = []
        for i,row in df1.iterrows():
            trapi_result_chunks = []
            for trapi_result_column in trapi_result_columns:
                row_value = row[trapi_result_column]
                if row_value in overlap_names:
                    trapi_result_chunk = f'''
<span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">{row_value}</span>
'''
                else:
                    trapi_result_chunk = f'{row_value}'
                trapi_result_chunks.append(trapi_result_chunk)
                
            trapi_results_rows.append(
                f'{" - ".join(trapi_result_chunks)}</span>'
            )
            
        p_value = list(set(df1["p_value"]))[0]
        score = list(set(df1["score"]))[0]
        trapi_results_row_sets.append(f'''
<div>
    <span style="font-style: italic; font-size: small;">
      TRAPI result p-value: {p_value:.1e}, containment: {score:.2}
    </span><br>
    {"<br>".join(trapi_results_rows)}
</div>
''')

    trapi_results_row_set_count = len(trapi_results_row_sets)
    display(HTML(data="<br>".join(trapi_results_row_sets[:display_count_limit])))
    if trapi_results_row_set_count > display_count_limit:
        print(f"...")
        print("")
        print(f"plus {trapi_results_row_set_count - display_count_limit} more TRAPI results")
    print("")

    count += 1
    if count >= limit:
        print("...")
        print("")
        print(f'plus {len(set(n0_n2_cooccurrence_df["figure_id"])) - limit} more figures')
        print("")
        break
# Out:
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Engineering a genetically encoded, reversible light-controlled signaling system
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2525560/bin/zpq9990841850001.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.5e-13, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - produces -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity - WASF1 - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - WASF1 - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - RGS14 - interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - RAC1 - coexists_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 2.2e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - SRC - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Guanosine-5'-diphosphate</span>
# </span>
# </div>
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Proposed gene regulatory network that controls lymph gland rupture upon wasp parasitism
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5681226/bin/elife-25496-fig8.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 1.0e-12, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">EGFR</span>
#  - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 4.4e-08, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - WNK1 - has_part -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">TNF</span>
# </span>
# </div>
# <div style="border: 1px solid slategray; padding: 6px; font-weight: bold;">
#   Schematic representations of the components and signaling pathways induced by pathogens for activating the Arp2/3 complex-mediated actin rearrangements
# </div>
# <figure style="margin: 5px !important;">
#     <a target="_blank" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/">
#       <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC98722/bin/ii1010637004.jpg" style="max-height: 500px; max-width: 100%;">
#     </a>
# </figure>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.0e-11, containment: 1.0
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">CDC42</span>
#  - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity - RERE - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity - RHO - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span><br>
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - entity_positively_regulates_entity - RHO - entity_positively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - MAPK3 - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# <br>
# <div>
#     <span style="font-style: italic; font-size: small;">
#       TRAPI result p-value: 3.3e-07, containment: 0.67
#     </span><br>
#
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">WAS</span>
#  - genetically_interacts_with - RAC1 - entity_negatively_regulated_by_entity -
# <span style="border: 1px orange solid; padding: 1px; border-radius: 4px;">Nitrogen</span>
# </span>
# </div>
# ...
#
# plus 6 more TRAPI results
#
# ...
#
# plus 153 more figures

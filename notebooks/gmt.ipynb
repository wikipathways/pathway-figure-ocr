# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# # Export 2020-02-24 Results as GMT

# %%
from pprint import pprint
import json
import os
import tempfile
from pathlib import Path
import re
import sys

import numpy as np
import pandas as pd

import requests
import requests_cache

import rpy2

# %%
requests_cache.install_cache("pfocr_cache")

# %%
from rdf2pandas import rds2pandas

# %% [markdown]
# ## Import Data

# %%
# figures
pfocr_figures_rds_url = (
    "https://www.dropbox.com/s/qhc33zho78rnaoj/pfocr_figures.rds?dl=1"
)

with tempfile.NamedTemporaryFile(suffix=".rds") as f:
    pfocr_figures_rds_path = f.name
    with requests.get(pfocr_figures_rds_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)
    pfocr_figures_df = rds2pandas(pfocr_figures_rds_path)
pfocr_figures_df["figurl"] = (
    "https://www.ncbi.nlm.nih.gov/pmc/articles/"
    + pfocr_figures_df["pmcid"]
    + "/bin/"
    + pfocr_figures_df["filename"]
)
pfocr_figures_df
# Out:
#                                             figid    number  \
# 0      PMC5653847__41598_2017_14124_Fig8_HTML.jpg  Figure 8
# 1                PMC4187043__zh20191474070013.jpg   Fig. 13
# 2                PMC5746550__rsob-7-170228-g1.jpg  Figure 1
# 3               PMC4211692__pone.0110875.g008.jpg  Figure 8
# 4                    PMC2588433__nihms78212f8.jpg  Figure 8
# ...                                           ...       ...
# 64638            PMC4216988__zh20221474360006.jpg    Fig. 6
# 64639               PMC2873070__nihms128887f5.jpg  Scheme 1
# 64640        PMC3651446__pnas.1220523110fig06.jpg    Fig. 6
# 64641       PMC6770832__cancers-11-01236-g005.jpg  Figure 5
# 64642   PMC4609065__12885_2015_1721_Fig5_HTML.jpg    Fig. 5
#
#                                                  reftext  year  pathway_score  \
# 0       Céline Barthelemy, et al. Sci Rep. 2017;7:13816.  2017       0.968270
# 1      Yuan Wei, et al. Am J Physiol Renal Physiol. 2...  2014       0.965793
# 2      Georgia R. Frost, et al. Open Biol. 2017 Dec;7...  2017       0.962470
# 3      Enida Gjoni, et al. PLoS One. 2014;9(10):e110875.  2014       0.966721
# 4      Amanda L. Lewis, et al. J Biol Chem. ;282(38):...    NA       0.966758
# ...                                                  ...   ...            ...
# 64638  Marcelo D. Carattino, et al. Am J Physiol Rena...  2014       0.143076
# 64639  Hua Cheng, et al. Neurobiol Aging. ;31(7):1188...    NA       0.127176
# 64640  Jiun-Ming Wu, et al. Proc Natl Acad Sci U S A....  2013       0.055546
# 64641  Carmel Mothersill, et al. Cancers (Basel). 201...  2019       0.140041
# 64642    Hiro Takahashi, et al. BMC Cancer. 2015;15:718.  2015       0.090798
#
#        pmc_ranked_result_index  \
# 0                       133303
# 1                        79929
# 2                        98034
# 3                       142401
# 4                        67398
# ...                        ...
# 64638                   108774
# 64639                   143547
# 64640                   159643
# 64641                      618
# 64642                    20865
#
#                                                 figtitle  \
# 0      Model of FTY720-induced transporter endocytosi...
# 1      Proposed signaling pathway by which the stimul...
# 2                                         AŒ≤ production
# 3
# 4
# ...                                                  ...
# 64638  Hypothetical mechanism of activation of ENaC b...
# 64639  A schematic diagram of a proposed working mode...
# 64640  Models for nucleation of centrosomal and kinet...
# 64641  A simplified TGFŒ≤ pathway leading to p21 expr...
# 64642  Hypothetical model of EGFR and ANXA3 to fluoro...
#
#                                               papertitle  \
# 0      FTY720-induced endocytosis of yeast and human ...
# 1      Angiotensin II type 2 receptor regulates ROMK-...
# 2      The role of astrocytes in amyloid production a...
# 3      Glucolipotoxicity Impairs Ceramide Flow from t...
# 4      NeuA sialic acid O-acetylesterase activity mod...
# ...                                                  ...
# 64638  Prostasin interacts with the epithelial Na+ ch...
# 64639  Apolipoprotein E mediates sulfatide depletion ...
# 64640  Aurora kinase inhibitors reveal mechanisms of ...
# 64641  Relevance of Non-Targeted Effects for Radiothe...
# 64642  Construction of possible integrated predictive...
#
#                                                  caption  \
# 0      Model of FTY720-induced transporter endocytosi...
# 1      Proposed signaling pathway by which the stimul...
# 2      AŒ≤ production. In the amyloidogenic pathway (...
# 3      Glucolipotoxicity impairs CERT- and vesicular-...
# 4      Bacterial Sia biosynthesis can be divided into...
# ...                                                  ...
# 64638  Hypothetical mechanism of activation of ENaC b...
# 64639  A schematic diagram of a proposed working mode...
# 64640  Models for nucleation of centrosomal and kinet...
# 64641  A simplified TGFŒ≤ pathway leading to p21 expr...
# 64642  Hypothetical model of EGFR and ANXA3 to fluoro...
#
#                                                  figlink       pmcid  \
# 0                  /pmc/articles/PMC5653847/figure/Fig8/  PMC5653847
# 1                   /pmc/articles/PMC4187043/figure/F13/  PMC4187043
# 2          /pmc/articles/PMC5746550/figure/RSOB170228F1/  PMC5746550
# 3      /pmc/articles/PMC4211692/figure/pone-0110875-g...  PMC4211692
# 4                    /pmc/articles/PMC2588433/figure/F8/  PMC2588433
# ...                                                  ...         ...
# 64638                /pmc/articles/PMC4216988/figure/F6/  PMC4216988
# 64639                /pmc/articles/PMC2873070/figure/F5/  PMC2873070
# 64640             /pmc/articles/PMC3651446/figure/fig06/  PMC3651446
# 64641  /pmc/articles/PMC6770832/figure/cancers-11-012...  PMC6770832
# 64642              /pmc/articles/PMC4609065/figure/Fig5/  PMC4609065
#
#                              filename  \
# 0      41598_2017_14124_Fig8_HTML.jpg
# 1                zh20191474070013.jpg
# 2                rsob-7-170228-g1.jpg
# 3               pone.0110875.g008.jpg
# 4                    nihms78212f8.jpg
# ...                               ...
# 64638            zh20221474360006.jpg
# 64639               nihms128887f5.jpg
# 64640        pnas.1220523110fig06.jpg
# 64641       cancers-11-01236-g005.jpg
# 64642   12885_2015_1721_Fig5_HTML.jpg
#
#                                                 source_f type.man  \
# 0      ../data/images/PMC5653847__41598_2017_14124_Fi...       NA
# 1        ../data/images/PMC4187043__zh20191474070013.jpg       NA
# 2        ../data/images/PMC5746550__rsob-7-170228-g1.jpg       NA
# 3       ../data/images/PMC4211692__pone.0110875.g008.jpg       NA
# 4            ../data/images/PMC2588433__nihms78212f8.jpg       NA
# ...                                                  ...      ...
# 64638    ../data/images/PMC4216988__zh20221474360006.jpg  pathway
# 64639       ../data/images/PMC2873070__nihms128887f5.jpg  pathway
# 64640  ../data/images/PMC3651446__pnas.1220523110fig0...  pathway
# 64641  ../data/images/PMC6770832__cancers-11-01236-g0...  pathway
# 64642  ../data/images/PMC4609065__12885_2015_1721_Fig...  pathway
#
#        automl_index                                             figurl
# 0              3012  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 1              4323  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 2              6334  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 3              3808  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 4              3790  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# ...             ...                                                ...
# 64638         77324  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 64639         78813  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 64640        114977  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 64641         77606  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 64642         84038  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
#
# [64643 rows x 16 columns]

# %%
# genes
pfocr_genes_rds_url = "https://www.dropbox.com/s/alf7auvxve36oer/pfocr_genes.rds?dl=1"

with tempfile.NamedTemporaryFile(suffix=".rds") as f:
    pfocr_genes_rds_path = f.name
    with requests.get(pfocr_genes_rds_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)
    pfocr_genes_df = rds2pandas(pfocr_genes_rds_path)
pfocr_genes_df
# Out:
#                                figid      pmcid      word     symbol  \
# 0        PMC100003__mb2410470011.jpg  PMC100003  Ga12,Gaq  G-ALPHA-q
# 1        PMC100003__mb2410470011.jpg  PMC100003       Etk        ETK
# 2        PMC100003__mb2410470011.jpg  PMC100003       FAK        FAK
# 3        PMC100003__mb2410470011.jpg  PMC100003       AR*         AR
# 4        PMC100003__mb2410470011.jpg  PMC100003      (Src        SRC
# ...                              ...        ...       ...        ...
# 1112546   PMC99976__mb2310138007.jpg   PMC99976     MEK-2       MEK2
# 1112547   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112548   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112549   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112550   PMC99976__mb2310138007.jpg   PMC99976     SOS-1       SOS1
#
#                      source hgnc_symbol  entrez
# 0         hgnc_alias_symbol        GNAQ    2776
# 1         hgnc_alias_symbol         BMX     660
# 2         hgnc_alias_symbol        PTK2    5747
# 3               hgnc_symbol          AR     367
# 4               hgnc_symbol         SRC    6714
# ...                     ...         ...     ...
# 1112546   hgnc_alias_symbol      MAP2K2    5605
# 1112547  bioentities_symbol        HRAS    3265
# 1112548  bioentities_symbol        KRAS    3845
# 1112549  bioentities_symbol        NRAS    4893
# 1112550         hgnc_symbol        SOS1    6654
#
# [1112551 rows x 7 columns]

# %%
# nobe_counts
pfocr_nobe_counts_rds_url = (
    "https://www.dropbox.com/s/pd8n5hs4vrvb4st/pfocr_nobe_counts.rds?dl=1"
)

with tempfile.NamedTemporaryFile(suffix=".rds") as f:
    pfocr_nobe_counts_rds_path = f.name
    with requests.get(pfocr_nobe_counts_rds_url, stream=True) as r:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
        f.seek(0)
    pfocr_nobe_counts_df = rds2pandas(pfocr_nobe_counts_rds_path)
pfocr_nobe_counts_df
# Out:
#                                 figid  nobe_count  entrez_count
# 0         PMC100003__mb2410470011.jpg           5             5
# 1         PMC100005__mb2410575011.jpg           6            16
# 2         PMC100008__mb2411709009.jpg           8            52
# 3      PMC101225__1475-2867-1-1-1.jpg           1             1
# 4             PMC101242__gkf20707.jpg          13            13
# ...                               ...         ...           ...
# 58957      PMC99889__mb2110211013.jpg          12            22
# 58958      PMC99903__mb2110106008.jpg           1             1
# 58959      PMC99957__mb2310813001.jpg          10            10
# 58960      PMC99957__mb2310813011.jpg           2             2
# 58961      PMC99976__mb2310138007.jpg           4            14
#
# [58962 rows x 3 columns]

# %%
# merge the dfs to get pfocr analysis set
pfocr_df = (
    (
        pfocr_figures_df.join(
            pfocr_genes_df.drop(columns=["pmcid"]).set_index("figid"),
            on="figid",
            how="inner",
        ).join(
            pfocr_nobe_counts_df.set_index("figid"), on="figid", how="inner",
        )
    )
    .sort_values(["year", "pmcid", "figid", "entrez"])
    .reset_index(drop=True)
)
pfocr_df
# Out:
#                                             figid  number  \
# 0                     PMC1201394__nihms3677f4.jpg  Fig. 4
# 1                     PMC1201394__nihms3677f4.jpg  Fig. 4
# 2                     PMC1201394__nihms3677f4.jpg  Fig. 4
# 3                     PMC1201394__nihms3677f4.jpg  Fig. 4
# 4                     PMC1201394__nihms3677f4.jpg  Fig. 4
# ...                                           ...     ...
# 1112546  PMC6906418__12276_2019_299_Fig2_HTML.jpg  Fig. 2
# 1112547  PMC6906418__12276_2019_299_Fig2_HTML.jpg  Fig. 2
# 1112548  PMC6906418__12276_2019_299_Fig2_HTML.jpg  Fig. 2
# 1112549  PMC6906418__12276_2019_299_Fig2_HTML.jpg  Fig. 2
# 1112550  PMC6906418__12276_2019_299_Fig2_HTML.jpg  Fig. 2
#
#                                                    reftext  year  \
# 0        Marissa J. Carstens, et al. J Biol Chem. ;279(...    NA
# 1        Marissa J. Carstens, et al. J Biol Chem. ;279(...    NA
# 2        Marissa J. Carstens, et al. J Biol Chem. ;279(...    NA
# 3        Marissa J. Carstens, et al. J Biol Chem. ;279(...    NA
# 4        Marissa J. Carstens, et al. J Biol Chem. ;279(...    NA
# ...                                                    ...   ...
# 1112546  Hyun-Cheol Lee, et al. Exp Mol Med. 2019 Dec;5...  2019
# 1112547  Hyun-Cheol Lee, et al. Exp Mol Med. 2019 Dec;5...  2019
# 1112548  Hyun-Cheol Lee, et al. Exp Mol Med. 2019 Dec;5...  2019
# 1112549  Hyun-Cheol Lee, et al. Exp Mol Med. 2019 Dec;5...  2019
# 1112550  Hyun-Cheol Lee, et al. Exp Mol Med. 2019 Dec;5...  2019
#
#          pathway_score  pmc_ranked_result_index figtitle  \
# 0             0.894122                    38017
# 1             0.894122                    38017
# 2             0.894122                    38017
# 3             0.894122                    38017
# 4             0.894122                    38017
# ...                ...                      ...      ...
# 1112546       0.828043                    65444
# 1112547       0.828043                    65444
# 1112548       0.828043                    65444
# 1112549       0.828043                    65444
# 1112550       0.828043                    65444
#
#                                                 papertitle  \
# 0        Cell Cycle Arrest and Cell Death Are Controlle...
# 1        Cell Cycle Arrest and Cell Death Are Controlle...
# 2        Cell Cycle Arrest and Cell Death Are Controlle...
# 3        Cell Cycle Arrest and Cell Death Are Controlle...
# 4        Cell Cycle Arrest and Cell Death Are Controlle...
# ...                                                    ...
# 1112546  Intracellular sensing of viral genomes and vir...
# 1112547  Intracellular sensing of viral genomes and vir...
# 1112548  Intracellular sensing of viral genomes and vir...
# 1112549  Intracellular sensing of viral genomes and vir...
# 1112550  Intracellular sensing of viral genomes and vir...
#
#                                                    caption  \
# 0        A, Mdm2 is negatively regulated by p19Arf. As ...
# 1        A, Mdm2 is negatively regulated by p19Arf. As ...
# 2        A, Mdm2 is negatively regulated by p19Arf. As ...
# 3        A, Mdm2 is negatively regulated by p19Arf. As ...
# 4        A, Mdm2 is negatively regulated by p19Arf. As ...
# ...                                                    ...
# 1112546  Schematic presentation of positive and negativ...
# 1112547  Schematic presentation of positive and negativ...
# 1112548  Schematic presentation of positive and negativ...
# 1112549  Schematic presentation of positive and negativ...
# 1112550  Schematic presentation of positive and negativ...
#
#                                        figlink  ... type.man automl_index  \
# 0          /pmc/articles/PMC1201394/figure/F4/  ...       NA        39679
# 1          /pmc/articles/PMC1201394/figure/F4/  ...       NA        39679
# 2          /pmc/articles/PMC1201394/figure/F4/  ...       NA        39679
# 3          /pmc/articles/PMC1201394/figure/F4/  ...       NA        39679
# 4          /pmc/articles/PMC1201394/figure/F4/  ...       NA        39679
# ...                                        ...  ...      ...          ...
# 1112546  /pmc/articles/PMC6906418/figure/Fig2/  ...       NA        50139
# 1112547  /pmc/articles/PMC6906418/figure/Fig2/  ...       NA        50139
# 1112548  /pmc/articles/PMC6906418/figure/Fig2/  ...       NA        50139
# 1112549  /pmc/articles/PMC6906418/figure/Fig2/  ...       NA        50139
# 1112550  /pmc/articles/PMC6906418/figure/Fig2/  ...       NA        50139
#
#                                                     figurl     word  symbol  \
# 0        https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...  (Cdkn2a  CDKN2A
# 1        https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...  p19/Arf     ARF
# 2        https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...     G1/S      Gs
# 3        https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...     G1/S      Gs
# 4        https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...     Mdm2    MDM2
# ...                                                    ...      ...     ...
# 1112546  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...   TRIM41  TRIM41
# 1112547  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...   RNF185  RNF185
# 1112548  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...     CGAS    CGAS
# 1112549  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...    TTLL6   TTLL6
# 1112550  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...    STING   STING
#
#                      source hgnc_symbol  entrez nobe_count entrez_count
# 0               hgnc_symbol      CDKN2A    1029          6            7
# 1         hgnc_alias_symbol      CDKN2A    1029          6            7
# 2        bioentities_symbol        GNAL    2774          6            7
# 3        bioentities_symbol        GNAS    2778          6            7
# 4               hgnc_symbol        MDM2    4193          6            7
# ...                     ...         ...     ...        ...          ...
# 1112546         hgnc_symbol      TRIM41   90933         24           28
# 1112547         hgnc_symbol      RNF185   91445         24           28
# 1112548         hgnc_symbol        CGAS  115004         24           28
# 1112549         hgnc_symbol       TTLL6  284076         24           28
# 1112550   hgnc_alias_symbol     TMEM173  340061         24           28
#
# [1112551 rows x 23 columns]

# %%
gene_counts_df = (
    pfocr_df[["figid", "entrez"]]
    .drop_duplicates()
    .groupby("figid")
    .count()
    .rename(columns={"entrez": "unique_gene_count"})
)
print(len(gene_counts_df))
pfocr_df = pfocr_df.join(gene_counts_df, on="figid")
# Out:
# 58962

# %% [markdown]
# Limit to figures having 10 or more unique genes.

# %%
cutoff_pfocr_df = pfocr_df[pfocr_df["unique_gene_count"] >= 10][
    ["figid", "figtitle", "entrez"]
].drop_duplicates()
cutoff_pfocr_df
# Out:
#                                             figid  \
# 16                    PMC1249490__nihms5296f3.jpg
# 17                    PMC1249490__nihms5296f3.jpg
# 18                    PMC1249490__nihms5296f3.jpg
# 19                    PMC1249490__nihms5296f3.jpg
# 20                    PMC1249490__nihms5296f3.jpg
# ...                                           ...
# 1112546  PMC6906418__12276_2019_299_Fig2_HTML.jpg
# 1112547  PMC6906418__12276_2019_299_Fig2_HTML.jpg
# 1112548  PMC6906418__12276_2019_299_Fig2_HTML.jpg
# 1112549  PMC6906418__12276_2019_299_Fig2_HTML.jpg
# 1112550  PMC6906418__12276_2019_299_Fig2_HTML.jpg
#
#                                                   figtitle  entrez
# 16       The primary targets of lithium in the cell are...    2774
# 17       The primary targets of lithium in the cell are...    2778
# 18       The primary targets of lithium in the cell are...    5330
# 19       The primary targets of lithium in the cell are...    5331
# 20       The primary targets of lithium in the cell are...    5332
# ...                                                    ...     ...
# 1112546                                                      90933
# 1112547                                                      91445
# 1112548                                                     115004
# 1112549                                                     284076
# 1112550                                                     340061
#
# [969257 rows x 3 columns]

# %%
print(len(cutoff_pfocr_df["figid"].unique()))
print(len(cutoff_pfocr_df["figtitle"].unique()))
print(len(cutoff_pfocr_df["entrez"].unique()))
# Out:
# 32277
# 23450
# 13153

# %% [markdown]
# ## Export GMT

# %% [markdown]
# [GMT format description](https://software.broadinstitute.org/cancer/software/gsea/wiki/index.php/Data_formats#GMT:_Gene_Matrix_Transposed_file_format_.28.2A.gmt.29).
#
# Sample of what we want:
# ```
# PMC100005__mb2410575011.jpg     Formation of TrkA–src-aPKC complexes    5293    5294    25759   6714    8503    4914    10818   399694  30849   7189      23533   5290    6464    146850  53358   5291
# ```

# %% [markdown]
# TODO: there are some characters that could mess up the parsing of a GMT. For example, a `%` or a `\t` would be parsed as a delimiter. Also, if a doublequote `"` can be used to enclose fields with characters like spaces, then a title containing a doublequote would mess up a parser.
#
# In those cases, do we want to escape the special characters or remove them?

# %%
def genes_to_gmt(df):
    return df["entrez"].astype("str").str.cat(sep="\t")

# %%
gmt_df = (
    cutoff_pfocr_df[["figid", "figtitle"]]
    .drop_duplicates()
    .set_index("figid")
    .copy(deep=True)
)
gmt_df["genes"] = (
    cutoff_pfocr_df.set_index("figid")
    .groupby("figid")
    .apply(lambda x: x["entrez"].astype("str").to_list())
)
gmt_df["genes_str"] = (
    cutoff_pfocr_df.set_index("figid").groupby("figid").apply(genes_to_gmt)
)
gmt_df = gmt_df.fillna("")

gmt_df
# Out:
#                                                                                    figtitle  \
# figid
# PMC1249490__nihms5296f3.jpg               The primary targets of lithium in the cell are...
# PMC1307498__nihms5498f3.jpg               Schematic model of insulin-stimulated glucose ...
# PMC1307511__nihms2079f3.jpg
# PMC1351030__nihms2404f8.jpg               A model of signaling pathway from oncogenic H-...
# PMC1352153__nihms-7536-0007.jpg               Model for GalR1 neuroplasticity within the LC
# ...                                                                                     ...
# PMC6904862__WJSC-11-1104-g003.jpg         Biomechanical stress stimulates the mechanosen...
# PMC6904864__WJSC-11-1084-g001.jpg         Small molecules guiding mesenchymal stem cell ...
# PMC6905007__40246_2019_252_Fig2_HTML.jpg  LRF/ZBTB7A‚Äôs silencing compromises Warburg e...
# PMC6906418__12276_2019_299_Fig1_HTML.jpg
# PMC6906418__12276_2019_299_Fig2_HTML.jpg
#
#                                                                                       genes  \
# figid
# PMC1249490__nihms5296f3.jpg               [2774, 2778, 5330, 5331, 5332, 5333, 5335, 533...
# PMC1307498__nihms5498f3.jpg               [207, 208, 3667, 5163, 5164, 5165, 5166, 5290,...
# PMC1307511__nihms2079f3.jpg               [317, 834, 835, 836, 837, 838, 839, 840, 841, ...
# PMC1351030__nihms2404f8.jpg               [595, 688, 1432, 1958, 3265, 5594, 5595, 5599,...
# PMC1352153__nihms-7536-0007.jpg           [466, 1385, 1386, 1390, 2587, 4236, 5566, 5567...
# ...                                                                                     ...
# PMC6904862__WJSC-11-1104-g003.jpg         [207, 208, 1432, 5594, 5595, 5599, 5600, 5601,...
# PMC6904864__WJSC-11-1084-g001.jpg         [207, 208, 649, 650, 651, 652, 653, 654, 655, ...
# PMC6905007__40246_2019_252_Fig2_HTML.jpg  [355, 596, 834, 835, 836, 837, 838, 839, 840, ...
# PMC6906418__12276_2019_299_Fig1_HTML.jpg  [834, 835, 836, 837, 838, 839, 840, 841, 842, ...
# PMC6906418__12276_2019_299_Fig2_HTML.jpg  [207, 208, 1147, 3439, 3551, 3661, 3665, 4790,...
#
#                                                                                   genes_str
# figid
# PMC1249490__nihms5296f3.jpg               2774\t2778\t5330\t5331\t5332\t5333\t5335\t5336...
# PMC1307498__nihms5498f3.jpg               207\t208\t3667\t5163\t5164\t5165\t5166\t5290\t...
# PMC1307511__nihms2079f3.jpg               317\t834\t835\t836\t837\t838\t839\t840\t841\t8...
# PMC1351030__nihms2404f8.jpg               595\t688\t1432\t1958\t3265\t5594\t5595\t5599\t...
# PMC1352153__nihms-7536-0007.jpg           466\t1385\t1386\t1390\t2587\t4236\t5566\t5567\...
# ...                                                                                     ...
# PMC6904862__WJSC-11-1104-g003.jpg         207\t208\t1432\t5594\t5595\t5599\t5600\t5601\t...
# PMC6904864__WJSC-11-1084-g001.jpg         207\t208\t649\t650\t651\t652\t653\t654\t655\t6...
# PMC6905007__40246_2019_252_Fig2_HTML.jpg  355\t596\t834\t835\t836\t837\t838\t839\t840\t8...
# PMC6906418__12276_2019_299_Fig1_HTML.jpg  834\t835\t836\t837\t838\t839\t840\t841\t842\t8...
# PMC6906418__12276_2019_299_Fig2_HTML.jpg  207\t208\t1147\t3439\t3551\t3661\t3665\t4790\t...
#
# [32277 rows x 3 columns]

# %% [markdown]
# Let's export the GMT file. The paths match AR's system, but you'll need to update them if yours aren't the same.

# %%
dropbox_dir = Path("~/Dropbox (Gladstone)").expanduser().resolve()
paper_dir = dropbox_dir.joinpath("Documents/PFOCR_25Years").expanduser().resolve()
data_dir = paper_dir
# data_dir = paper_dir.joinpath("raw")

if not data_dir.exists():
    tmp_dir = tempfile.TemporaryDirectory()
    # can explicitly remove tmp_dir with tmp_dir.cleanup()
    data_dir = Path(tmp_dir.name)

gmt_path = data_dir.joinpath("pfocr_curated.gmt")

with open(gmt_path, "w") as gmt_f:
    for figid, row in gmt_df.iterrows():
        gmt_f.write("\t".join([figid, row["figtitle"], row["genes_str"],]))
        gmt_f.write("\n")

print(f"Output saved: {gmt_path}")
# Out:
# Output saved: /home/ariutta/Dropbox (Gladstone)/Documents/PFOCR_25Years/pfocr_curated.gmt

# %%
ar_gmt_df = gmt_df.reset_index()

# %%
ap_gmt_path = paper_dir.joinpath("raw/pfocr_curated_ap.gmt")
ap_gmt_data = list()
with open(ap_gmt_path, "r") as gmt_f:
    for line in gmt_f:
        chunks = line.strip().split("\t")
        figid = chunks.pop(0)
        figtitle = chunks.pop(0)
        genes = chunks
        ap_gmt_data.append({"figid": figid, "figtitle": figtitle, "genes": genes})
ap_gmt_df = pd.DataFrame.from_records(ap_gmt_data)
ap_gmt_df
# Out:
#                              figid  \
# 0      PMC100005__mb2410575011.jpg
# 1      PMC100008__mb2411709009.jpg
# 2          PMC101242__gkf20707.jpg
# 3      PMC101600__ac1100359003.jpg
# 4      PMC102186__mb2400926009.jpg
# ...                            ...
# 32274   PMC99537__jb1610128005.jpg
# 32275   PMC99857__mb2010895009.jpg
# 32276   PMC99889__mb2110211013.jpg
# 32277   PMC99957__mb2310813001.jpg
# 32278   PMC99976__mb2310138007.jpg
#
#                                                 figtitle  \
# 0                   Formation of TrkA–src-aPKC complexes
# 1      Cooperation between Beta-AR and B2R signaling ...
# 2          Up-regulation of RAD51 in 8-MOP-treated cells
# 3      Hypothetical biosynthetic pathway of coumermyc...
# 4                        Ras-mediated signaling pathways
# ...                                                  ...
# 32274                      Basic metabolic pathways in C
# 32275  The B(a)P-induced apoptotic signaling pathway,...
# 32276           Erk activation following TCR stimulation
# 32277                             Purine metabolism in S
# 32278                      EGL-15/FGFR signaling pathway
#
#                                                    genes
# 0      [5293, 5294, 25759, 6714, 8503, 4914, 10818, 3...
# 1      [5331, 5576, 51196, 23236, 5567, 5566, 107, 11...
# 2      [5883, 5980, 11200, 5893, 10111, 5888, 546, 47...
# 3      [125965, 84701, 1327, 10063, 1352, 1353, 1351,...
# 4      [6300, 5602, 6300, 5879, 5058, 5062, 57144, 58...
# ...                                                  ...
# 32274  [23038, 4236, 10603, 788, 5885, 9126, 6576, 12...
# 32275  [9459, 64374, 837, 100506742, 23581, 834, 835,...
# 32276  [5594, 5595, 2885, 7535, 5604, 27040, 5327, 39...
# 32277  [23038, 4236, 355, 22978, 5471, 2987, 1015, 83...
# 32278  [1432, 5594, 5595, 5599, 5600, 5601, 5602, 560...
#
# [32279 rows x 3 columns]

# %% [markdown]
# The results from AP and from AR are not identical matches.

# %%
weird_ap = set(ap_gmt_df["figid"]) - set(ar_gmt_df["figid"])
print(len(weird_ap))
weird_ar = set(ar_gmt_df["figid"]) - set(ap_gmt_df["figid"])
print(len(weird_ar))
# Out:
# 311
# 309

# %% [markdown]
# Sample of results in AP but not in AR.

# %%
ap_gmt_df[ap_gmt_df["figid"].isin(weird_ap)].head()
# Out:
#                                 figid  \
# 15   PMC1069556__zjv0080560770006.jpg
# 19        PMC107855__ii0180505007.jpg
# 263           PMC140507__gkg141f1.jpg
# 290             PMC1435660__75f8c.jpg
# 405      PMC1544360__nihms10600f7.jpg
#
#                                               figtitle  \
# 15   Effect of NS5A on the Beta-catenin signaling p...
# 19             Influence of OdDHL on the immune system
# 263                    The PI 3-kinase pathway by RNAi
# 290                         Hypothetical model for HHT
# 405  Simplified repression model of angptl3 promote...
#
#                                                  genes
# 15   [7008, 2932, 572, 9733, 1499, 2308, 10000, 207...
# 19   [3592, 3576, 3458, 3664, 3553, 3593, 3439, 712...
# 263  [5601, 5599, 207, 5602, 5601, 5163, 5599, 5728...
# 290  [7043, 94, 7046, 94, 7042, 2022, 51175, 7046, ...
# 405  [6256, 9612, 6257, 6258, 10062, 9612, 6256, 87...

# %% [markdown]
# Sample of results in AR but not in AP.

# %%
ar_gmt_df[ar_gmt_df["figid"].isin(weird_ar)].head()
# Out:
#                                  figid  \
# 151  PMC2254938__nihms-38751-f0001.jpg
# 194  PMC2398704__nihms-47534-f0003.jpg
# 241       PMC2529154__nihms62767f4.jpg
# 300       PMC2585776__nihms70500f3.jpg
# 301       PMC2585776__nihms70500f5.jpg
#
#                                               figtitle  \
# 151
# 194  Variation the insulin/insulin-like (IIS) pathw...
# 241  Proposed biosynthetic pathway for MDP chromoph...
# 300
# 301
#
#                                                  genes  \
# 151  [207, 208, 3265, 3667, 3845, 4893, 8471, 8660,...
# 194  [207, 948, 3479, 3667, 5163, 5164, 5165, 5166,...
# 241  [712, 713, 714, 715, 716, 717, 718, 727, 729, ...
# 300  [1432, 2353, 5594, 5595, 5599, 5600, 5601, 560...
# 301  [1432, 2353, 5594, 5595, 5599, 5600, 5601, 560...
#
#                                              genes_str
# 151  207\t208\t3265\t3667\t3845\t4893\t8471\t8660\t...
# 194  207\t948\t3479\t3667\t5163\t5164\t5165\t5166\t...
# 241  712\t713\t714\t715\t716\t717\t718\t727\t729\t7...
# 300  1432\t2353\t5594\t5595\t5599\t5600\t5601\t5602...
# 301  1432\t2353\t5594\t5595\t5599\t5600\t5601\t5602...

# %%
ap_gmt_df[ap_gmt_df["figid"].isin(weird_ap)]["genes"].apply(len).max()
ap_gmt_df["genes"].apply(len).max()
# Out:
# 385

# %% [markdown]
# The results from AP include some cases where entrez ids are duplicated.

# %%
ap_gmt_df["unique_genes"] = ap_gmt_df["genes"].apply(lambda x: list(set(x)))
ap_gmt_df[ap_gmt_df["genes"].apply(len) != ap_gmt_df["unique_genes"].apply(len)].head()
# Out:
#                             figid  \
# 2         PMC101242__gkf20707.jpg
# 4     PMC102186__mb2400926009.jpg
# 5     PMC104390__mb0691873009.jpg
# 9   PMC1052008__JCI0524178.f2.jpg
# 12    PMC106275__am0681773006.jpg
#
#                                              figtitle  \
# 2       Up-regulation of RAD51 in 8-MOP-treated cells
# 4                     Ras-mediated signaling pathways
# 5   Proposed model for translational homeostasis i...
# 9   Gq/11-activated pathways in maladaptive hypert...
# 12       Analysis of the region between styR and styA
#
#                                                 genes  \
# 2   [5883, 5980, 11200, 5893, 10111, 5888, 546, 47...
# 4   [6300, 5602, 6300, 5879, 5058, 5062, 57144, 58...
# 5   [5293, 8503, 2475, 5291, 5464, 30849, 146850, ...
# 9   [5331, 5534, 5332, 5579, 23683, 5587, 5533, 55...
# 12  [55811, 196883, 107, 108, 112, 115, 114, 113, ...
#
#                                          unique_genes
# 2   [2521, 546, 545, 10111, 5980, 5893, 472, 5883,...
# 4   [391, 5062, 5605, 3845, 10298, 56924, 3725, 56...
# 5   [5290, 208, 8503, 5464, 23533, 207, 5293, 5291...
# 9   [5590, 5330, 5583, 5579, 5532, 5578, 23683, 55...
# 12  [113, 90527, 196883, 107, 108, 55811, 112, 263...

# %%
sorted(
    ap_gmt_df[ap_gmt_df["genes"].apply(len) != ap_gmt_df["unique_genes"].apply(len)][
        "genes"
    ].iat[0]
)
# Out:
# ['10111',
#  '11200',
#  '2521',
#  '472',
#  '545',
#  '546',
#  '5883',
#  '5884',
#  '5884',
#  '5888',
#  '5893',
#  '5980',
#  '7376']

# %% [markdown]
# The following should have no rows, because the results from AR shouldn't have any duplicates:

# %%
ar_gmt_df["unique_genes"] = ar_gmt_df["genes"].apply(lambda x: list(set(x)))
ar_gmt_df[ar_gmt_df["genes"].apply(len) != ar_gmt_df["unique_genes"].apply(len)]
# Out:
# Empty DataFrame
# Columns: [figid, figtitle, genes, genes_str, unique_genes]
# Index: []

# %% [markdown]
# There are `309` hits in AR that are missing from AP, e.g., the figure with figid `PMC4929164__294_2016_565_Fig2_HTML.jpg`.

# %%
len(weird_ar)
# Out:
# 309

# %%
list(weird_ar)[0]
# Out:
# 'PMC4929164__294_2016_565_Fig2_HTML.jpg'

# %%
pfocr_genes_df[pfocr_genes_df["figid"] == list(weird_ar)[0]].head()
# Out:
#                                          figid       pmcid   word symbol  \
# 661217  PMC4929164__294_2016_565_Fig2_HTML.jpg  PMC4929164  (CDK)    CDK
# 661218  PMC4929164__294_2016_565_Fig2_HTML.jpg  PMC4929164  (CDK)    CDK
# 661219  PMC4929164__294_2016_565_Fig2_HTML.jpg  PMC4929164  (CDK)    CDK
# 661220  PMC4929164__294_2016_565_Fig2_HTML.jpg  PMC4929164  (CDK)    CDK
# 661221  PMC4929164__294_2016_565_Fig2_HTML.jpg  PMC4929164  (CDK)    CDK
#
#                     source hgnc_symbol  entrez
# 661217  bioentities_symbol      CDK11A  728642
# 661218  bioentities_symbol        CDK8    1024
# 661219  bioentities_symbol        CDK7    1022
# 661220  bioentities_symbol        CDK3    1018
# 661221  bioentities_symbol       CDKL5    6792

# %% [markdown]
# The results from AP don't even contain anything for the paper:

# %%
ap_gmt_df[ap_gmt_df["figid"].str.contains("PMC4929164", regex=False)]
# Out:
# Empty DataFrame
# Columns: [figid, figtitle, genes, unique_genes]
# Index: []

# %% [markdown]
# There are `311` hits in AP that are missing from AR, e.g., the figure with figid `PMC5752509__oncotarget-08-109135-g007.jpg`.

# %%
len(weird_ap)
# Out:
# 311

# %%
list(weird_ap)[0]
# Out:
# 'PMC5752509__oncotarget-08-109135-g007.jpg'

# %%
print(len(pfocr_genes_df[pfocr_genes_df["figid"] == list(weird_ap)[0]]))
pfocr_genes_df[pfocr_genes_df["figid"] == list(weird_ap)[0]]
# Out:
# 10
#                                             figid       pmcid   word symbol  \
# 847113  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    RAR    RAR
# 847114  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    RAR    RAR
# 847115  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    P38    p38
# 847116  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    P38    p38
# 847117  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    P38    p38
# 847118  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    P38    p38
# 847119  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509   RARa   RARA
# 847120  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    Src    SRC
# 847121  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509    RAR    RAR
# 847122  PMC5752509__oncotarget-08-109135-g007.jpg  PMC5752509  GPR40  GPR40
#
#                     source hgnc_symbol  entrez
# 847113  bioentities_symbol        RARB    5915
# 847114  bioentities_symbol        RARG    5916
# 847115  bioentities_symbol      MAPK13    5603
# 847116  bioentities_symbol      MAPK12    6300
# 847117  bioentities_symbol      MAPK14    1432
# 847118  bioentities_symbol      MAPK11    5600
# 847119         hgnc_symbol        RARA    5914
# 847120         hgnc_symbol         SRC    6714
# 847121  bioentities_symbol        RARA    5914
# 847122    hgnc_prev_symbol       FFAR1    2864

# %% [markdown]
# The results from AR don't even contain anything for the paper:

# %%
ar_gmt_df[ar_gmt_df["figid"].str.contains("PMC5752509", regex=False)]
# Out:
# Empty DataFrame
# Columns: [figid, figtitle, genes, genes_str, unique_genes]
# Index: []

# %%
print(len(pfocr_genes_df[pfocr_genes_df["figid"].isin(weird_ap)]))
pfocr_genes_df[pfocr_genes_df["figid"].isin(weird_ap)]
# Out:
# 3304
#                                     figid       pmcid      word    symbol  \
# 452      PMC1069556__zjv0080560770006.jpg  PMC1069556       Tef       TEF
# 453      PMC1069556__zjv0080560770006.jpg  PMC1069556    GSK-3B     GSK3B
# 454      PMC1069556__zjv0080560770006.jpg  PMC1069556       Bad       BAD
# 455      PMC1069556__zjv0080560770006.jpg  PMC1069556      p110      p110
# 456      PMC1069556__zjv0080560770006.jpg  PMC1069556  Bcatenin  BCATENIN
# ...                                   ...         ...       ...       ...
# 1112145        PMC98722__ii1010637004.jpg    PMC98722     actin     Actin
# 1112146        PMC98722__ii1010637004.jpg    PMC98722     actin     Actin
# 1112147        PMC98722__ii1010637004.jpg    PMC98722     Cdc42     CDC42
# 1112148        PMC98722__ii1010637004.jpg    PMC98722    N-WASP    N-WASP
# 1112149        PMC98722__ii1010637004.jpg    PMC98722    (WASP)      WASP
#
#                      source hgnc_symbol  entrez
# 452             hgnc_symbol         TEF    7008
# 453             hgnc_symbol       GSK3B    2932
# 454             hgnc_symbol         BAD     572
# 455       hgnc_alias_symbol       SART3    9733
# 456      bioentities_symbol      CTNNB1    1499
# ...                     ...         ...     ...
# 1112145  bioentities_symbol       ACTG1      71
# 1112146  bioentities_symbol       ACTG2      72
# 1112147         hgnc_symbol       CDC42     998
# 1112148   hgnc_alias_symbol        WASL    8976
# 1112149   hgnc_alias_symbol         WAS    7454
#
# [3304 rows x 7 columns]

# %%
pfocr_genes_df
# Out:
#                                figid      pmcid      word     symbol  \
# 0        PMC100003__mb2410470011.jpg  PMC100003  Ga12,Gaq  G-ALPHA-q
# 1        PMC100003__mb2410470011.jpg  PMC100003       Etk        ETK
# 2        PMC100003__mb2410470011.jpg  PMC100003       FAK        FAK
# 3        PMC100003__mb2410470011.jpg  PMC100003       AR*         AR
# 4        PMC100003__mb2410470011.jpg  PMC100003      (Src        SRC
# ...                              ...        ...       ...        ...
# 1112546   PMC99976__mb2310138007.jpg   PMC99976     MEK-2       MEK2
# 1112547   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112548   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112549   PMC99976__mb2310138007.jpg   PMC99976       RAS        RAS
# 1112550   PMC99976__mb2310138007.jpg   PMC99976     SOS-1       SOS1
#
#                      source hgnc_symbol  entrez
# 0         hgnc_alias_symbol        GNAQ    2776
# 1         hgnc_alias_symbol         BMX     660
# 2         hgnc_alias_symbol        PTK2    5747
# 3               hgnc_symbol          AR     367
# 4               hgnc_symbol         SRC    6714
# ...                     ...         ...     ...
# 1112546   hgnc_alias_symbol      MAP2K2    5605
# 1112547  bioentities_symbol        HRAS    3265
# 1112548  bioentities_symbol        KRAS    3845
# 1112549  bioentities_symbol        NRAS    4893
# 1112550         hgnc_symbol        SOS1    6654
#
# [1112551 rows x 7 columns]

# %%
pfocr_df[pfocr_df["figid"].isin(weird_ap)]["unique_gene_count"].max()
# Out:
# 9

# %%
pfocr_genes_df[pfocr_genes_df["figid"].isin(weird_ap)].groupby("figid")[
    "entrez"
].count().max()
# Out:
# 17

# %%
counts_df = (
    pfocr_genes_df[pfocr_genes_df["figid"].isin(weird_ap)]
    .groupby("figid")["entrez"]
    .count()
)
counts_df.sort_values()
# counts_df.max()
# counts_df[counts_df["entrez"] == 17]
# Out:
# figid
# PMC1069556__zjv0080560770006.jpg              10
# PMC4800799__zmb9991011760007.jpg              10
# PMC4815360__pr.115.011833f3.jpg               10
# PMC4820813__kcll-05-04-1136374-g005.jpg       10
# PMC4825016__zbc0171641000007.jpg              10
#                                               ..
# PMC5735158__41598_2017_16627_Fig6_HTML.jpg    15
# PMC5915505__441_2018_2801_Fig2_HTML.jpg       15
# PMC6272071__IJBMS-21-911-g007.jpg             15
# PMC5045067__hp-2-197Fig1.jpg                  15
# PMC3151466__nihms-315348-f0002.jpg            17
# Name: entrez, Length: 311, dtype: int64

# %%
pfocr_df[pfocr_df["figid"].isin(weird_ap)][["unique_gene_count"]].max()
# Out:
# unique_gene_count    9
# dtype: int64

# %%
pfocr_df[(pfocr_df["figid"].isin(weird_ap)) & (pfocr_df["unique_gene_count"] == 17)][
    ["figid", "unique_gene_count", "entrez"]
]
# Out:
# Empty DataFrame
# Columns: [figid, unique_gene_count, entrez]
# Index: []

# %%
pfocr_df[pfocr_df["figid"] == "PMC3151466__nihms-315348-f0002.jpg"]
# Out:
#                                     figid    number  \
# 64942  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64943  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64944  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64945  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64946  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64947  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64948  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64949  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64950  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64951  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64952  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64953  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64954  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64955  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64956  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64957  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
# 64958  PMC3151466__nihms-315348-f0002.jpg  Fig. (2)
#
#                                                  reftext year  pathway_score  \
# 64942  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64943  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64944  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64945  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64946  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64947  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64948  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64949  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64950  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64951  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64952  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64953  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64954  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64955  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64956  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64957  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
# 64958  Wei Du, et al. Curr Drug Targets. ;10(7):581-589.   NA       0.910064
#
#        pmc_ranked_result_index figtitle  \
# 64942                   190619
# 64943                   190619
# 64944                   190619
# 64945                   190619
# 64946                   190619
# 64947                   190619
# 64948                   190619
# 64949                   190619
# 64950                   190619
# 64951                   190619
# 64952                   190619
# 64953                   190619
# 64954                   190619
# 64955                   190619
# 64956                   190619
# 64957                   190619
# 64958                   190619
#
#                                     papertitle  \
# 64942  The Rb Pathway and Cancer Therapeutics.
# 64943  The Rb Pathway and Cancer Therapeutics.
# 64944  The Rb Pathway and Cancer Therapeutics.
# 64945  The Rb Pathway and Cancer Therapeutics.
# 64946  The Rb Pathway and Cancer Therapeutics.
# 64947  The Rb Pathway and Cancer Therapeutics.
# 64948  The Rb Pathway and Cancer Therapeutics.
# 64949  The Rb Pathway and Cancer Therapeutics.
# 64950  The Rb Pathway and Cancer Therapeutics.
# 64951  The Rb Pathway and Cancer Therapeutics.
# 64952  The Rb Pathway and Cancer Therapeutics.
# 64953  The Rb Pathway and Cancer Therapeutics.
# 64954  The Rb Pathway and Cancer Therapeutics.
# 64955  The Rb Pathway and Cancer Therapeutics.
# 64956  The Rb Pathway and Cancer Therapeutics.
# 64957  The Rb Pathway and Cancer Therapeutics.
# 64958  The Rb Pathway and Cancer Therapeutics.
#
#                                                  caption  \
# 64942  In mammals the E2F family is composed of eight...
# 64943  In mammals the E2F family is composed of eight...
# 64944  In mammals the E2F family is composed of eight...
# 64945  In mammals the E2F family is composed of eight...
# 64946  In mammals the E2F family is composed of eight...
# 64947  In mammals the E2F family is composed of eight...
# 64948  In mammals the E2F family is composed of eight...
# 64949  In mammals the E2F family is composed of eight...
# 64950  In mammals the E2F family is composed of eight...
# 64951  In mammals the E2F family is composed of eight...
# 64952  In mammals the E2F family is composed of eight...
# 64953  In mammals the E2F family is composed of eight...
# 64954  In mammals the E2F family is composed of eight...
# 64955  In mammals the E2F family is composed of eight...
# 64956  In mammals the E2F family is composed of eight...
# 64957  In mammals the E2F family is composed of eight...
# 64958  In mammals the E2F family is composed of eight...
#
#                                    figlink  ... automl_index  \
# 64942  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64943  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64944  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64945  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64946  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64947  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64948  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64949  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64950  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64951  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64952  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64953  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64954  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64955  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64956  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64957  /pmc/articles/PMC3151466/figure/F2/  ...        35244
# 64958  /pmc/articles/PMC3151466/figure/F2/  ...        35244
#
#                                                   figurl  word symbol  \
# 64942  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F1   E2F1
# 64943  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64944  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F2   E2F2
# 64945  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64946  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F3   E2F3
# 64947  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64948  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64949  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F4   E2F4
# 64950  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64951  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F5   E2F5
# 64952  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64953  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F6   E2F6
# 64954  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  p107   p107
# 64955  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F8   E2F8
# 64956  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
# 64957  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  E2F7   E2F7
# 64958  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   E2F    E2F
#
#                    source hgnc_symbol  entrez nobe_count entrez_count  \
# 64942         hgnc_symbol        E2F1    1869         10           17
# 64943  bioentities_symbol        E2F1    1869         10           17
# 64944         hgnc_symbol        E2F2    1870         10           17
# 64945  bioentities_symbol        E2F2    1870         10           17
# 64946         hgnc_symbol        E2F3    1871         10           17
# 64947  bioentities_symbol        E2F3    1871         10           17
# 64948  bioentities_symbol        E2F4    1874         10           17
# 64949         hgnc_symbol        E2F4    1874         10           17
# 64950  bioentities_symbol        E2F5    1875         10           17
# 64951         hgnc_symbol        E2F5    1875         10           17
# 64952  bioentities_symbol        E2F6    1876         10           17
# 64953         hgnc_symbol        E2F6    1876         10           17
# 64954   hgnc_alias_symbol        RBL1    5933         10           17
# 64955         hgnc_symbol        E2F8   79733         10           17
# 64956  bioentities_symbol        E2F8   79733         10           17
# 64957         hgnc_symbol        E2F7  144455         10           17
# 64958  bioentities_symbol        E2F7  144455         10           17
#
#       unique_gene_count
# 64942                 9
# 64943                 9
# 64944                 9
# 64945                 9
# 64946                 9
# 64947                 9
# 64948                 9
# 64949                 9
# 64950                 9
# 64951                 9
# 64952                 9
# 64953                 9
# 64954                 9
# 64955                 9
# 64956                 9
# 64957                 9
# 64958                 9
#
# [17 rows x 24 columns]

# %%
pfocr_genes_df[pfocr_genes_df["figid"].isin(weird_ap)][
    ["figid", "entrez"]
].drop_duplicates().groupby("figid")["entrez"].count().max()
# Out:
# 9

# %% [markdown]
# For GMT files, tabs and percent signs are special characters. Let's check whether we have any that require escaping.
#
# No figids or figtitles have tabs, and no figid has a percent sign.

# %%
for i, row in (
    pfocr_df[
        pfocr_df["figtitle"].str.contains("\t")
        | pfocr_df["figid"].str.contains("\t")
        | pfocr_df["figid"].str.contains("\%")
    ][["figid", "figtitle"]]
    .drop_duplicates()
    .iterrows()
):
    figtitle = row["figtitle"]
    figid = row["figid"]
    print(f"{figid} '{figtitle}'")

# %% [markdown]
# Some figtitles do have at least one percent sign.

# %%
for i, row in (
    pfocr_df[pfocr_df["figtitle"].str.contains("\%")][["figid", "figtitle"]]
    .drop_duplicates()
    .iterrows()
):
    figtitle = row["figtitle"]
    figid = row["figid"]
    print(figid)
    print(figtitle)
    print("")
# Out:
# PMC2703816__nihms100324f3.jpg
# Functional annotation of 115 C/EBPŒ≤ target genes presented in pie chart format shows that 74% of target genes are dedicated to signaling, metabolism, and transport, with the remaining 26% having roles in transcription, synaptic transmission, differentiation and proliferation
#
# PMC2730981__nihms137404f1.jpg
# Activation of inflammatory pathway mediated through NF-Œ∫B by life-style related factors such as tobacco, stress, dietary agents, obesity, alcohol, infectious agents, irradiation and environmental stimuli that account for as much as 95% of all cancers
#
# PMC2750869__nihms91210f5.jpg
# Final elaboration of 8, the requisite cyclization precursor, entailed treatment of 2-butanone (21) with (‚àí)-DIPCl and Et3N according to conditions developed by Paterson,, followed by addition of aldehyde (+)-20; cyclization precursor (8) was obtained as an inseparable mixture of diastereomers (5:1) in 86% yield ()
#
# PMC3188852__nihms196597f11.jpg
# In order to construct the quaternary carbon center at C-16, numerous efforts (aldolizations, alkylations, and acylations) were originally carried out, but they were not successful.‚Äì Gratifyingly, it was found that the aldehydic group at C-16 in Na-methylvellosimine could be converted into its related diol after 60 hours in 88% yield via the Tollens reaction by using 37% aqueous formaldehyde (5 equivalents) and KOH (10 equivalents) in methanol
#
# PMC3188852__nihms196597f6.jpg
# The key intermediate, (+)-vellosimine (13) was prepared from the common intermediate, E-ethylidene ketone 10, which was synthesized via the asymmetric Pictect-Spengler reaction, Dieckmann cyclization, and palladium mediated cross coupling in high overall yield.‚Äì As illustrated in , the route began with the readily available (‚àí)-Na-H tetracyclic ketone 19, which was subjected to the conditions of catalytic hydrogenolysis to remove the benzyl function in 92% yield
#
# PMC3887475__nihms515312f5.jpg
# When we conducted further studies to test whether the oxidation pathway could be generalized, we found that cyclopentenones with exocyclic double bonds could be obtained in good yields from several other substrates with electron-withdrawing aromatic substituents (62‚Äì92% yield; )
#
# PMC5195866__nihms818513f1.jpg
# Role of CYP2A6 in the metabolic pathway of nicotine.Up to 80% of a nicotine dose inhaled from cigarette smoke undergoes metabolic inactivation to cotinine
#
# PMC152346__008946f5.jpg
# Simplified Scheme of Predicted Fluxes of C16 and C18 Fatty Acids in Membrane Leaf Glycerolipids of Arabidopsis Wild-Type, fatb-ko, and fatb-ko act1 Mutant Plants.The numbers in the figure represent average values of mol % units of C16 and C18 fatty acids accumulated in membrane glycerolipids
#
# PMC523366__pp1363043f05.jpg
# Metabolic flux map of primary and intermediate metabolic pathways in developing soybean cotyledons cultured on Suc (10% [w/w] U-13C) and Gln
#
# PMC1383630__tpc1800523f01.jpg
# Schematic Representation of Arabidopsis Nonhost Resistance to Bgh.After germination of spores (Sp), formation of appressoria (Ap), and breaching of the host cell wall (CW) by the fungal penetration peg (Pp), ‚àº90% of penetrations are stopped in cell wall extensions called papillae (Pa)
#
# PMC1393175__zam0030665160003.jpg
# Transcriptional response of frc and oxc to pH 5.5, pH 4.5, and 1% (70 mM) ammonium oxalate (pH 6.8) in MRS broth after 30 min
#
# PMC2785970__pp1511769f03.jpg
# Iodine staining of starch content together with quantitative measurements (in mg g‚àí1 fresh weight, and as a % of Columbia-0 in parentheses) from four replicate plants, harvested at the end of the day
#
# PMC2813229__1477-5956-7-48-4.jpg
# Pathway analysis result showing 18 differentially expressed proteins following 50% PH can be sorted into the c-myc pathway
#
# PMC2932889__kdj-34-211-g002.jpg
# A fraction (2-5%) of the glucose entering a cell is directed into the hexosamine biosynthesis pathway (HBP) pathway
#
# PMC3109408__PD2011-716859.002.jpg
# Simplified diagram of Kynurenine pathway: during neuroinflammation, 95% of the dietary tryptophan is metabolized along the KP within the brain
#
# PMC3715096__anie0052-5305-f7.jpg
# Mechanistic rationale for the formation of (¬±)-1 and (¬±)-14: 15 was obtained by the oxidative addition of Pd0 to (¬±)-2; pathway A: C‚ÄìH activation pathway by highly electrophilic Ar‚ÄìPd species; pathway B: Generation of a syn Œ≤-hydride (Hb) by a Pd-enolate; Pathway C: Formation of (¬±)-iso-linoxepin 14 by a syn Œ≤-hydride elimination of Ha; conditions: a) PdCl2 (20 mol %), PPh3 (44 mol %) NEt3 (10 equiv), microwave radiation, DMF, 130 ¬∞C, 7 h, 74 %; b) PdCl2 (20 mol %), PPh3 (44 mol %), CsOAc (10.0 equiv), DMF, 75 ¬∞C, 4 h, 78 %
#
# PMC3842785__1475-2859-12-109-6.jpg
# 100% 2-13C glycerol ILE shows that glycine and serine are predominantly synthesized from glyoxylate rather than 3-phosphoglycerate
#
# PMC4417967__toxins-07-01273-g002.jpg
# Relative adenine and thymine (%AT) DNA content of ergot alkaloid synthesis (EAS) loci
#
# PMC4638047__zjw0111551700007.jpg
# Pathway analysis highlights APP is a central hub interacting with nearly 40% of candidate molecules in EGS
#
# PMC5223135__nutd201649f4.jpg
# Proposed mechanisms of kefir peptides-mediated modulation of the lipid metabolism pathway in 30% fructose-induced NAFLD mice
#
# PMC5505034__13068_2017_868_Fig2_HTML.jpg
# Genes transcript abundance of reconstructed carbon fixation pathway in Chlorella PY-ZU1 cells cultivated with 15% CO2 gas versus air
#
# PMC6404759__nihms-997888-f0001.jpg
# Major metabolic pathway (97%) in cancer initiation by estrogens
#
# PMC5863803__12864_2018_4609_Fig5_HTML.jpg
# Schematic representation of the expression of genes of glycolysis, pentose phosphate pathway (PPP) and pentose catabolic pathway (PCP) in Aspergillus nidulans after 2¬†h of transfer to 1% (w/v) wheat bran
#
# PMC5918149__13568_2018_594_Fig6_HTML.jpg
# Contribution made by different microbes in consortium CY-1 when 50% phenanthrene was removed
#
# PMC6016767__pnas.1721487115fig02.jpg
# Three TFs‚ÄîCRF4, SNZ, and CDF1‚Äîregulate 53% of the N-uptake/assimilation pathway genes
#
# PMC6134795__12916_2018_1136_Fig1_HTML.jpg
# Composite pathway using the KEGG pathway analysis, a composite pathway was generated based on the canonical mapping of the phosphorylated proteins independently associated with increased % collagen (red) in the liver
#
# PMC6471220__ijms-20-01472-g003.jpg
# Transcriptional effects in zebrafish liver after feeding with 25% of maize substitution
#
# PMC6630544__pharmaceuticals-12-00066-g001.jpg
# Stages of Mtb transmission and infection cycle showing that 95% of infected patients will have the latent form, and 50% of relapse cases will go directly from latent to active form (only 5% for new cases) []

# %%
pfocr_df[pfocr_df["figid"].str.contains("\t")]
# Out:
# Empty DataFrame
# Columns: [figid, number, reftext, year, pathway_score, pmc_ranked_result_index, figtitle, papertitle, caption, figlink, pmcid, filename, source_f, type.man, automl_index, figurl, word, symbol, source, hgnc_symbol, entrez, nobe_count, entrez_count, unique_gene_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
# A figid that rpy2 may be importing incorrectly. Check the encoding of figtitles.
pfocr_figures_df[pfocr_figures_df["figid"] == "PMC2703816__nihms100324f3.jpg"]
# Out:
#                                figid    number  \
# 61692  PMC2703816__nihms100324f3.jpg  Figure 3
#
#                                                  reftext year  pathway_score  \
# 61692  N. Kfoury, et al. Mol Cell Neurosci. ;40(3):31...   NA       0.708703
#
#        pmc_ranked_result_index  \
# 61692                   222034
#
#                                                 figtitle  \
# 61692  Functional annotation of 115 C/EBPŒ≤ target ge...
#
#                                               papertitle  \
# 61692  Identification of neuronal target genes for CC...
#
#                                                  caption  \
# 61692  Functional annotation of 115 C/EBPŒ≤ target ge...
#
#                                    figlink       pmcid           filename  \
# 61692  /pmc/articles/PMC2703816/figure/F3/  PMC2703816  nihms100324f3.jpg
#
#                                            source_f type.man  automl_index  \
# 61692  ../data/images/PMC2703816__nihms100324f3.jpg       NA         58133
#
#                                                   figurl
# 61692  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...

# %%
import pandas as pd
import rpy2

import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr

pandas2ri.activate()
base = importr("base")
readRDS = robjects.r["readRDS"]

# %%
def rdf2pandas(df):
    df_names = base.names(df)
    data = dict()
    for i in range(len(df_names)):
        column = df[i]
        if hasattr(column, "iter_labels"):
            data[df_names[i]] = [x for x in column.iter_labels()]
        else:
            data[df_names[i]] = [x for x in column]

    return pd.DataFrame(data=data)


def rds2pandas(f):
    return rdf2pandas(readRDS(str(f)))

# %%
hmm_pfocr_figures_df = readRDS(
    "~/Dropbox (Gladstone)/Documents/PFOCR_25Years/pfocr_figures.rds"
)
hmm_pfocr_figures_df.head()
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x75f3d5d70eb0 / R:0x1eb60358>
# [StrVector, StrVector, StrVector, StrVector, ..., StrVector, StrVector, StrVector, StrVector]
#   figid: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5edfbe0 / R:0x151ad988>
# ['PMC5..., 'PMC4..., 'PMC5..., 'PMC4..., 'PMC2..., 'PMC4...]
#   pmcid: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5fd9f50 / R:0x151ad9f8>
# ['PMC5..., 'PMC4..., 'PMC5..., 'PMC4..., 'PMC2..., 'PMC4...]
#   filename: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5dd28c0 / R:0x151ada68>
# ['4159..., 'zh20..., 'rsob..., 'pone..., 'nihm..., 'emss...]
#   year: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5d83be0 / R:0x151adad8>
# ['2017', '2014', '2017', '2014', NA_character_, '2015']
# ...
#   pmc_ranked_result_index: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5dc9a50 / R:0x151add08>
# ['Mode..., 'Stim..., 'AB p..., 'Gluc..., 'NeuA..., 'Sche...]
#   figlink: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5fb3640 / R:0x151add78>
# ['Figu..., 'Fig...., 'Figu..., 'Figu..., 'Figu..., 'Figu...]
#   source_f: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5f3e500 / R:0x151adde8>
# ['Mode..., 'Prop..., 'Aβ p..., 'Gluc..., 'Bact..., 'Sche...]
#   type.man: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3d5d908c0 / R:0x151ade58>
# ['Homo..., 'Homo..., 'Homo..., 'Homo..., 'Homo..., 'Homo...]

# %%
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

from rpy2.robjects.conversion import localconverter

# %%
r_df = ro.DataFrame(
    {
        "int_values": ro.IntVector([1, 2, 3]),
        "str_values": ro.StrVector(["abc", "def", "ghi"]),
    }
)

r_df
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x75f3c8ddcb40 / R:0x36f91d18>
# [IntVector, StrVector]
#   int_values: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x75f3c8ade320 / R:0x36f91258>
# [1, 2, 3]
#   str_values: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x75f3c8ade3c0 / R:0x1ed36ff8>
# ['abc', 'def', 'ghi']

# %% [markdown]
# Demo from [here](https://rpy2.github.io/doc/v3.4.x/html/generated_rst/pandas.html)

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
    pd_from_r_df = ro.conversion.ri2py_dataframe(r_df)

pd_from_r_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-192-6d2b643804af> in <module>
#       1 with localconverter(ro.default_converter + pandas2ri.converter):
# ----> 2     pd_from_r_df = ro.conversion.ri2py_dataframe(r_df)
#       3
#       4 pd_from_r_df
#
# AttributeError: module 'rpy2.robjects.conversion' has no attribute 'ri2py_dataframe'

# %%
from rpy2.robjects import pandas2ri
from rpy2.robjects import default_converter
from rpy2.robjects.conversion import localconverter

with localconverter(default_converter + pandas2ri.converter) as cv:
    pd_from_r_df = pandas2ri.ri2py(r_df)
pd_from_r_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-dd482ca90ca7> in <module>
#       4
#       5 with localconverter(default_converter + pandas2ri.converter) as cv:
# ----> 6     pd_from_r_df = pandas2ri.ri2py(r_df)
#       7 pd_from_r_df
#
# /nix/store/gpnm7i19lpj8p43mjrdw03d0hjalmskl-python3-3.7.5/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in ri2py_dataframe(obj)
#     188 @ri2py.register(DataFrame)
#     189 def ri2py_dataframe(obj):
# --> 190     items = tuple((k, ri2py(v)) for k, v in obj.items())
#     191     res = PandasDataFrame.from_items(items)
#     192     return res
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in <genexpr>(.0)
#     188 @ri2py.register(DataFrame)
#     189 def ri2py_dataframe(obj):
# --> 190     items = tuple((k, ri2py(v)) for k, v in obj.items())
#     191     res = PandasDataFrame.from_items(items)
#     192     return res
#
# /nix/store/gpnm7i19lpj8p43mjrdw03d0hjalmskl-python3-3.7.5/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in ri2py_vector(obj)
#     137 @ri2py.register(SexpVector)
#     138 def ri2py_vector(obj):
# --> 139     res = numpy2ri.ri2py(obj)
#     140     return res
#     141
#
# /nix/store/gpnm7i19lpj8p43mjrdw03d0hjalmskl-python3-3.7.5/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/numpy2ri.py in ri2py_sexp(obj)
#     157 def ri2py_sexp(obj):
#     158     if (obj.typeof in _vectortypes) and (obj.typeof != VECSXP):
# --> 159         res = numpy.asarray(obj)
#     160     else:
#     161         res = ro.default_converter.ri2py(obj)
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: Buffer for this type not yet supported.

# %%
pandas2ri.ri2py_dataframe(r_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-714aeae71077> in <module>
# ----> 1 pandas2ri.ri2py_dataframe(r_df)
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in ri2py_dataframe(obj)
#     188 @ri2py.register(DataFrame)
#     189 def ri2py_dataframe(obj):
# --> 190     items = tuple((k, ri2py(v)) for k, v in obj.items())
#     191     res = PandasDataFrame.from_items(items)
#     192     return res
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in <genexpr>(.0)
#     188 @ri2py.register(DataFrame)
#     189 def ri2py_dataframe(obj):
# --> 190     items = tuple((k, ri2py(v)) for k, v in obj.items())
#     191     res = PandasDataFrame.from_items(items)
#     192     return res
#
# /nix/store/gpnm7i19lpj8p43mjrdw03d0hjalmskl-python3-3.7.5/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py in ri2py_vector(obj)
#     137 @ri2py.register(SexpVector)
#     138 def ri2py_vector(obj):
# --> 139     res = numpy2ri.ri2py(obj)
#     140     return res
#     141
#
# /nix/store/gpnm7i19lpj8p43mjrdw03d0hjalmskl-python3-3.7.5/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/robjects/numpy2ri.py in ri2py_sexp(obj)
#     157 def ri2py_sexp(obj):
#     158     if (obj.typeof in _vectortypes) and (obj.typeof != VECSXP):
# --> 159         res = numpy.asarray(obj)
#     160     else:
#     161         res = ro.default_converter.ri2py(obj)
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: Buffer for this type not yet supported.

# %%
rpy2.situation
# Out:
# <module 'rpy2.situation' from '/nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/situation.py'>

# %%
ro.conversion.ri2py
# Out:
# <function rpy2.robjects.conversion._ri2py(obj)>

# %%
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

from rpy2.robjects.conversion import localconverter

# %%
pd_df = pd.DataFrame({"int_values": [1, 2, 3], "str_values": ["abc", "def", "ghi"]})

pd_df
# Out:
#    int_values str_values
# 0           1        abc
# 1           2        def
# 2           3        ghi

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
    r_from_pd_df = ro.conversion.py2rpy(pd_df)

r_from_pd_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-ba05bb0f6f26> in <module>
#       1 with localconverter(ro.default_converter + pandas2ri.converter):
# ----> 2     r_from_pd_df = ro.conversion.py2rpy(pd_df)
#       3
#       4 r_from_pd_df
#
# AttributeError: module 'rpy2.robjects.conversion' has no attribute 'py2rpy'

# %%
from functools import partial
from rpy2.ipython import html
html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/ipython/rmagic.py in <module>
#     105 try:
# --> 106     from IPython.external.simplegeneric import generic
#     107 except ImportError:
#
# ModuleNotFoundError: No module named 'IPython.external.simplegeneric'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-200-39bcd566a575> in <module>
#       1 from functools import partial
# ----> 2 from rpy2.ipython import html
#       3 html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils")
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/ipython/__init__.py in <module>
# ----> 1 from .rmagic import load_ipython_extension
#
# /nix/store/hm475d8nhddsi2cvipkhl8k06cmxn7kh-python3-3.7.5-env/lib/python3.7/site-packages/rpy2/ipython/rmagic.py in <module>
#     107 except ImportError:
#     108     # IPython 4.0
# --> 109     from simplegeneric import generic
#     110
#     111
#
# ModuleNotFoundError: No module named 'simplegeneric'

# %%
# /run/user/1000/tmp_yz5_q44/pfocr20200224.gmt
